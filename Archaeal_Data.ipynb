# %% [markdown]
# # Archaeal Blast Data Handling

# %% [markdown]
# ## 1.1 Create Archaeal Master file

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits"

# Name of the master file
master_filename = "archaeal_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/archaeal_master_blaster.txt

# %% [markdown]
# ## 1.2 Print Total Hits and Accession ID's

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/archaeal_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract accession IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_accession_id = None
        for line in master_file:
            if "|" in line:  
                current_accession_id = line.split("|")[1].strip()
            elif ">" in line:  
                if current_accession_id:
                    query_hits[current_accession_id].append(line.split(">")[1].strip())  
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {accession_id: len(hits) for accession_id, hits in query_hits.items()}

# Rank and print total hits
print("Ranked total hits for each accession ID:")
for rank, (accession_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {accession_id}, Total Hits: {hits}")

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/archaeal_master_blaster_results.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Accession ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for accession_id, hits in query_hits.items():
            writer.writerow({'Accession ID': accession_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Ranked total hits for each accession ID:
# 1. Accession ID: Q02388, Total Hits: 250
# 2. Accession ID: P11802, Total Hits: 250
# 3. Accession ID: P09914, Total Hits: 250
# 4. Accession ID: P60484, Total Hits: 250
# 5. Accession ID: Q00535, Total Hits: 250
# 6. Accession ID: P06493, Total Hits: 250
# 7. Accession ID: P43490, Total Hits: 250
# 8. Accession ID: Q9Y3Z3, Total Hits: 250
# 9. Accession ID: Q15303, Total Hits: 250
# 10. Accession ID: P19525, Total Hits: 250
# 11. Accession ID: P19838, Total Hits: 250
# 12. Accession ID: Q00534, Total Hits: 250
# 13. Accession ID: O95786, Total Hits: 250
# 14. Accession ID: O14879, Total Hits: 250
# 15. Accession ID: Q13325, Total Hits: 250
# 16. Accession ID: P56199, Total Hits: 250
# 17. Accession ID: Q00526, Total Hits: 250
# 18. Accession ID: P24941, Total Hits: 250
# 19. Accession ID: P01019, Total Hits: 250
# 20. Accession ID: P06396, Total Hits: 206
# 21. Accession ID: Q12965, Total Hits: 56
# 22. Accession ID: O43745, Total Hits: 37
# 23. Accession ID: O43808, Total Hits: 33
# 24. Accession ID: Q99653, Total Hits: 23
# 25. Accession ID: P55265, Total Hits: 19
# 26. Accession ID: P20592, Total Hits: 11
# 27. Accession ID: P20591, Total Hits: 11
# 28. Accession ID: P38398, Total Hits: 9
# 29. Accession ID: P19883, Total Hits: 8
# 30. Accession ID: Q9BTW9, Total Hits: 7
# 31. Accession ID: O00910, Total Hits: 4
# 32. Accession ID: P42224, Total Hits: 3
# 33. Accession ID: P40763, Total Hits: 3
# 34. Accession ID: Q14765, Total Hits: 3
# 35. Accession ID: P52630, Total Hits: 3
# 36. Accession ID: P42226, Total Hits: 3
# 37. Accession ID: P02533, Total Hits: 2
# 38. Accession ID: P01966, Total Hits: 1
# 39. Accession ID: P04637, Total Hits: 1
# 40. Accession ID: P15502, Total Hits: 1
# 41. Accession ID: Q96BS2, Total Hits: 1
# 42. Accession ID: P13164, Total Hits: 1
# 43. Accession ID: Q92968, Total Hits: 1
# 44. Accession ID: P23142, Total Hits: 1
# 45. Accession ID: Q9Y5Y5, Total Hits: 1
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/archaeal_master_blaster_results.csv'

# %% [markdown]
# ### 1.2.1 Make additions to masterfile to analyse hits in regard to protein type and name

# %%
import pandas as pd

# File paths
archaeal_master_blaster_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/archaeal_master_blaster_results.csv"
protein_names_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/protein_names.csv"
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/archaeal_master_blaster_protein_results.csv"

# Read the bacterial master blaster CSV
master_blaster_df = pd.read_csv(archaeal_master_blaster_filepat)

# Read the protein names CSV
protein_names_df = pd.read_csv(protein_names_filepath)

# Merge the dataframes on 'Accession ID'
merged_df = pd.merge(master_blaster_df, protein_names_df[['Accession ID', 'Protein Names', 'Protein Type']], on='Accession ID', how='left')

# Reorder columns to place 'Protein Names' and 'Protein Type' at the start
cols = ['Protein Names', 'Protein Type'] + [col for col in bacterial_master_blaster_df.columns if col not in ['Protein Names', 'Protein Type']]
merged_df = merged_df[cols]

# Write the merged dataframe to a new CSV file
merged_df.to_csv(output_csv_path, index=False)

# Count the number of unique protein names
unique_protein_names = merged_df['Protein Names'].nunique()
print(f"Number of unique protein names: {unique_protein_names}")

# Breakdown of each protein type
protein_type_counts = merged_df['Protein Type'].value_counts()
print("Breakdown of protein types:")
print(protein_type_counts)

print(f"Merged results saved to '{output_csv_path}'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bd9e44084968> in <module>
#       7
#       8 # Read the bacterial master blaster CSV
# ----> 9 master_blaster_df = pd.read_csv(archaeal_master_blaster_filepat)
#      10
#      11 # Read the protein names CSV
#
# NameError: name 'archaeal_master_blaster_filepat' is not defined

# %% [markdown]
# ## 1.3 Filter for Queries which Produced Hits

# %%
import os
import shutil

# Function to check if the given file contains the phrase "No hits found" (case-insensitive)
def contains_no_hits(file_path):
    with open(file_path, 'r') as f:
        content = f.read()
        return "no hits found" not in content.lower()  

# Source directory containing blast result files
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/"

# Destination directory for files with hits
dest_dir = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits"

# Create destination directory if it doesn't exist
if not os.path.exists(dest_dir):
    os.makedirs(dest_dir)

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith(".txt"):  # Check if it's a text file
        file_path = os.path.join(source_dir, file_name)
        if contains_no_hits(file_path):
            # Move the file to the destination directory if it contains hits
            shutil.move(file_path, os.path.join(dest_dir, file_name))

# %% [markdown]
# ## 1.4 Create Initial Species CSV file from Master File

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/archaeal_hits_data.csv"

# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Function to parse data from blast result file
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        query_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0  # Initialize hit_number
        hit_id = None  # Initialize hit_id variable
        species_id = None  # Initialize species_id variable
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1  # Increment hit_number for each new hit
                # Extract Hit ID
                hit_id = line.split(">")[1].split(" ")[0]
                # Extract species ID if present
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
                # Manually add species ID for specific hit ID
                if hit_id == "MDO8640940.1":
                    species_id = "Nitrosarchaeum sp."

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
                hits_data.append([query_id, hit_id, hit_number, seq_length, species_id])
    return hits_data

# List to store parsed data
parsed_data = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"): 
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow(['Accession ID', 'Hit ID', 'Hit Number', 'Sequence Length', 'Species ID'])
    # Write parsed data
    writer.writerows(parsed_data)

print("CSV file created successfully")
# Out:
# CSV file created successfully

# %% [markdown]
# ## 1.5 Create comprehensive CSV table containing blast alignment results

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/comp_archaeal_data.csv"

# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Parse out required data from blast reaults
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        query_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0 
        hit_id = None 
        species_id = None 
        seq_length = None  
        evalue = None 
        score = None  
        identities = None  
        identities_percent = None
        positives = None 
        positives_percent = None  
        gaps = None  
        gaps_percent = None  
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1 
                hit_id = line.split(">")[1].split(" ")[0]
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
                # Manually add species ID for specific hit ID
                if hit_id == "MDO8640940.1":
                    species_id = "Nitrosarchaeum sp."

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
            elif hit_id and "Expect =" in line:
                evalue = line.split("Expect = ")[1].split(",")[0].strip()
                score = line.split("Score = ")[1].split(" bits")[0].strip()
            elif hit_id and "Identities =" in line:
                identities_str = line.split("Identities = ")[1].split(",")[0].strip()
                identities = identities_str.split(" ")[0]
                identities_fraction = identities.split("/")
                identities_percent = (int(identities_fraction[0]) / int(identities_fraction[1])) * 100
                positives_str = line.split("Positives = ")[1].split(",")[0].strip()
                positives = positives_str.split(" ")[0]
                positives_fraction = positives.split("/")
                positives_percent = (int(positives_fraction[0]) / int(positives_fraction[1])) * 100
                gaps_str = line.split("Gaps = ")[1].split(" ")[0].strip()
                gaps = gaps_str
                gaps_fraction = gaps.split("/")
                gaps_percent = (int(gaps_fraction[0]) / int(gaps_fraction[1])) * 100
                # Append all values to hits_data
                hits_data.append([
                    query_id, hit_id, hit_number, seq_length, species_id, evalue, score, 
                    identities, f"{identities_percent:.2f}%", positives, f"{positives_percent:.2f}%", gaps, f"{gaps_percent:.2f}%"
                ])
    return hits_data

# List to store parsed data
parsed_data = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"): 
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow([
        'Accession ID', 'Hit ID', 'Hit Number', 'Sequence Length', 'Species ID', 'Evalue', 'Score', 
        'Identities', 'Identities (%)', 'Positives', 'Positives (%)', 'Gaps', 'Gaps (%)'
    ])
    # Write parsed data
    writer.writerows(parsed_data)

print("CSV file created successfully")
# Out:
# CSV file created successfully

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/comp_archaeal_data.csv"

# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Parse out required data from blast reaults
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        query_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0 
        hit_id = None 
        species_id = None 
        seq_length = None  
        evalue = None 
        score = None  
        identities = None  
        identities_percent = None
        positives = None 
        positives_percent = None  
        gaps = None  
        gaps_percent = None  
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1 
                hit_id = line.split(">")[1].split(" ")[0]
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
               

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
            elif hit_id and "Expect =" in line:
                evalue = line.split("Expect = ")[1].split(",")[0].strip()
                score = line.split("Score = ")[1].split(" bits")[0].strip()
            elif hit_id and "Identities =" in line:
                identities_str = line.split("Identities = ")[1].split(",")[0].strip()
                identities = identities_str.split(" ")[0]
                identities_fraction = identities.split("/")
                identities_percent = (int(identities_fraction[0]) / int(identities_fraction[1])) * 100
                positives_str = line.split("Positives = ")[1].split(",")[0].strip()
                positives = positives_str.split(" ")[0]
                positives_fraction = positives.split("/")
                positives_percent = (int(positives_fraction[0]) / int(positives_fraction[1])) * 100
                gaps_str = line.split("Gaps = ")[1].split(" ")[0].strip()
                gaps = gaps_str
                gaps_fraction = gaps.split("/")
                gaps_percent = (int(gaps_fraction[0]) / int(gaps_fraction[1])) * 100
                # Append all values to hits_data
                hits_data.append([
                    query_id, hit_id, hit_number, seq_length, species_id, evalue, score, 
                    identities, f"{identities_percent:.2f}%", positives, f"{positives_percent:.2f}%", gaps, f"{gaps_percent:.2f}%"
                ])
    return hits_data

# List to store parsed data
parsed_data = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"): 
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow([
        'Accession ID', 'Hit ID', 'Hit Number', 'Sequence Length', 'Species ID', 'Evalue', 'Score', 
        'Identities', 'Identities (%)', 'Positives', 'Positives (%)', 'Gaps', 'Gaps (%)'
    ])
    # Write parsed data
    writer.writerows(parsed_data)

print("CSV file created successfully")
# Out:
# CSV file created successfully

# %% [markdown]
# ### Combine Hits Data from Viruses, Bacteria and Archaea

# %%
import pandas as pd
import re

# Define the file paths
bacterial_blast_file = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv"
viral_csv_file = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/viral_hits.csv"
output_csv_file = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/bac_vs_vir_hits.csv"

# Function to clean accession IDs
def clean_accession_id(accession_id):
    return re.sub(r'\s+', '', str(accession_id)).upper()

# Function to extract accession IDs from a CSV file
def extract_accession_ids_from_csv(csv_file):
    df = pd.read_csv(csv_file, encoding='utf-8')
    return sorted(set(df['Accession ID'].apply(clean_accession_id)))

# Extract and sort accession IDs from the bacterial and viral CSV files
bacterial_accession_ids = extract_accession_ids_from_csv(bacterial_blast_file)
viral_accession_ids = extract_accession_ids_from_csv(viral_csv_file)

# Create a DataFrame with two columns: "viral hits" and "bacterial hits"
max_length = max(len(bacterial_accession_ids), len(viral_accession_ids))
bacterial_accession_ids += [""] * (max_length - len(bacterial_accession_ids)) 
viral_accession_ids += [""] * (max_length - len(viral_accession_ids))  

data = {
    'viral hits': viral_accession_ids,
    'bacterial hits': bacterial_accession_ids
}

df = pd.DataFrame(data)

# Save the DataFrame to a new CSV file
df.to_csv(output_csv_file, index=False)

print(f"CSV file with viral and bacterial hits has been saved to {output_csv_file}")
# Out:
# CSV file with viral and bacterial hits has been saved to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/bac_vs_vir_hits.csv

# %% [markdown]
# ### Compare Hits From Viral and Bacterial Search

# %%
import os
import pandas as pd
import shutil

# Define file paths and directories
csv_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/bac_vs_vir_hits.csv"
source_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq"
destination_directory = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_archaeal_seq"
# Ensure the destination directory exists
os.makedirs(destination_directory, exist_ok=True)

# Read the CSV file to get the Accession IDs from the "bacterial hits" column
df = pd.read_csv(csv_file_path)
bacterial_hits = df['bacterial hits'].dropna().unique()

# Function to check if a file has a matching Accession ID
def has_matching_accession_id(file_name, accession_ids):
    # Extract the Accession ID from the file name
    accession_id = os.path.splitext(file_name)[0]
    return accession_id in accession_ids

# Counter to keep track of the number of files copied
num_files_copied = 0

# Scan the source directory for matching fasta files and copy them
for file_name in os.listdir(source_directory):
    if file_name.endswith(".fasta") and has_matching_accession_id(file_name, bacterial_hits):
        source_file_path = os.path.join(source_directory, file_name)
        destination_file_path = os.path.join(destination_directory, file_name)
        shutil.copy2(source_file_path, destination_file_path)
        num_files_copied += 1
        print(f"Copied: {file_name}")

print(f"Total files copied: {num_files_copied}")

# %% [markdown]
# #

# %% [markdown]
# # 3.0 Run Blast on Processed Sequences

# %% [markdown]
# ### 3.1 Create working Directory

# %%
# !mkdir /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs

# %% [markdown]
# ### 3.2 Pull Fasta's from Archaeal processed sequences Text file

# %%
import os

# Input file path
file_path = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_archaeal_blasts.txt"
# Output directory path
output_dir = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs"

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Function to extract accession ID from header line
def extract_accession_id(header):
    parts = header.split('|')
    if len(parts) > 1:
        return parts[1].strip()
    return None

# Read the input file and process
with open(file_path, 'r') as infile:
    current_file = None
    current_file_path = None
    
    for line in infile:
        if line.startswith('>'):
            # Close the previous file if it was open
            if current_file:
                current_file.close()
            
            # Extract accession ID and create a new file
            accession_id = extract_accession_id(line)
            if accession_id:
                current_file_path = os.path.join(output_dir, f"{accession_id}.fasta")
                current_file = open(current_file_path, 'w')
        
        # Write the current line to the current file
        if current_file:
            current_file.write(line)
    
    # Close the last file if it was open
    if current_file:
        current_file.close()

print("FASTA files have been successfully created.")
# Out:
# FASTA files have been successfully created.

# %% [markdown]
# ### 3.3 Run Blast on Archaeal Samples

# %%
# !mkdir  /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results

# %%
import subprocess
import os
import time
from datetime import datetime, timezone

# Path to the directory containing fasta files
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs"

# Directory to store blast results
blast_output_directory =  "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results"

# Create the blast output directory if it doesn't exist
os.makedirs(blast_output_directory, exist_ok=True)

# Record the start time of the entire process in GMT
start_time = datetime.now(timezone.utc)
print(f"Process started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')} GMT")

# Iterate through each fasta file in the directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):
        fasta_file = os.path.join(fasta_directory, filename)
        output_file = os.path.join(blast_output_directory, f"{os.path.splitext(filename)[0]}_blastp_results.txt")
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            print(f"Skipping {filename} as output file already exists.")
            continue
        
        # Construct the blastp command
        blastp_command = [
            "blastp",
            "-db",
            "nr",
            "-query",
            fasta_file,
            "-out",
            output_file,
            "-evalue",
            "0.06",
            "-remote",
            "-entrez_query",
            "archaea[orgn]"
        ]
        
        # Record start time for this file
        file_start_time = time.time()
        
        # Execute the blastp command
        print(f"Running blast search for {filename}...")
        try:
            result = subprocess.run(blastp_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
            result.check_returncode()  
            print(f"Blast search for {filename} completed successfully.")
        except subprocess.CalledProcessError as e:
            print(f"Blast search for {filename} failed with return code {e.returncode}.")
            print(f"Error: {e.stderr}")
        
        # Calculate elapsed time for this file
        file_elapsed_time = time.time() - file_start_time
        
        # Print filename and elapsed time
        print(f"Blast search for {filename} completed in {file_elapsed_time:.2f} seconds.")
        
        # Check if 30 minutes have elapsed since the start of the process
        if (datetime.now(timezone.utc) - start_time).seconds >= 1800:
            print(f"Process has been running for 30 minutes. Current time: {datetime.now(timezone.utc).strftime('%Y-%m-%d %H:%M:%S')} GMT")
            start_time = datetime.now(timezone.utc)  

print("Blastp searches completed for all fasta files.")

# %% [markdown]
# ## 4.0 Collate Processed Results

# %% [markdown]
# ### 4.1 Create Masterfile for Archaeal results

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results"

# Name of the master file
master_filename = "processed_archaeal_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/processed_archaeal_master_blaster.txt

# %% [markdown]
# ### 4.2 Count hits and Create csv

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/processed_archaeal_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line:  
                current_query_id = line.split("|")[1].strip()
            elif ">" in line:  
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

# Rank and print total hits
print("Ranked total hits for each accession ID:")
for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/processed_archaeal_master_blaster.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Query ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in query_hits.items():
            writer.writerow({'Query ID': query_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Ranked total hits for each accession ID:
# 1. Accession ID: Q02388, Total Hits: 250
# 2. Accession ID: P11802, Total Hits: 250
# 3. Accession ID: P09914, Total Hits: 250
# 4. Accession ID: P60484, Total Hits: 250
# 5. Accession ID: Q00535, Total Hits: 250
# 6. Accession ID: P06493, Total Hits: 250
# 7. Accession ID: Q9Y3Z3, Total Hits: 250
# 8. Accession ID: Q15303, Total Hits: 250
# 9. Accession ID: P19525, Total Hits: 250
# 10. Accession ID: P19838, Total Hits: 250
# 11. Accession ID: Q00534, Total Hits: 250
# 12. Accession ID: O95786, Total Hits: 250
# 13. Accession ID: P56199, Total Hits: 250
# 14. Accession ID: Q00526, Total Hits: 250
# 15. Accession ID: P24941, Total Hits: 250
# 16. Accession ID: P06396, Total Hits: 206
# 17. Accession ID: Q12965, Total Hits: 53
# 18. Accession ID: O43745, Total Hits: 35
# 19. Accession ID: O43808, Total Hits: 31
# 20. Accession ID: Q99653, Total Hits: 21
# 21. Accession ID: P55265, Total Hits: 19
# 22. Accession ID: P20592, Total Hits: 10
# 23. Accession ID: P20591, Total Hits: 10
# 24. Accession ID: P38398, Total Hits: 8
# 25. Accession ID: P19883, Total Hits: 8
# 26. Accession ID: Q9BTW9, Total Hits: 6
# 27. Accession ID: O00910, Total Hits: 4
# 28. Accession ID: P42224, Total Hits: 3
# 29. Accession ID: P40763, Total Hits: 3
# 30. Accession ID: Q14765, Total Hits: 3
# 31. Accession ID: P52630, Total Hits: 3
# 32. Accession ID: P42226, Total Hits: 3
# 33. Accession ID: P02533, Total Hits: 2
# 34. Accession ID: P04637, Total Hits: 1
# 35. Accession ID: P15502, Total Hits: 1
# 36. Accession ID: Q96BS2, Total Hits: 1
# 37. Accession ID: P13164, Total Hits: 1
# 38. Accession ID: Q92968, Total Hits: 1
# 39. Accession ID: P23142, Total Hits: 1
# 40. Accession ID: Q9Y5Y5, Total Hits: 1
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/processed_archaeal_master_blaster.csv'

# %% [markdown]
# ### 4.3 Create comprehensive processed csv

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/comp_archaeal_processed_results.csv"

# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Parse out required data from blast results
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        accession_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0 
        hit_id = None 
        species_id = None 
        seq_length = None  
        evalue = None 
        score = None  
        identities = None  
        positives = None  
        gaps = None  
        query_definition = None  
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1 
                hit_id = line.split(">")[1].split(" ")[0]
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
                query_definition = line  # Assuming entire line is query definition

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
            elif hit_id and "Expect =" in line:
                evalue = line.split("Expect = ")[1].split(",")[0].strip()
                score = line.split("Score = ")[1].split(" bits")[0].strip()
            elif hit_id and "Identities =" in line:
                identities_str = line.split("Identities = ")[1].split(",")[0].strip()
                identities = round(float(identities_str.split(" ")[0].split("/")[0]) / float(identities_str.split(" ")[0].split("/")[1]) * 100, 2)
                positives_str = line.split("Positives = ")[1].split(",")[0].strip()
                positives = positives_str.split(" ")[0]
                gaps_str = line.split("Gaps = ")[1].split(" ")[0].strip()
                gaps = gaps_str
                hits_data.append([
                    os.path.basename(file_path), accession_id, hit_number, hit_id, seq_length, species_id, 
                    query_definition, "N/A", score, evalue, identities, positives, gaps, "Query", "Subject", "Archaea"
                ])
    return hits_data

# List to store parsed data
parsed_data = []

# List to store excluded file names
excluded_files = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"): 
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))
    else:
        excluded_files.append(file_name)  

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow([
        "File Name", "Accession ID", "Hit Number", "Hit ID", "Hit Length", "Species", 
        "Query Definition", "Hsp Bit Score", "Hsp Score", "Hsp E-value", 
        "Identity", "Positives", "Gaps", "Hsp Qseq", "Hsp Hseq", "Database"
    ])
    # Write parsed data
    writer.writerows(parsed_data)

print(f"CSV file created successfully with {len(parsed_data)} entries.")

# Print excluded file names
if excluded_files:
    print("\nExcluded files:")
    for file_name in excluded_files:
        print(file_name)
else:
    print("\nNo files were excluded.")
# Out:
# CSV file created successfully with 10257 entries.
#
# Excluded files:
# processed_archaeal_master_blaster.txt
# .ipynb_checkpoints
# comp_archaeal_processed_results.csv
# processed_archaeal_master_blaster.csv
# archaeal_master_blaster.txt
# final_archaeal_processed_results.csv

# %% [markdown]
# ### 4.4 Add Protein Names

# %%
import csv

# Input and output file paths
input_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/protein_names.txt"
output_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/protein_names.csv"

# Initialize a dictionary to track seen combinations of protein type and accession ID
seen_combinations = {}

# Process the lines to split data and prepare for CSV writing
data = []
with open(input_file, 'r', encoding='utf-8') as txt_file:
    try:
        reader = csv.reader(txt_file, delimiter='\t')
        for line_data in reader:
            # Skip empty lines
            if not line_data or all(cell.strip() == '' for cell in line_data):
                continue
            
            # Ensure each line has enough cells to contain at least Protein Type and Accession ID
            if len(line_data) >= 2:
                protein_type = line_data[0].strip()
                accession_id = line_data[1].strip()
                if accession_id: 
                   
                    key = (protein_type, accession_id)
                    if key not in seen_combinations:
                        seen_combinations[key] = True
                        data.append(line_data)
    except UnicodeDecodeError:
        print(f"Error decoding line in file: {input_file}")
        

# Write the processed data to CSV file
with open(output_file, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(data)

print(f"Converted {input_file} to CSV format at {output_file}")
# Out:
# Converted /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/protein_names.txt to CSV format at /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/protein_names.csv

# %%
import csv

# Input file paths
comp_archaeal_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/comp_archaeal_processed_results.csv"
protein_names_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/protein_names.csv"
output_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/final_archaeal_processed_results.csv"

# Step 1: Load data from protein_names.csv into a dictionary
accession_info = {}
with open(protein_names_file, 'r', encoding='utf-8') as csv_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        accession_id = row['Accession ID'].strip()
        protein_type = row['Protein Type'].strip()
        protein_names = row['Protein Names'].strip()
        accession_info[accession_id] = {
            'ProteinType': protein_type,
            'ProteinNames': protein_names
        }

# Step 2: Merge data with comp_archaeal_processed_results.csv and add new columns
merged_data = []
with open(comp_archaeal_file, 'r', encoding='utf-8') as csv_file:
    reader = csv.reader(csv_file)
    header = next(reader)
    header.insert(1, 'Protein Type')
    header.insert(2, 'Protein Names')
    merged_data.append(header)

    for row in reader:
        accession_id = row[1].strip()

        if accession_id in accession_info:
            protein_type = accession_info[accession_id]['ProteinType']
            protein_names = accession_info[accession_id]['ProteinNames']
        else:
            protein_type = ''
            protein_names = ''

        row.insert(1, protein_type)
        row.insert(2, protein_names)
        merged_data.append(row)

# Step 3: Write merged data to final_archaeal_processed_results.csv
with open(output_file, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(merged_data)

print(f"Merged data from {comp_archaeal_file} and {protein_names_file} into {output_file}")
# Out:
# Merged data from /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/comp_archaeal_processed_results.csv and /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/protein_names.csv into /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/final_archaeal_processed_results.csv

# %%
import csv

# Input file paths
comp_archaeal_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/comp_archaeal_processed_results.csv"
protein_names_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/protein_names.csv"
output_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/final_archaeal_processed_results.csv"


# Function to print headers of a CSV file
def print_csv_headers(file_path):
    with open(file_path, 'r', encoding='utf-8') as csv_file:
        # Determine the delimiter (tab or comma) by checking the first line
        first_line = csv_file.readline()
        delimiter = '\t' if '\t' in first_line else ','
        
        # Reset file pointer to beginning
        csv_file.seek(0)
        
        reader = csv.reader(csv_file, delimiter=delimiter)
        header = next(reader)
        print(f"Headers for {file_path}:")
        print(header)
        print()

# Print headers for both files
print_csv_headers(comp_archaeal_file)
print_csv_headers(protein_names_file)
print_csv_headers(output_file)
# Out:
# Headers for /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/comp_archaeal_processed_results.csv:
# ['File Name', 'Accession ID', 'Hit Number', 'Hit ID', 'Hit Length', 'Species', 'Query Definition', 'Hsp Bit Score', 'Hsp Score', 'Hsp E-value', 'Identity', 'Positives', 'Gaps', 'Hsp Qseq', 'Hsp Hseq', 'Database']
#
# Headers for /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/protein_names.csv:
# ['Protein Type', 'Protein Names', 'Accession ID']
#
# Headers for /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/final_archaeal_processed_results.csv:
# ['File Name', 'Protein Type', 'Protein Names', 'Accession ID', 'Hit Number', 'Hit ID', 'Hit Length', 'Species', 'Query Definition', 'Hsp Bit Score', 'Hsp Score', 'Hsp E-value', 'Identity', 'Positives', 'Gaps', 'Hsp Qseq', 'Hsp Hseq', 'Database']

# %% [markdown]
# ### 4.5 Reorder Columns

# %%
import csv

# Input and output file paths
input_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/final_archaeal_processed_results.csv"
output_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/reordered_comp_archaeal_processed_results.csv"

# Define the desired column order
desired_order = ['Protein Type', 'Protein Names', 'File Name', 'Accession ID', 'Hit Number', 'Hit ID', 'Hit Length', 'Species', 'Query Definition', 'Hsp Bit Score', 'Hsp Score', 'Hsp E-value', 'Identity', 'Positives', 'Gaps', 'Hsp Qseq', 'Hsp Hseq', 'Database']

# Read the original CSV file and reorder columns
with open(input_file, 'r', newline='', encoding='utf-8') as csv_file:
    reader = csv.reader(csv_file)
    header = next(reader)
    
    # Create a dictionary to map original indices to desired indices
    header_mapping = {header.index(col): idx for idx, col in enumerate(desired_order)}
    reordered_header = [header[idx] for idx in sorted(header_mapping.keys(), key=lambda x: header_mapping[x])]
    
    # Read and reorder rows
    rows = []
    for row in reader:
        reordered_row = [row[idx] for idx in sorted(header_mapping.keys(), key=lambda x: header_mapping[x])]
        rows.append(reordered_row)

# Write reordered data to a new CSV file
with open(output_file, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(reordered_header)
    writer.writerows(rows)

print(f"Reordered columns in {input_file} and saved to {output_file}")
# Out:
# Reordered columns in /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/final_archaeal_processed_results.csv and saved to /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/reordered_comp_archaeal_processed_results.csv

# %% [markdown]
# ## 5.0 Extract some key metrics from the Processed Search

# %% [markdown]
# ### 5.1 Print Queries which Produced hits

# %%
import csv

# Path to the CSV file
csv_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/reordered_comp_archaeal_processed_results.csv"
# Initialize a set to store unique Accession IDs
unique_accession_ids = set()

try:
    # Open and read the CSV file
    with open(csv_file_path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        # Loop through each row in the CSV file
        for row in csv_reader:
            # Extract the Accession ID and add it to the set
            accession_id = row['Accession ID']  # Replace 'Accession ID' with the actual column name if different
            unique_accession_ids.add(accession_id)
    
    # Print each unique Accession ID
    for accession_id in unique_accession_ids:
        print(accession_id)
    
    # Print the total number of unique Accession IDs
    print(f"Total number of unique Accession IDs: {len(unique_accession_ids)}")

except FileNotFoundError:
    print(f"Error: File '{csv_file_path}' not found.")
except KeyError:
    print("Error: 'Accession ID' column not found in the CSV file. Please check the column name.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# P60484
# Q12965
# P19883
# P02533
# P56199
# Q02388
# P11802
# P42226
# P55265
# P13164
# O43745
# P20591
# Q14765
# Q99653
# P40763
# P19525
# P24941
# Q9BTW9
# Q00534
# P38398
# Q00526
# Q9Y5Y5
# P06493
# P09914
# O43808
# P23142
# P06396
# Q15303
# P15502
# P19838
# Q9Y3Z3
# P52630
# Q96BS2
# P04637
# O95786
# P20592
# O00910
# P42224
# Q92968
# Q00535
# Total number of unique Accession IDs: 40

# %% [markdown]
# ### 5.2 Print the number of input files

# %%
import os

# Path to the directory
directory_path = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/"

# Initialize a counter for FASTA files
fasta_file_count = 0

# Iterate through the files in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".fasta") or file_name.endswith(".fa"):  
        fasta_file_count += 1

# Print the total number of FASTA files
print(f"Total number of FASTA files: {fasta_file_count}")
# Out:
# Total number of FASTA files: 52

# %% [markdown]
# #

# %% [markdown]
# ## 6.0 Perform species analysis

# %% [markdown]
# ### 6.1 Create directory

# %%
# !mkdir  "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/species"

# %% [markdown]
# ### 6.2 Create Unique list of species

# %%
! awk -F "," '{ print $8 }' /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/reordered_comp_archaeal_processed_results.csv | sort | uniq > /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/species/unique_archaea.txt

# %% [markdown]
# ### 6.3 Run Taxonkit on Unique Species

# %%
import subprocess

# Path to the unique-species.txt file
file_path = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/species/unique_archaea.txt"
# Path to the taxonkit binary
taxonkit_path = '/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit'

# Read the species names from the file
with open(file_path, 'r') as file:
    species_names = [line.strip() for line in file.readlines()]

# Define a function to apply the command to each species name
def process_species_name(species_name):
    # Construct the command
    cmd = f'echo "{species_name}" | {taxonkit_path} name2taxid | {taxonkit_path} reformat -I 2'
    # Run the command
    result = subprocess.run(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    # Debug: Print command and output
    print(f"Command: {cmd}")
    print(f"Stdout: {result.stdout.strip()}")
    print(f"Stderr: {result.stderr.strip()}")
    # Return the output
    return result.stdout.strip()

# Process each species name and store the results
results = {species: process_species_name(species) for species in species_names}

# Print the results
for species, output in results.items():
    print(f'{species}:\n{output}\n')

# Optionally, save the results to a new file
output_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/processed_seqs/processed_archaeal_results/species/processed_species.txt"
with open(output_file_path, 'w') as output_file:
    for species, output in results.items():
        output_file.write(f'{species}:\n{output}\n\n')
# Out:
# Command: echo "" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr:
# Command: echo "Acidianus brierleyi" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidianus brierleyi	41673	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Acidianus;Acidianus brierleyi
# Stderr:
# Command: echo "Acidianus infernus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidianus infernus	12915	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Acidianus;Acidianus infernus
# Stderr:
# Command: echo "Acidianus manzaensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidianus manzaensis	282676	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Acidianus;Acidianus manzaensis
# Stderr:
# Command: echo "Acidianus sp. HS-5" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidianus sp. HS-5	2886040	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Acidianus;Acidianus sp. HS-5
# Stderr:
# Command: echo "Acidianus sulfidivorans" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidianus sulfidivorans	312539	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Acidianus;Acidianus sulfidivorans
# Stderr:
# Command: echo "Acidilobus sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidilobus sp.	1872109	Archaea;Thermoproteota;Thermoprotei;Acidilobales;Acidilobaceae;Acidilobus;Acidilobus sp.
# Stderr:
# Command: echo "Acidilobus sp. 7A" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidilobus sp. 7A	1577685	Archaea;Thermoproteota;Thermoprotei;Acidilobales;Acidilobaceae;Acidilobus;Acidilobus sp. 7A
# Stderr:
# Command: echo "Aciduliprofundum sp. MAR08-339" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aciduliprofundum sp. MAR08-339	673860	Archaea;Candidatus Thermoplasmatota;;;;Candidatus Aciduliprofundum;Aciduliprofundum sp. MAR08-339
# Stderr:
# Command: echo "Aeropyrum pernix" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeropyrum pernix	56636	Archaea;Thermoproteota;Thermoprotei;Desulfurococcales;Desulfurococcaceae;Aeropyrum;Aeropyrum pernix
# Stderr:
# Command: echo "Aigarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:31:10.151 [ERRO] invalid TaxId:
# Command: echo "Aigarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aigarchaeota archaeon	2528703	Archaea;Nitrososphaerota;;;;;Aigarchaeota archaeon
# Stderr:
# Command: echo "ANME-1 cluster archaeon AG-394-G06" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: ANME-1 cluster archaeon AG-394-G06	2081360	Archaea;Euryarchaeota;Methanomicrobia;Methanophagales;;;ANME-1 cluster archaeon AG-394-G06
# Stderr:
# Command: echo "ANME-2 cluster" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: ANME-2 cluster	588816	Archaea;Euryarchaeota;Methanomicrobia;Methanosarcinales;;;
# Stderr:
# Command: echo "ANME-2 cluster archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: ANME-2 cluster archaeon	2056317	Archaea;Euryarchaeota;Methanomicrobia;Methanosarcinales;;;ANME-2 cluster archaeon
# Stderr:
# Command: echo "Archaeoglobaceae archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Archaeoglobaceae archaeon	2511821	Archaea;Euryarchaeota;Archaeoglobi;Archaeoglobales;Archaeoglobaceae;;Archaeoglobaceae archaeon
# Stderr:
# Command: echo "Archaeoglobales archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Archaeoglobales archaeon	2250258	Archaea;Euryarchaeota;Archaeoglobi;Archaeoglobales;;;Archaeoglobales archaeon
# Stderr:
# Command: echo "Archaeoglobus sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Archaeoglobus sp.	1872626	Archaea;Euryarchaeota;Archaeoglobi;Archaeoglobales;Archaeoglobaceae;Archaeoglobus;Archaeoglobus sp.
# Stderr:
# Command: echo "archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: archaeon	1906665	Archaea;;;;;;archaeon
# Stderr:
# Command: echo "archaeon 13_1_40CM_4_53_4" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: archaeon 13_1_40CM_4_53_4	1805017	Archaea;;;;;;archaeon 13_1_40CM_4_53_4
# Stderr:
# Command: echo "archaeon 13_2_20CM_2_53_6" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: archaeon 13_2_20CM_2_53_6	1805020	Archaea;;;;;;archaeon 13_2_20CM_2_53_6
# Stderr:
# Command: echo "archaeon GW2011_AR1" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: archaeon GW2011_AR1	1579364	Archaea;;;;;;archaeon GW2011_AR1
# Stderr:
# Command: echo "archaeon HR01" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: archaeon HR01	2035437	Archaea;;;;;;archaeon HR01
# Stderr:
# Command: echo "archaeon HR04" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: archaeon HR04	2035440	Archaea;;;;;;archaeon HR04
# Stderr:
# Command: echo "Asgard group archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Asgard group archaeon	2591838	Archaea;;;;;;Asgard group archaeon
# Stderr:
# Command: echo "Caldivirga sp. MU80" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Caldivirga sp. MU80	1650354	Archaea;Thermoproteota;Thermoprotei;Thermoproteales;Thermoproteaceae;Caldivirga;Caldivirga sp. MU80
# Stderr:
# Command: echo "Candidatus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:31:54.251 [ERRO] invalid TaxId:
# Command: echo "Candidatus Aciduliprofundum boonei" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Aciduliprofundum boonei	379547	Archaea;Candidatus Thermoplasmatota;;;;Candidatus Aciduliprofundum;Candidatus Aciduliprofundum boonei
# Stderr:
# Command: echo "Candidatus Aenigmarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:31:59.813 [ERRO] invalid TaxId:
# Command: echo "Candidatus Aenigmarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Aenigmarchaeota archaeon	3121606	Archaea;Candidatus Aenigmatarchaeota;;;;;Candidatus Aenigmatarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Aenigmatarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Aenigmatarchaeota	743724	Archaea;Candidatus Aenigmatarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus ainarchaeum sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus ainarchaeum sp.	3018264	Archaea;Candidatus Diapherotrites;;;;Candidatus Iainarchaeum;Candidatus ainarchaeum sp.
# Stderr:
# Command: echo "Candidatus Alkanophaga volatiphilum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Alkanophaga volatiphilum	2971472	Archaea;Euryarchaeota;Methanomicrobia;Candidatus Alkanophagales;;Candidatus Alkanophaga;Candidatus Alkanophaga volatiphilum
# Stderr:
# Command: echo "Candidatus Altarchaeum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Altarchaeum	1803512	Archaea;Candidatus Altarchaeota;Candidatus Altiarchaeia;Candidatus Altarchaeales;Candidatus Altarchaeaceae;Candidatus Altarchaeum;
# Stderr:
# Command: echo "Candidatus Altiarchaeales" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:32:15.446 [ERRO] invalid TaxId:
# Command: echo "Candidatus Altiarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:32:18.345 [ERRO] invalid TaxId:
# Command: echo "Candidatus Argoarchaeum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Argoarchaeum	2608792	Archaea;Euryarchaeota;Methanomicrobia;Methanosarcinales;;Candidatus Argoarchaeum;
# Stderr:
# Command: echo "Candidatus Bathyarchaeia" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Bathyarchaeia	3037982	Archaea;Candidatus Bathyarchaeota;Candidatus Bathyarchaeia;;;;
# Stderr:
# Command: echo "Candidatus Bathyarchaeia archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Bathyarchaeia archaeon	3045160	Archaea;Candidatus Bathyarchaeota;Candidatus Bathyarchaeia;;;;Candidatus Bathyarchaeia archaeon
# Stderr:
# Command: echo "Candidatus Bathyarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Bathyarchaeota	928852	Archaea;Candidatus Bathyarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Bathyarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Bathyarchaeota archaeon	2026714	Archaea;Candidatus Bathyarchaeota;;;;;Candidatus Bathyarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Bathyarchaeota archaeon ex4484_205" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Bathyarchaeota archaeon ex4484_205	2012510	Archaea;Candidatus Bathyarchaeota;;;;;Candidatus Bathyarchaeota archaeon ex4484_205
# Stderr:
# Command: echo "Candidatus Bathycorpusculum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Bathycorpusculum	3139623	Archaea;Candidatus Bathyarchaeota;Candidatus Bathyarchaeia;Candidatus Bathyarchaeales;Candidatus Bathycorpusculaceae;Candidatus Bathycorpusculum;
# Stderr:
# Command: echo "Candidatus Bathycorpusculum sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Bathycorpusculum sp.	2994959	Archaea;Candidatus Bathyarchaeota;Candidatus Bathyarchaeia;Candidatus Bathyarchaeales;Candidatus Bathycorpusculaceae;Candidatus Bathycorpusculum;Candidatus Bathycorpusculum sp.
# Stderr:
# Command: echo "Candidatus Bilamarchaeum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Bilamarchaeum	2885758	Archaea;Candidatus Micrarchaeota;Candidatus Micrarchaeia;Candidatus Anstonellales;Candidatus Bilamarchaeaceae;Candidatus Bilamarchaeum;
# Stderr:
# Command: echo "Candidatus Bilamarchaeum sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Bilamarchaeum sp.	3070761	Archaea;Candidatus Micrarchaeota;Candidatus Micrarchaeia;Candidatus Anstonellales;Candidatus Bilamarchaeaceae;Candidatus Bilamarchaeum;Candidatus Bilamarchaeum sp.
# Stderr:
# Command: echo "Candidatus Borrarchaeum sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Borrarchaeum sp.	2846742	Archaea;Candidatus Borrarchaeota;Candidatus Borrarchaeia;Candidatus Borrarchaeales;Candidatus Borrarchaeaceae;Candidatus Borrarchaeum;Candidatus Borrarchaeum sp.
# Stderr:
# Command: echo "Candidatus Calditenuaceae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Calditenuaceae	3079257	Archaea;Nitrososphaerota;;Candidatus Caldarchaeales;Candidatus Calditenuaceae;;
# Stderr:
# Command: echo "Candidatus Calypsonella sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:32:53.669 [ERRO] invalid TaxId:
# Command: echo "Candidatus Culexmicrobium thermophilum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Culexmicrobium thermophilum	2928967	Archaea;Candidatus Culexarchaeota;Candidatus Culexarchaeia;Candidatus Culexarchaeles;Candidatus Culexmicrobiaceae;Candidatus Culexmicrobium;Candidatus Culexmicrobium thermophilum
# Stderr:
# Command: echo "Candidatus Diapherotrites archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Diapherotrites archaeon	2026736	Archaea;Candidatus Diapherotrites;;;;;Candidatus Diapherotrites archaeon
# Stderr:
# Command: echo "Candidatus Freyarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Freyarchaeota	2827219	Archaea;Candidatus Freyarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Freyarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Freyarchaeota archaeon	2830916	Archaea;Candidatus Freyarchaeota;;;;;Candidatus Freyarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Freyrarchaeum guaymaensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Freyrarchaeum guaymaensis	3036978	Archaea;Candidatus Freyarchaeota;Candidatus Freyrarchaeia;Candidatus Freyrarchaeales;Candidatus Freyrarchaeaceae;Candidatus Freyrarchaeum;Candidatus Freyrarchaeum guaymaensis
# Stderr:
# Command: echo "Candidatus Gerdarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Gerdarchaeota	2795490	Archaea;Candidatus Gerdarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Harpocratesius" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Harpocratesius	3049169	Archaea;Candidatus Lokiarchaeota;Candidatus Lokiarchaeia;Candidatus Prometheoarchaeales;Candidatus Prometheoarchaeaceae;Candidatus Harpocratesius;
# Stderr:
# Command: echo "Candidatus Harpocratesius repetitus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Harpocratesius repetitus	3049170	Archaea;Candidatus Lokiarchaeota;Candidatus Lokiarchaeia;Candidatus Prometheoarchaeales;Candidatus Prometheoarchaeaceae;Candidatus Harpocratesius;Candidatus Harpocratesius repetitus
# Stderr:
# Command: echo "Candidatus Heimdallarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Heimdallarchaeota	1936272	Archaea;Candidatus Heimdallarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Heimdallarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Heimdallarchaeota archaeon	2026747	Archaea;Candidatus Heimdallarchaeota;;;;;Candidatus Heimdallarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Heimdallarchaeum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Heimdallarchaeum	3053649	Archaea;Candidatus Heimdallarchaeota;;;;Candidatus Heimdallarchaeum;
# Stderr:
# Command: echo "Candidatus Helarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Helarchaeota	2572044	Archaea;Candidatus Helarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Helarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Helarchaeota archaeon	2719382	Archaea;Candidatus Helarchaeota;;;;;Candidatus Helarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Hermodarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Hermodarchaeota archaeon	2799008	Archaea;Candidatus Hermodarchaeota;;;;;Candidatus Hermodarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Hydrothermarchaeaceae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Hydrothermarchaeaceae	3072871	Archaea;Candidatus Hydrothermarchaeota;Candidatus Hydrothermarchaeia;Candidatus Hydrothermarchaeales;Candidatus Hydrothermarchaeaceae;;
# Stderr:
# Command: echo "Candidatus Hydrothermarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Hydrothermarchaeota	1935019	Archaea;Candidatus Hydrothermarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Jordarchaeia archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Jordarchaeia archaeon	3067279	Archaea;;Candidatus Jordarchaeia;;;;Candidatus Jordarchaeia archaeon
# Stderr:
# Command: echo "Candidatus Korarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Korarchaeota	51967	Archaea;Candidatus Korarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Korarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Korarchaeota archaeon	2056630	Archaea;Candidatus Korarchaeota;;;;;Candidatus Korarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Korarchaeum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Korarchaeum	498845	Archaea;Candidatus Korarchaeota;;;;Candidatus Korarchaeum;
# Stderr:
# Command: echo "Candidatus Lokiarchaeia" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Lokiarchaeia	3049162	Archaea;Candidatus Lokiarchaeota;Candidatus Lokiarchaeia;;;;
# Stderr:
# Command: echo "Candidatus Lokiarchaeia archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Lokiarchaeia archaeon	3067280	Archaea;Candidatus Lokiarchaeota;Candidatus Lokiarchaeia;;;;Candidatus Lokiarchaeia archaeon
# Stderr:
# Command: echo "Candidatus Lokiarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Lokiarchaeota	1655434	Archaea;Candidatus Lokiarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Lokiarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Lokiarchaeota archaeon	2053489	Archaea;Candidatus Lokiarchaeota;;;;;Candidatus Lokiarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Lokiarchaeum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Lokiarchaeum	1655637	Archaea;Candidatus Lokiarchaeota;;;;Candidatus Lokiarchaeum;
# Stderr:
# Command: echo "Candidatus Lokiarchaeum ossiferum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Lokiarchaeum ossiferum	2951803	Archaea;Candidatus Lokiarchaeota;;;;Candidatus Lokiarchaeum;Candidatus Lokiarchaeum ossiferum
# Stderr:
# Command: echo "Candidatus Marsarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Marsarchaeota	1978152	Archaea;Candidatus Marsarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Methanocrinis alkalitolerans" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanocrinis alkalitolerans	3033395	Archaea;Euryarchaeota;Methanomicrobia;Methanotrichales;Methanotrichaceae;Methanocrinis;Candidatus Methanocrinis alkalitolerans
# Stderr:
# Command: echo "Candidatus Methanodesulfokores" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanodesulfokores	2545700	Archaea;Candidatus Korarchaeota;;;;Candidatus Methanodesulfokores;
# Stderr:
# Command: echo "Candidatus Methanofastidiosia" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanofastidiosia	1705400	Archaea;Euryarchaeota;Candidatus Methanofastidiosia;;;;
# Stderr:
# Command: echo "Candidatus Methanoliparum sp. LAM-1" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanoliparum sp. LAM-1	2874846	Archaea;Euryarchaeota;Candidatus Methanoliparia;Candidatus Methanoliparales;Candidatus Methanoliparaceae;Candidatus Methanoliparum;Candidatus Methanoliparum sp. LAM-1
# Stderr:
# Command: echo "Candidatus Methanoliparum thermophilum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanoliparum thermophilum	2491083	Archaea;Euryarchaeota;Candidatus Methanoliparia;Candidatus Methanoliparales;Candidatus Methanoliparaceae;Candidatus Methanoliparum;Candidatus Methanoliparum thermophilum
# Stderr:
# Command: echo "Candidatus Methanomassiliicoccus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:34:22.177 [ERRO] invalid TaxId:
# Command: echo "Candidatus Methanomethylophilaceae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanomethylophilaceae	2517203	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;Methanomassiliicoccales;Methanomethylophilaceae;;
# Stderr:
# Command: echo "Candidatus Methanoperedenaceae archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanoperedenaceae archaeon	2072416	Archaea;Euryarchaeota;Methanomicrobia;Methanosarcinales;Candidatus Methanoperedenaceae;;Candidatus Methanoperedenaceae archaeon
# Stderr:
# Command: echo "Candidatus Methanoperedens" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanoperedens	1392997	Archaea;Euryarchaeota;Methanomicrobia;Methanosarcinales;Candidatus Methanoperedenaceae;Candidatus Methanoperedens;
# Stderr:
# Command: echo "Candidatus Methanoperedens sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanoperedens sp.	2032688	Archaea;Euryarchaeota;Methanomicrobia;Methanosarcinales;Candidatus Methanoperedenaceae;Candidatus Methanoperedens;Candidatus Methanoperedens sp.
# Stderr:
# Command: echo "Candidatus Methanoperedens sp. BLZ2" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanoperedens sp. BLZ2	2035255	Archaea;Euryarchaeota;Methanomicrobia;Methanosarcinales;Candidatus Methanoperedenaceae;Candidatus Methanoperedens;Candidatus Methanoperedens sp. BLZ2
# Stderr:
# Command: echo "Candidatus Methanoplasma" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Methanoplasma	1607807	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;Methanomassiliicoccales;Methanomassiliicoccaceae;Candidatus Methanoplasma;
# Stderr:
# Command: echo "Candidatus Methylarchaceae archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:34:40.692 [ERRO] invalid TaxId:
# Command: echo "Candidatus Micrarchaeaceae archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Micrarchaeaceae archaeon	2953041	Archaea;Candidatus Micrarchaeota;Candidatus Micrarchaeia;Candidatus Micrarchaeales;Candidatus Micrarchaeaceae;;Candidatus Micrarchaeaceae archaeon
# Stderr:
# Command: echo "Candidatus Micrarchaeota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Micrarchaeota	1801631	Archaea;Candidatus Micrarchaeota;;;;;
# Stderr:
# Command: echo "Candidatus Micrarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Micrarchaeota archaeon	2250274	Archaea;Candidatus Micrarchaeota;;;;;Candidatus Micrarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Nanoarchaeia" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nanoarchaeia	2885752	Archaea;Nanoarchaeota;Candidatus Nanoarchaeia;;;;
# Stderr:
# Command: echo "Candidatus Nanoarchaeia archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nanoarchaeia archaeon	2910166	Archaea;Nanoarchaeota;Candidatus Nanoarchaeia;;;;Candidatus Nanoarchaeia archaeon
# Stderr:
# Command: echo "Candidatus Nanohalarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nanohalarchaeota archaeon	2099673	Archaea;Candidatus Nanohalarchaeota;;;;;Candidatus Nanohalarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Nanopusillus sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nanopusillus sp.	2268188	Archaea;Nanoarchaeota;Candidatus Nanoarchaeia;Nanoarchaeales;Nanopusillaceae;Candidatus Nanopusillus;Candidatus Nanopusillus sp.
# Stderr:
# Command: echo "Candidatus Nitrosocosmicus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosocosmicus	1826864	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrososphaerales;Nitrososphaeraceae;Candidatus Nitrosocosmicus;
# Stderr:
# Command: echo "Candidatus Nitrosocosmicus sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosocosmicus sp.	2109671	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrososphaerales;Nitrososphaeraceae;Candidatus Nitrosocosmicus;Candidatus Nitrosocosmicus sp.
# Stderr:
# Command: echo "Candidatus Nitrosomarinus catalina" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosomarinus catalina	1898749	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrosopumilales;Nitrosopumilaceae;Candidatus Nitrosomarinus;Candidatus Nitrosomarinus catalina
# Stderr:
# Command: echo "Candidatus Nitrosomarinus sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosomarinus sp.	2478979	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrosopumilales;Nitrosopumilaceae;Candidatus Nitrosomarinus;Candidatus Nitrosomarinus sp.
# Stderr:
# Command: echo "Candidatus Nitrosopelagicus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosopelagicus	1593364	Archaea;Nitrososphaerota;;;;Candidatus Nitrosopelagicus;
# Stderr:
# Command: echo "Candidatus Nitrosopelagicus sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosopelagicus sp.	2026808	Archaea;Nitrososphaerota;;;;Candidatus Nitrosopelagicus;Candidatus Nitrosopelagicus sp.
# Stderr:
# Command: echo "Candidatus Nitrosopolaris" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosopolaris	2959592	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrososphaerales;Nitrososphaeraceae;Candidatus Nitrosopolaris;
# Stderr:
# Command: echo "Candidatus Nitrosopolaris sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosopolaris sp.	3069383	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrososphaerales;Nitrososphaeraceae;Candidatus Nitrosopolaris;Candidatus Nitrosopolaris sp.
# Stderr:
# Command: echo "Candidatus Nitrosopumilus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:35:25.865 [ERRO] invalid TaxId:
# Command: echo "Candidatus Nitrosopumilus limneticus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosopumilus limneticus	2929773	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrosopumilales;Nitrosopumilaceae;Nitrosopumilus;Candidatus Nitrosopumilus limneticus
# Stderr:
# Command: echo "Candidatus Nitrosopumilus salaria" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosopumilus salaria	1170320	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrosopumilales;Nitrosopumilaceae;Nitrosopumilus;Candidatus Nitrosopumilus salaria
# Stderr:
# Command: echo "Candidatus Nitrosopumilus sediminis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosopumilus sediminis	1229909	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrosopumilales;Nitrosopumilaceae;Nitrosopumilus;Candidatus Nitrosopumilus sediminis
# Stderr:
# Command: echo "Candidatus Nitrosopumilus sp. SW" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosopumilus sp. SW	2508726	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrosopumilales;Nitrosopumilaceae;Nitrosopumilus;Candidatus Nitrosopumilus sp. SW
# Stderr:
# Command: echo "Candidatus Nitrososphaera" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrososphaera	497726	Archaea;Nitrososphaerota;Nitrososphaeria;Nitrososphaerales;Nitrososphaeraceae;Nitrososphaera;
# Stderr:
# Command: echo "Candidatus Nitrosotalea bavarica" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosotalea bavarica	1903277	Archaea;Nitrososphaerota;;;;Candidatus Nitrosotalea;Candidatus Nitrosotalea bavarica
# Stderr:
# Command: echo "Candidatus Nitrosotalea devanaterra" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosotalea devanaterra	1078905	Archaea;Nitrososphaerota;;;;Candidatus Nitrosotalea;Candidatus Nitrosotalea devanaterra
# Stderr:
# Command: echo "Candidatus Nitrosotalea sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosotalea sp.	2833567	Archaea;Nitrososphaerota;;;;Candidatus Nitrosotalea;Candidatus Nitrosotalea sp.
# Stderr:
# Command: echo "Candidatus Nitrosotenuis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosotenuis	1825023	Archaea;Nitrososphaerota;;;;Candidatus Nitrosotenuis;
# Stderr:
# Command: echo "Candidatus Nitrosotenuis aquarius" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosotenuis aquarius	1846278	Archaea;Nitrososphaerota;;;;Candidatus Nitrosotenuis;Candidatus Nitrosotenuis aquarius
# Stderr:
# Command: echo "Candidatus Nitrosotenuis chungbukensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosotenuis chungbukensis	1353246	Archaea;Nitrososphaerota;;;;Candidatus Nitrosotenuis;Candidatus Nitrosotenuis chungbukensis
# Stderr:
# Command: echo "Candidatus Nitrosotenuis cloacae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosotenuis cloacae	1603555	Archaea;Nitrososphaerota;;;;Candidatus Nitrosotenuis;Candidatus Nitrosotenuis cloacae
# Stderr:
# Command: echo "Candidatus Nitrosotenuis sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosotenuis sp.	2507556	Archaea;Nitrososphaerota;;;;Candidatus Nitrosotenuis;Candidatus Nitrosotenuis sp.
# Stderr:
# Command: echo "Candidatus Nitrosotenuis sp. DW1" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Nitrosotenuis sp. DW1	2259672	Archaea;Nitrososphaerota;;;;Candidatus Nitrosotenuis;Candidatus Nitrosotenuis sp. DW1
# Stderr:
# Command: echo "Candidatus Njordarchaeota archaeon" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Njordarchaeota archaeon	3036966	Archaea;Candidatus Njordarchaeota;;;;;Candidatus Njordarchaeota archaeon
# Stderr:
# Command: echo "Candidatus Njordarchaeum guaymaensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Candidatus Njordarchaeum guaymaensis	3036989	Archaea;Candidatus Njordarchaeota;Candidatus Njordarchaeia;Candidatus Njordarchaeales;Candidatus Njordarchaeaceae;Candidatus Njordarchaeum;Candidatus Njordarchaeum guaymaensis
# Stderr:
# ...
#
# Picrophilus oshimae DSM 9789:
# Picrophilus oshimae DSM 9789	1122961	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;Thermoplasmatales;Picrophilaceae;Picrophilus;Picrophilus oshimae
#
# Poseidonia sp.:
# Poseidonia sp.	2666344	Archaea;Candidatus Thermoplasmatota;Candidatus Poseidoniia;Candidatus Poseidoniales;Candidatus Poseidoniaceae;Candidatus Poseidonia;Poseidonia sp.
#
# protein ADP-ribosylglutamate:
#
#
# Pyrobaculum aerophilum:
# Pyrobaculum aerophilum	13773	Archaea;Thermoproteota;Thermoprotei;Thermoproteales;Thermoproteaceae;Pyrobaculum;Pyrobaculum aerophilum
#
# Pyrobaculum sp.:
# Pyrobaculum sp.	2004705	Archaea;Thermoproteota;Thermoprotei;Thermoproteales;Thermoproteaceae;Pyrobaculum;Pyrobaculum sp.
#
# Pyrobaculum sp. JCHS_4:
# Pyrobaculum sp. JCHS_4	1714260	Archaea;Thermoproteota;Thermoprotei;Thermoproteales;Thermoproteaceae;Pyrobaculum;Pyrobaculum sp. JCHS_4
#
# Pyrobaculum sp. WP30:
# Pyrobaculum sp. WP30	1227555	Archaea;Thermoproteota;Thermoprotei;Thermoproteales;Thermoproteaceae;Pyrobaculum;Pyrobaculum sp. WP30
#
# Pyrococcus:
# Pyrococcus	2260	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Pyrococcus;
#
# Pyrococcus abyssi:
# Pyrococcus abyssi	29292	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Pyrococcus;Pyrococcus abyssi
#
# Pyrococcus furiosus:
# Pyrococcus furiosus	2261	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Pyrococcus;Pyrococcus furiosus
#
# Pyrococcus furiosus DSM 3638:
# Pyrococcus furiosus DSM 3638	186497	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Pyrococcus;Pyrococcus furiosus
#
# Pyrococcus horikoshii:
# Pyrococcus horikoshii	53953	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Pyrococcus;Pyrococcus horikoshii
#
# Pyrococcus sp. ST04:
# Pyrococcus sp. ST04	1183377	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Pyrococcus;Pyrococcus sp. ST04
#
# Salinibaculum sp. KK48:
# Salinibaculum sp. KK48	3058903	Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Haloarculaceae;Salinibaculum;Salinibaculum sp. KK48
#
# Salinigranum marinum:
# Salinigranum marinum	1515595	Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Haloferacaceae;Salinigranum;Salinigranum marinum
#
# Salinirubellus:
# Salinirubellus	2162630	Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Haloarculaceae;Salinirubellus;
#
# Salinirubellus salinus:
# Salinirubellus salinus	1364945	Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Haloarculaceae;Salinirubellus;Salinirubellus salinus
#
# Salinirubellus sp. SYNS196:
# Salinirubellus sp. SYNS196	3131999	Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Haloarculaceae;Salinirubellus;Salinirubellus sp. SYNS196
#
# Species:
#
#
# Staphylothermus hellenicus:
# Staphylothermus hellenicus	84599	Archaea;Thermoproteota;Thermoprotei;Desulfurococcales;Desulfurococcaceae;Staphylothermus;Staphylothermus hellenicus
#
# Stygiolobus sp. CP850M:
# Stygiolobus sp. CP850M	3133134	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Stygiolobus;Stygiolobus sp. CP850M
#
# Stygiolobus sp. CP8521M:
# Stygiolobus sp. CP8521M	3133136	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Stygiolobus;Stygiolobus sp. CP8521M
#
# Stygiolobus sp. CP859M:
# Stygiolobus sp. CP859M	3133135	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Stygiolobus;Stygiolobus sp. CP859M
#
# Sulfolobales archaeon:
# Sulfolobales archaeon	2268200	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;;;Sulfolobales archaeon
#
# Sulfolobus acidocaldarius:
# Sulfolobus acidocaldarius	2285	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Sulfolobus;Sulfolobus acidocaldarius
#
# Sulfolobus acidocaldarius DSM 639:
# Sulfolobus acidocaldarius DSM 639	330779	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Sulfolobus;Sulfolobus acidocaldarius
#
# Sulfolobus acidocaldarius SUSAZ:
# Sulfolobus acidocaldarius SUSAZ	1435377	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Sulfolobus;Sulfolobus acidocaldarius
#
# Sulfolobus islandicus:
# Sulfolobus islandicus	43080	Archaea;Thermoproteota;Thermoprotei;Sulfolobales;Sulfolobaceae;Sulfolobus;Sulfolobus islandicus
#
# Sulfolobus sp. SCGC:
#
#
# TACK group archaeon:
# TACK group archaeon	2259140	Archaea;;;;;;TACK group archaeon
#
# Thaumarchaeota:
# Thaumarchaeota	651137	Archaea;Nitrososphaerota;;;;;
#
# Thaumarchaeota archaeon:
#
#
# Thaumarchaeota archaeon 13_1_40CM_4_48_7:
# Thaumarchaeota archaeon 13_1_40CM_4_48_7	1805396	Archaea;Nitrososphaerota;;;;;Thaumarchaeota archaeon 13_1_40CM_4_48_7
#
# Theionarchaea archaeon:
# Theionarchaea archaeon	2747605	Archaea;Euryarchaeota;Theionarchaea;;;;Theionarchaea archaeon
#
# Thermocladium modestius:
# Thermocladium modestius	62609	Archaea;Thermoproteota;Thermoprotei;Thermoproteales;Thermoproteaceae;Thermocladium;Thermocladium modestius
#
# Thermococcaceae:
# Thermococcaceae	2259	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;;
#
# Thermococcaceae archaeon:
# Thermococcaceae archaeon	2666349	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;;Thermococcaceae archaeon
#
# Thermococcales:
# Thermococcales	2258	Archaea;Euryarchaeota;Thermococci;Thermococcales;;;
#
# Thermococci archaeon:
# Thermococci archaeon	2250254	Archaea;Euryarchaeota;Thermococci;;;;Thermococci archaeon
#
# Thermococcus:
# Thermococcus	2263	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;
#
# Thermococcus aciditolerans:
# Thermococcus aciditolerans	2598455	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus aciditolerans
#
# Thermococcus aggregans:
# Thermococcus aggregans	110163	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus aggregans
#
# Thermococcus alcaliphilus:
# Thermococcus alcaliphilus	139207	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus alcaliphilus
#
# Thermococcus argininiproducens:
# Thermococcus argininiproducens	2866384	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus argininiproducens
#
# Thermococcus barophilus:
# Thermococcus barophilus	55802	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus barophilus
#
# Thermococcus barophilus MP:
# Thermococcus barophilus MP	391623	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus barophilus
#
# Thermococcus bergensis:
# Thermococcus bergensis	2689387	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus bergensis
#
# Thermococcus celericrescens:
# Thermococcus celericrescens	227598	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus celericrescens
#
# Thermococcus cleftensis:
# Thermococcus cleftensis	163003	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus cleftensis
#
# Thermococcus eurythermalis:
# Thermococcus eurythermalis	1505907	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus eurythermalis
#
# Thermococcus gammatolerans:
# Thermococcus gammatolerans	187878	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus gammatolerans
#
# Thermococcus gammatolerans EJ3:
# Thermococcus gammatolerans EJ3	593117	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus gammatolerans
#
# Thermococcus guaymasensis:
# Thermococcus guaymasensis	110164	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus guaymasensis
#
# Thermococcus henrietii:
# Thermococcus henrietii	2016361	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus henrietii
#
# Thermococcus indicus:
# Thermococcus indicus	2586643	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus indicus
#
# Thermococcus litoralis:
# Thermococcus litoralis	2265	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus litoralis
#
# Thermococcus litoralis DSM 5473:
# Thermococcus litoralis DSM 5473	523849	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus litoralis
#
# Thermococcus nautili:
# Thermococcus nautili	195522	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus nautili
#
# Thermococcus paralvinellae:
# Thermococcus paralvinellae	582419	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus paralvinellae
#
# Thermococcus profundus:
# Thermococcus profundus	49899	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus profundus
#
# Thermococcus sp.:
# Thermococcus sp.	35749	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp.
#
# Thermococcus sp. 18S1:
# Thermococcus sp. 18S1	1638210	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. 18S1
#
# Thermococcus sp. 21S7:
# Thermococcus sp. 21S7	1638221	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. 21S7
#
# Thermococcus sp. 21S9:
# Thermococcus sp. 21S9	1638223	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. 21S9
#
# Thermococcus sp. 2319x1:
# Thermococcus sp. 2319x1	1674923	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. 2319x1
#
# Thermococcus sp. 9N3:
# Thermococcus sp. 9N3	163002	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. 9N3
#
# Thermococcus sp. AM4:
# Thermococcus sp. AM4	246969	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. AM4
#
# Thermococcus sp. Bubb.Bath:
# Thermococcus sp. Bubb.Bath	1638242	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. Bubb.Bath
#
# Thermococcus sp. EP1:
# Thermococcus sp. EP1	1591054	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. EP1
#
# Thermococcus sp. JdF3:
# Thermococcus sp. JdF3	1638258	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. JdF3
#
# Thermococcus sp. M39:
# Thermococcus sp. M39	1638262	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. M39
#
# Thermococcus sp. MV5:
# Thermococcus sp. MV5	1638272	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. MV5
#
# Thermococcus sp. PK:
# Thermococcus sp. PK	913025	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. PK
#
# Thermococcus sp. SY098:
# Thermococcus sp. SY098	3111325	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus sp. SY098
#
# Thermococcus thermotolerans:
# Thermococcus thermotolerans	2969672	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus thermotolerans
#
# Thermococcus thioreducens:
# Thermococcus thioreducens	277988	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus thioreducens
#
# Thermococcus zilligii:
# Thermococcus zilligii	54076	Archaea;Euryarchaeota;Thermococci;Thermococcales;Thermococcaceae;Thermococcus;Thermococcus zilligii
#
# Thermofilum adornatum:
# Thermofilum adornatum	1365176	Archaea;Thermoproteota;Thermoprotei;Thermofilales;Thermofilaceae;Thermofilum;Thermofilum adornatum
#
# Thermofilum pendens:
# Thermofilum pendens	2269	Archaea;Thermoproteota;Thermoprotei;Thermofilales;Thermofilaceae;Thermofilum;Thermofilum pendens
#
# Thermofilum sp.:
# Thermofilum sp.	1961369	Archaea;Thermoproteota;Thermoprotei;Thermofilales;Thermofilaceae;Thermofilum;Thermofilum sp.
#
# Thermoplasmata:
# Thermoplasmata	183967	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;;;;
#
# Thermoplasmata archaeon:
# Thermoplasmata archaeon	1906666	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;;;;Thermoplasmata archaeon
#
# Thermoplasmata archaeon HGW-Thermoplasmata-1:
# Thermoplasmata archaeon HGW-Thermoplasmata-1	2013852	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;;;;Thermoplasmata archaeon HGW-Thermoplasmata-1
#
# Thermoplasmataceae archaeon:
# Thermoplasmataceae archaeon	2953047	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;Thermoplasmatales;Thermoplasmataceae;;Thermoplasmataceae archaeon
#
# Thermoplasmatales:
# Thermoplasmatales	2301	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;Thermoplasmatales;;;
#
# Thermoplasmatales archaeon:
# Thermoplasmatales archaeon	2268204	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;Thermoplasmatales;;;Thermoplasmatales archaeon
#
# Thermoplasmatales archaeon A-plasma:
# Thermoplasmatales archaeon A-plasma	667135	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;Thermoplasmatales;;;Thermoplasmatales archaeon A-plasma
#
# Thermoplasmatales archaeon ex4484_36:
# Thermoplasmatales archaeon ex4484_36	2012523	Archaea;Candidatus Thermoplasmatota;Thermoplasmata;Thermoplasmatales;;;Thermoplasmatales archaeon ex4484_36
#
# Thermoproteaceae archaeon:
# Thermoproteaceae archaeon	2614265	Archaea;Thermoproteota;Thermoprotei;Thermoproteales;Thermoproteaceae;;Thermoproteaceae archaeon
#
# Thermoprotei archaeon:
# Thermoprotei archaeon	2250277	Archaea;Thermoproteota;Thermoprotei;;;;Thermoprotei archaeon
#
# Thermoproteota:
# Thermoproteota	28889	Archaea;Thermoproteota;;;;;
#
# Thermoproteota archaeon:
# Thermoproteota archaeon	2056631	Archaea;Thermoproteota;;;;;Thermoproteota archaeon
#
# Thermoproteus sp.:
# Thermoproteus sp.	2268139	Archaea;Thermoproteota;Thermoprotei;Thermoproteales;Thermoproteaceae;Thermoproteus;Thermoproteus sp.
#
# unclassified:
# unclassified	12908	;;;;;;
#
# unclassified Methanoregula:
# unclassified Methanoregula	2649730	Archaea;Euryarchaeota;Methanomicrobia;Methanomicrobiales;Methanoregulaceae;Methanoregula;
#
# unclassified Methanosarcina:
# unclassified Methanosarcina	2644672	Archaea;Euryarchaeota;Methanomicrobia;Methanosarcinales;Methanosarcinaceae;Methanosarcina;
#
# uncultured:
#
#
# uncultured Acidilobus sp. CIS:
# uncultured Acidilobus sp. CIS	1410574	Archaea;Thermoproteota;Thermoprotei;Acidilobales;Acidilobaceae;Acidilobus;uncultured Acidilobus sp. CIS
#
# uncultured Acidilobus sp. JCHS:
# uncultured Acidilobus sp. JCHS	1410576	Archaea;Thermoproteota;Thermoprotei;Acidilobales;Acidilobaceae;Acidilobus;uncultured Acidilobus sp. JCHS
#
# uncultured Acidilobus sp. MG:
# uncultured Acidilobus sp. MG	1410573	Archaea;Thermoproteota;Thermoprotei;Acidilobales;Acidilobaceae;Acidilobus;uncultured Acidilobus sp. MG
#
# uncultured Acidilobus sp. OSP8:
# uncultured Acidilobus sp. OSP8	1410575	Archaea;Thermoproteota;Thermoprotei;Acidilobales;Acidilobaceae;Acidilobus;uncultured Acidilobus sp. OSP8
#
# uncultured archaeon:
# uncultured archaeon	115547	Archaea;;;;;;uncultured archaeon
#
# uncultured euryarchaeote:
# uncultured euryarchaeote	114243	Archaea;Euryarchaeota;;;;;uncultured euryarchaeote
#
# uncultured marine group II/III euryarchaeote:
#
#
# uncultured marine thaumarchaeote:
# uncultured marine thaumarchaeote	1167203	Archaea;Nitrososphaerota;;;;;uncultured marine thaumarchaeote
#
# uncultured Methanobacterium:
#
#
# uncultured Methanobrevibacter:
#
#
# uncultured Methanobrevibacter sp.:
# uncultured Methanobrevibacter sp.	253161	Archaea;Euryarchaeota;Methanobacteria;Methanobacteriales;Methanobacteriaceae;Methanobrevibacter;uncultured Methanobrevibacter sp.
#
# uncultured Methanofollis sp.:
# uncultured Methanofollis sp.	262500	Archaea;Euryarchaeota;Methanomicrobia;Methanomicrobiales;Methanomicrobiaceae;Methanofollis;uncultured Methanofollis sp.
#
# uncultured Methanolobus sp.:
# uncultured Methanolobus sp.	218300	Archaea;Euryarchaeota;Methanomicrobia;Methanosarcinales;Methanosarcinaceae;Methanolobus;uncultured Methanolobus sp.
#
# uncultured Methanomethylovorans:
#
#
# uncultured Poseidoniia archaeon:
# uncultured Poseidoniia archaeon	1697135	Archaea;Candidatus Thermoplasmatota;Candidatus Poseidoniia;;;;uncultured Poseidoniia archaeon
#
# Vulcanisaeta sp.:
# Vulcanisaeta sp.	2020871	Archaea;Thermoproteota;Thermoprotei;Thermoproteales;Thermoproteaceae;Vulcanisaeta;Vulcanisaeta sp.
#
# Vulcanisaeta sp. JCM:
