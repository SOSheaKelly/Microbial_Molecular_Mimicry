# %% [markdown]
# ## 0.1 Setup

# %%
# !pip install biopython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting biopython
#   Downloading biopython-1.83-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from biopython) (1.26.4)
# Downloading biopython-1.83-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 19.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: biopython
# Successfully installed biopython-1.83

# %%
# !pwd
# Out:
# /home/osheakes/Research_Project_MMM/Fasta

# %% [markdown]
# ##

# %% [markdown]
# # 1.0 Viral Precursor Blast

# %% [markdown]
# ## 1.1 Viral Blast test

# %%
#test run of one Accession to ensure command runs as expected
# !blastp -remote -query input_proteins.fa -db genomic/Viruses/Viral_Protein_Sequences -evalue 0.06 -outfmt 7 -out output.txt

# %% [markdown]
# #

# %% [markdown]
# ## 1.2 Blast in fmt 5 format

# %%
# !mkdir /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/

# %%
import os
import time

# Record start time
start_time = time.time()

# fasta inputs
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta"

# Directory for results
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/"

# BLAST parameters
blast_db = "genomic/Viruses/Viral_Protein_Sequences"
evalue = "0.06"
outfmt = "5"  
blast_remote = "-remote"  

# 5min interval for logbook
print_interval = 300 

# Set initial time for printing logbook
next_print_time = start_time + print_interval

# Select fasta's in directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):  
        fasta_file = os.path.join(fasta_directory, filename)
        output_file = os.path.splitext(filename)[0] + "_blast_results.txt"
        output_path = os.path.join(blast_output_directory, output_file)
        
        # Check if output file already exists
        if os.path.exists(output_path):
            print(f"Skipping {filename} - Output file already exists: {output_path}")
            continue
        
        # Record start time for each file
        file_start_time = time.time()
        
        # BLAST command 
        command = f"blastp {blast_remote} -query {fasta_file} -db {blast_db} -evalue {evalue} -outfmt {outfmt} -out {output_path}"
        
        # Execute BLAST command
        os.system(command)
        
        # Calculate time taken for BLAST search on current file
        file_duration = time.time() - file_start_time
        
        #  to print logbook
        if time.time() >= next_print_time:
            # Print logbook message
            print(f"BLAST for {filename} started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(file_start_time))} and completed in {file_duration//60:.0f} minutes {file_duration%60:.2f} seconds. Results saved in {output_path}")
            
            # Update next print time
            next_print_time += print_interval
        
# Calculate total run time
total_duration = time.time() - start_time

# Print total execution time
print(f"Total execution time: {total_duration//60:.0f} minutes {total_duration%60:.2f} seconds")
# Out:
# Skipping O96011.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O96011_blast_results.txt
# Skipping Q07812.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q07812_blast_results.txt
# Skipping Q8NFJ6.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q8NFJ6_blast_results.txt
# Skipping P07492.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P07492_blast_results.txt
# Skipping Q15303.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q15303_blast_results.txt
# Skipping Q15726.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q15726_blast_results.txt
# Skipping O00910.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O00910_blast_results.txt
# Skipping P38398.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P38398_blast_results.txt
# Skipping P06881.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P06881_blast_results.txt
# Skipping P46663.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P46663_blast_results.txt
# Skipping P32247.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P32247_blast_results.txt
# Skipping P60484.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P60484_blast_results.txt
# Skipping P20366.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P20366_blast_results.txt
# Skipping P35318.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P35318_blast_results.txt
# Skipping P12872.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P12872_blast_results.txt
# Skipping P10645.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P10645_blast_results.txt
# Skipping O95760.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O95760_blast_results.txt
# Skipping P01344.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01344_blast_results.txt
# Skipping O14879.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O14879_blast_results.txt
# Skipping O43745.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O43745_blast_results.txt
# Skipping Q92968.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q92968_blast_results.txt
# Skipping O95390.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O95390_blast_results.txt
# Skipping P02533.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P02533_blast_results.txt
# Skipping Q01629.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q01629_blast_results.txt
# Skipping P0C0P6.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P0C0P6_blast_results.txt
# Skipping Q00534.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q00534_blast_results.txt
# Skipping P20592.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P20592_blast_results.txt
# Skipping P06493.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P06493_blast_results.txt
# Skipping P06400.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P06400_blast_results.txt
# Skipping Q03252.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q03252_blast_results.txt
# Skipping P24941.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P24941_blast_results.txt
# Skipping Q13519.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q13519_blast_results.txt
# Skipping P01574.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01574_blast_results.txt
# Skipping P19883.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P19883_blast_results.txt
# Skipping P01282.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01282_blast_results.txt
# Skipping Q9Y5Q6.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q9Y5Q6_blast_results.txt
# Skipping Q8IUX4.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q8IUX4_blast_results.txt
# Skipping P55265.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P55265_blast_results.txt
# Skipping Q99988.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q99988_blast_results.txt
# Skipping P48645.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P48645_blast_results.txt
# Skipping P06396.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P06396_blast_results.txt
# Skipping P01966.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01966_blast_results.txt
# Skipping Q96BS2.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q96BS2_blast_results.txt
# Skipping P47898.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P47898_blast_results.txt
# Skipping P42226.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P42226_blast_results.txt
# Skipping P09914.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P09914_blast_results.txt
# Skipping O75192.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O75192_blast_results.txt
# Skipping O95399.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O95399_blast_results.txt
# Skipping P11802.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P11802_blast_results.txt
# Skipping P08949.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P08949_blast_results.txt
# Skipping Q01453.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q01453_blast_results.txt
# Skipping Q10589.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q10589_blast_results.txt
# Skipping Q969E3.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q969E3_blast_results.txt
# Skipping Q14790.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q14790_blast_results.txt
# Skipping A0A097EV82.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/A0A097EV82_blast_results.txt
# Skipping P55089.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P55089_blast_results.txt
# Skipping O75381.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O75381_blast_results.txt
# Skipping Q9P0W0.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q9P0W0_blast_results.txt
# Skipping Q9H293.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q9H293_blast_results.txt
# Skipping Q00535.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q00535_blast_results.txt
# Skipping P43490.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P43490_blast_results.txt
# Skipping Q9BTW9.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q9BTW9_blast_results.txt
# Skipping P42224.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P42224_blast_results.txt
# Skipping Q00526.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q00526_blast_results.txt
# Skipping Q9HC23.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q9HC23_blast_results.txt
# Skipping P01241.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01241_blast_results.txt
# Skipping Q16611.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q16611_blast_results.txt
# Skipping P56199.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P56199_blast_results.txt
# Skipping P01258.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01258_blast_results.txt
# Skipping Q8NG41.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q8NG41_blast_results.txt
# Skipping P10082.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P10082_blast_results.txt
# Skipping Q7Z2W4.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q7Z2W4_blast_results.txt
# Skipping P19525.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P19525_blast_results.txt
# Skipping O43808.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O43808_blast_results.txt
# Skipping Q96RP3.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q96RP3_blast_results.txt
# Skipping P01566.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01566_blast_results.txt
# Skipping P01568.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01568_blast_results.txt
# Skipping P80303.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P80303_blast_results.txt
# Skipping O15130.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O15130_blast_results.txt
# Skipping P01019.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01019_blast_results.txt
# Skipping Q99653.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q99653_blast_results.txt
# Skipping P01570.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01570_blast_results.txt
# Skipping P30990.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P30990_blast_results.txt
# Skipping P23582.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P23582_blast_results.txt
# Skipping P42574.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P42574_blast_results.txt
# Skipping P16860.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P16860_blast_results.txt
# Skipping Q14765.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q14765_blast_results.txt
# Skipping Q9Y3Z3.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q9Y3Z3_blast_results.txt
# Skipping P01579.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01579_blast_results.txt
# Skipping Q02388.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q02388_blast_results.txt
# Skipping Q8N729.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q8N729_blast_results.txt
# Skipping O95786.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/O95786_blast_results.txt
# Skipping P13164.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P13164_blast_results.txt
# Skipping P18509.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P18509_blast_results.txt
# Skipping Q12965.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q12965_blast_results.txt
# Skipping P01160.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01160_blast_results.txt
# Skipping P81605.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P81605_blast_results.txt
# Skipping P09912.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P09912_blast_results.txt
# Skipping Q13325.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q13325_blast_results.txt
# Skipping P20591.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P20591_blast_results.txt
# Skipping P52630.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P52630_blast_results.txt
# Skipping P01210.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01210_blast_results.txt
# Skipping P40763.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P40763_blast_results.txt
# Skipping P01213.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01213_blast_results.txt
# Skipping Q01628.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q01628_blast_results.txt
# Skipping P23142.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P23142_blast_results.txt
# Skipping Q9UHF0.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q9UHF0_blast_results.txt
# Skipping P51587.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P51587_blast_results.txt
# Skipping P15502.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P15502_blast_results.txt
# Skipping P19838.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P19838_blast_results.txt
# Skipping P04637.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P04637_blast_results.txt
# Skipping Q5H8A3.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q5H8A3_blast_results.txt
# Skipping P55211.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P55211_blast_results.txt
# Skipping P25445.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P25445_blast_results.txt
# Skipping Q9Y5Y5.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/Q9Y5Y5_blast_results.txt
# Skipping P01303.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01303_blast_results.txt
# Skipping P55210.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P55210_blast_results.txt
# Skipping P01225.fasta - Output file already exists: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/P01225_blast_results.txt
# Total execution time: 1 minutes 0.27 seconds

# %%
import os

# Path to the directory containing the FASTA files
directory_path = "/home/osheakes/Research_Project_MMM/Fasta/"

# Count the number of FASTA files in the directory
fasta_files = [file for file in os.listdir(directory_path) if file.endswith(".fasta")]
num_fasta_files = len(fasta_files)

print(f"Number of FASTA files in directory '{directory_path}': {num_fasta_files}")
# Out:
# Number of FASTA files in directory '/home/osheakes/Research_Project_MMM/Fasta/': 119

# %% [markdown]
# ## 1.3 Create script to parse data out of blast results files

# %%
import os
import re
import csv

# Path to the blast outputs in fmt 5
results_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5"

# Output CSV file path
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/VB_Results.csv"

# Initialize count variables
included_files_count = 0
ignored_files_count = 0

# Write CSV header
with open(output_csv_path, "w", newline="") as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(["Accession ID", "Hit Number", "Hit ID", "Hit Length", "Species", "Query Definition", "Hsp Bit Score", "Hsp Score", "Hsp E-value", "Identity", "Positives", "Gaps", "Hsp Qseq", "Hsp Hseq"])

# Iterate through each blast output
for filename in os.listdir(results_directory):
    if filename.endswith(".txt") and filename != ".txt":  
        print(f"Processing file: {filename}")
        results_file_path = os.path.join(results_directory, filename)
        
        # Open and read the results
        with open(results_file_path, "r") as results_file:
            results_text = results_file.read()

            # Check if "0 hits found" or "No hits found" is present
            if "0 hits found" in results_text or "No hits found" in results_text:
                print(f"Ignoring file: {filename} - No hits found")
                ignored_files_count += 1
                continue
            
            # Check if the file contains expected XML structure
            if "<Hit>" not in results_text:
                print(f"Ignoring file: {filename} - Unexpected format")
                ignored_files_count += 1
                continue
            
            # Increment included files count
            included_files_count += 1
            
            # Use file names to get Accession ID's
            accession_id = os.path.splitext(filename)[0].replace("_blast_results", "")
            
            # Initialize hit number
            hit_number = 1
            
            # Specify Hit ID
            hit_ids = re.findall(r'<Hit_id>.*?\|(.*?)\|</Hit_id>', results_text)
            
            # Specify hit length
            hit_lengths = re.findall(r'<Hit_len>(\d+)</Hit_len>', results_text)
            
            # Specify species
            species = re.findall(r'\[(.*?)\]', results_text)

            # Specify Query Definition
            query_definitions = re.findall(r'<Hit_def>(.*?)<', results_text)

            # Specify additional Hsp information
            hsp_bit_scores = re.findall(r'<Hsp_bit-score>(.*?)</Hsp_bit-score>', results_text)
            hsp_scores = re.findall(r'<Hsp_score>(.*?)</Hsp_score>', results_text)
            hsp_evals = re.findall(r'<Hsp_evalue>(.*?)</Hsp_evalue>', results_text)
            hsp_qseqs = re.findall(r'<Hsp_qseq>(.*?)</Hsp_qseq>', results_text)
            hsp_hseqs = re.findall(r'<Hsp_hseq>(.*?)</Hsp_hseq>', results_text)
            hsp_identities = re.findall(r'<Hsp_identity>(.*?)</Hsp_identity>', results_text)
            hsp_positives = re.findall(r'<Hsp_positive>(.*?)</Hsp_positive>', results_text)
            hsp_gaps = re.findall(r'<Hsp_gaps>(.*?)</Hsp_gaps>', results_text)

            # Write to CSV
            with open(output_csv_path, "a", newline="") as csvfile:
                csv_writer = csv.writer(csvfile)
                for hit_id, length, word, query_def, bit_score, score, eval, identity, positives, gaps, qseq, hseq in zip(hit_ids, hit_lengths, species, query_definitions, hsp_bit_scores, hsp_scores, hsp_evals, hsp_identities, hsp_positives, hsp_gaps, hsp_qseqs, hsp_hseqs):
                    if query_def:  # Check if query definition is not empty
                        csv_writer.writerow([accession_id, f"Hit {hit_number}", hit_id, length, word, query_def, bit_score, score, eval, identity, positives, gaps, qseq, hseq])
                        hit_number += 1

# Print count of included and ignored files
print(f"Included files: {included_files_count}")
print(f"Ignored files: {ignored_files_count}")
print("CSV generation complete.")
# Out:
# Processing file: P12872_blast_results.txt
# Ignoring file: P12872_blast_results.txt - No hits found
# Processing file: P56199_blast_results.txt
# Processing file: P81605_blast_results.txt
# Ignoring file: P81605_blast_results.txt - No hits found
# Processing file: P01579_blast_results.txt
# Ignoring file: P01579_blast_results.txt - No hits found
# Processing file: P18509_blast_results.txt
# Ignoring file: P18509_blast_results.txt - No hits found
# Processing file: P01258_blast_results.txt
# Ignoring file: P01258_blast_results.txt - No hits found
# Processing file: P01570_blast_results.txt
# Ignoring file: P01570_blast_results.txt - No hits found
# Processing file: P23582_blast_results.txt
# Ignoring file: P23582_blast_results.txt - No hits found
# Processing file: P24941_blast_results.txt
# Processing file: P19838_blast_results.txt
# Processing file: O95390_blast_results.txt
# Processing file: Q9HC23_blast_results.txt
# Ignoring file: Q9HC23_blast_results.txt - No hits found
# Processing file: Q8NFJ6_blast_results.txt
# Processing file: O95786_blast_results.txt
# Processing file: P20366_blast_results.txt
# Ignoring file: P20366_blast_results.txt - No hits found
# Processing file: P01568_blast_results.txt
# Ignoring file: P01568_blast_results.txt - No hits found
# Processing file: O95760_blast_results.txt
# Ignoring file: O95760_blast_results.txt - No hits found
# Processing file: P06881_blast_results.txt
# Ignoring file: P06881_blast_results.txt - No hits found
# Processing file: Q5H8A3_blast_results.txt
# Ignoring file: Q5H8A3_blast_results.txt - No hits found
# Processing file: O43808_blast_results.txt
# Processing file: O14879_blast_results.txt
# Processing file: P01966_blast_results.txt
# Processing file: P01282_blast_results.txt
# Ignoring file: P01282_blast_results.txt - No hits found
# Processing file: P09912_blast_results.txt
# Ignoring file: P09912_blast_results.txt - No hits found
# Processing file: P01225_blast_results.txt
# Ignoring file: P01225_blast_results.txt - No hits found
# Processing file: P11802_blast_results.txt
# Processing file: Q08722_blast_results.txt
# Processing file: P01303_blast_results.txt
# Ignoring file: P01303_blast_results.txt - No hits found
# Processing file: Q15303_blast_results.txt
# Processing file: P51587_blast_results.txt
# Ignoring file: P51587_blast_results.txt - No hits found
# Processing file: Q16611_blast_results.txt
# Processing file: Q9UHF0_blast_results.txt
# Ignoring file: Q9UHF0_blast_results.txt - No hits found
# Processing file: Q01629_blast_results.txt
# Ignoring file: Q01629_blast_results.txt - No hits found
# Processing file: P0C0P6_blast_results.txt
# Ignoring file: P0C0P6_blast_results.txt - No hits found
# Processing file: P16860_blast_results.txt
# Ignoring file: P16860_blast_results.txt - No hits found
# Processing file: Q92968_blast_results.txt
# Ignoring file: Q92968_blast_results.txt - No hits found
# Processing file: P35318_blast_results.txt
# Ignoring file: P35318_blast_results.txt - No hits found
# Processing file: P47898_blast_results.txt
# Processing file: P20591_blast_results.txt
# Processing file: O43745_blast_results.txt
# Ignoring file: O43745_blast_results.txt - No hits found
# Processing file: P55089_blast_results.txt
# Ignoring file: P55089_blast_results.txt - No hits found
# Processing file: P20592_blast_results.txt
# Processing file: Q13325_blast_results.txt
# Ignoring file: Q13325_blast_results.txt - No hits found
# Processing file: P32247_blast_results.txt
# Processing file: Q9Y3Z3_blast_results.txt
# Processing file: P01160_blast_results.txt
# Ignoring file: P01160_blast_results.txt - No hits found
# Processing file: Q9H293_blast_results.txt
# Ignoring file: Q9H293_blast_results.txt - No hits found
# Processing file: P08949_blast_results.txt
# Ignoring file: P08949_blast_results.txt - No hits found
# Processing file: O95399_blast_results.txt
# Ignoring file: O95399_blast_results.txt - No hits found
# Processing file: P06396_blast_results.txt
# Processing file: P01213_blast_results.txt
# Ignoring file: P01213_blast_results.txt - No hits found
# Processing file: P01210_blast_results.txt
# Ignoring file: P01210_blast_results.txt - No hits found
# Processing file: P10082_blast_results.txt
# Ignoring file: P10082_blast_results.txt - No hits found
# Processing file: Q15726_blast_results.txt
# Ignoring file: Q15726_blast_results.txt - No hits found
# Processing file: P80303_blast_results.txt
# Ignoring file: P80303_blast_results.txt - No hits found
# Processing file: P01574_blast_results.txt
# Ignoring file: P01574_blast_results.txt - No hits found
# Processing file: Q8IUX4_blast_results.txt
# Ignoring file: Q8IUX4_blast_results.txt - No hits found
# Processing file: P40763_blast_results.txt
# Ignoring file: P40763_blast_results.txt - No hits found
# Processing file: Q00526_blast_results.txt
# Processing file: O75192_blast_results.txt
# Ignoring file: O75192_blast_results.txt - No hits found
# Processing file: P55210_blast_results.txt
# Processing file: Q02388_blast_results.txt
# Processing file: P55211_blast_results.txt
# Ignoring file: P55211_blast_results.txt - No hits found
# Processing file: A0A097EV82_blast_results.txt
# Ignoring file: A0A097EV82_blast_results.txt - No hits found
# Processing file: P13164_blast_results.txt
# Ignoring file: P13164_blast_results.txt - No hits found
# Processing file: Q96RP3_blast_results.txt
# Ignoring file: Q96RP3_blast_results.txt - No hits found
# Processing file: P23142_blast_results.txt
# Ignoring file: P23142_blast_results.txt - No hits found
# Processing file: Q00535_blast_results.txt
# Processing file: Q99653_blast_results.txt
# Ignoring file: Q99653_blast_results.txt - No hits found
# Processing file: Q01453_blast_results.txt
# Ignoring file: Q01453_blast_results.txt - No hits found
# Processing file: Q7Z2W4_blast_results.txt
# Processing file: P42226_blast_results.txt
# Ignoring file: P42226_blast_results.txt - No hits found
# Processing file: P48645_blast_results.txt
# Ignoring file: P48645_blast_results.txt - No hits found
# Processing file: P01566_blast_results.txt
# Ignoring file: P01566_blast_results.txt - No hits found
# Processing file: O15130_blast_results.txt
# Ignoring file: O15130_blast_results.txt - No hits found
# Processing file: O96011_blast_results.txt
# Ignoring file: O96011_blast_results.txt - No hits found
# Processing file: P09914_blast_results.txt
# Ignoring file: P09914_blast_results.txt - No hits found
# Processing file: Q969E3_blast_results.txt
# Ignoring file: Q969E3_blast_results.txt - No hits found
# Processing file: P55265_blast_results.txt
# Processing file: Q12965_blast_results.txt
# Processing file: P02533_blast_results.txt
# Ignoring file: P02533_blast_results.txt - No hits found
# Processing file: Q9BTW9_blast_results.txt
# Ignoring file: Q9BTW9_blast_results.txt - No hits found
# Processing file: P10645_blast_results.txt
# Processing file: Q8N729_blast_results.txt
# Ignoring file: Q8N729_blast_results.txt - No hits found
# Processing file: P07492_blast_results.txt
# Ignoring file: P07492_blast_results.txt - No hits found
# Processing file: P43490_blast_results.txt
# Processing file: Q9P0W0_blast_results.txt
# Ignoring file: Q9P0W0_blast_results.txt - No hits found
# Processing file: Q03252_blast_results.txt
# Ignoring file: Q03252_blast_results.txt - No hits found
# Processing file: P25445_blast_results.txt
# Processing file: P42224_blast_results.txt
# Ignoring file: P42224_blast_results.txt - No hits found
# Processing file: Q13519_blast_results.txt
# Ignoring file: Q13519_blast_results.txt - No hits found
# Processing file: P04637_blast_results.txt
# Ignoring file: P04637_blast_results.txt - No hits found
# Processing file: P46663_blast_results.txt
# Processing file: Q14790_blast_results.txt
# Processing file: P30990_blast_results.txt
# Ignoring file: P30990_blast_results.txt - No hits found
# Processing file: P01344_blast_results.txt
# Processing file: Q00534_blast_results.txt
# Processing file: Q9Y5Y5_blast_results.txt
# Ignoring file: Q9Y5Y5_blast_results.txt - No hits found
# Processing file: Q14765_blast_results.txt
# Processing file: Q96BS2_blast_results.txt
# Ignoring file: Q96BS2_blast_results.txt - No hits found
# Processing file: Q99988_blast_results.txt
# Ignoring file: Q99988_blast_results.txt - No hits found
# Processing file: P06400_blast_results.txt
# Ignoring file: P06400_blast_results.txt - No hits found
# Processing file: P52630_blast_results.txt
# Ignoring file: P52630_blast_results.txt - No hits found
# Processing file: P19883_blast_results.txt
# Ignoring file: P19883_blast_results.txt - No hits found
# Processing file: Q01628_blast_results.txt
# Ignoring file: Q01628_blast_results.txt - No hits found
# Processing file: Q07812_blast_results.txt
# Processing file: P01241_blast_results.txt
# Ignoring file: P01241_blast_results.txt - No hits found
# Processing file: P06493_blast_results.txt
# Processing file: Q9Y5Q6_blast_results.txt
# Ignoring file: Q9Y5Q6_blast_results.txt - No hits found
# Processing file: P42574_blast_results.txt
# Ignoring file: P42574_blast_results.txt - No hits found
# Processing file: Q8NG41_blast_results.txt
# Ignoring file: Q8NG41_blast_results.txt - No hits found
# Processing file: Q10589_blast_results.txt
# Ignoring file: Q10589_blast_results.txt - No hits found
# Processing file: P01019_blast_results.txt
# Processing file: P15502_blast_results.txt
# Ignoring file: P15502_blast_results.txt - No hits found
# Processing file: P60484_blast_results.txt
# Processing file: P19525_blast_results.txt
# Processing file: P38398_blast_results.txt
# Processing file: O00910_blast_results.txt
# Processing file: O75381_blast_results.txt
# Ignoring file: O75381_blast_results.txt - No hits found
# Included files: 41
# Ignored files: 78
# CSV generation complete.

# %%
import os
import csv

# Path to the blast outputs in fmt 5
results_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5"

# Output CSV file path for no-hit queries
no_hits_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/No_Hits_Results.csv"

# Initialize count variables
ignored_files_count = 0

# Write CSV header for no-hit queries
with open(no_hits_csv_path, "w", newline="") as no_hits_file:
    no_hits_writer = csv.writer(no_hits_file)
    no_hits_writer.writerow(["Filename", "Reason"])

# Iterate through each blast output
for filename in os.listdir(results_directory):
    if filename.endswith(".txt") and filename != ".txt":
        print(f"Processing file: {filename}")
        results_file_path = os.path.join(results_directory, filename)
        
        # Open and read the results
        with open(results_file_path, "r") as results_file:
            results_text = results_file.read()

            # Check if "0 hits found" or "No hits found" is present
            if "0 hits found" in results_text or "No hits found" in results_text:
                print(f"Ignoring file: {filename} - No hits found")
                ignored_files_count += 1
                with open(no_hits_csv_path, "a", newline="") as no_hits_file:
                    no_hits_writer = csv.writer(no_hits_file)
                    no_hits_writer.writerow([filename, "No hits found"])
                continue
            
            # Check if the file contains expected XML structure
            if "<Hit>" not in results_text:
                print(f"Ignoring file: {filename} - Unexpected format")
                ignored_files_count += 1
                with open(no_hits_csv_path, "a", newline="") as no_hits_file:
                    no_hits_writer = csv.writer(no_hits_file)
                    no_hits_writer.writerow([filename, "Unexpected format"])
                continue

# Print count of ignored files
print(f"Ignored files: {ignored_files_count}")
print("CSV generation for no-hit queries complete.")
# Out:
# Processing file: P12872_blast_results.txt
# Ignoring file: P12872_blast_results.txt - No hits found
# Processing file: P56199_blast_results.txt
# Processing file: P81605_blast_results.txt
# Ignoring file: P81605_blast_results.txt - No hits found
# Processing file: P01579_blast_results.txt
# Ignoring file: P01579_blast_results.txt - No hits found
# Processing file: P18509_blast_results.txt
# Ignoring file: P18509_blast_results.txt - No hits found
# Processing file: P01258_blast_results.txt
# Ignoring file: P01258_blast_results.txt - No hits found
# Processing file: P01570_blast_results.txt
# Ignoring file: P01570_blast_results.txt - No hits found
# Processing file: P23582_blast_results.txt
# Ignoring file: P23582_blast_results.txt - No hits found
# Processing file: P24941_blast_results.txt
# Processing file: P19838_blast_results.txt
# Processing file: O95390_blast_results.txt
# Processing file: Q9HC23_blast_results.txt
# Ignoring file: Q9HC23_blast_results.txt - No hits found
# Processing file: Q8NFJ6_blast_results.txt
# Processing file: O95786_blast_results.txt
# Processing file: P20366_blast_results.txt
# Ignoring file: P20366_blast_results.txt - No hits found
# Processing file: P01568_blast_results.txt
# Ignoring file: P01568_blast_results.txt - No hits found
# Processing file: O95760_blast_results.txt
# Ignoring file: O95760_blast_results.txt - No hits found
# Processing file: P06881_blast_results.txt
# Ignoring file: P06881_blast_results.txt - No hits found
# Processing file: Q5H8A3_blast_results.txt
# Ignoring file: Q5H8A3_blast_results.txt - No hits found
# Processing file: O43808_blast_results.txt
# Processing file: O14879_blast_results.txt
# Processing file: P01966_blast_results.txt
# Processing file: P01282_blast_results.txt
# Ignoring file: P01282_blast_results.txt - No hits found
# Processing file: P09912_blast_results.txt
# Ignoring file: P09912_blast_results.txt - No hits found
# Processing file: P01225_blast_results.txt
# Ignoring file: P01225_blast_results.txt - No hits found
# Processing file: P11802_blast_results.txt
# Processing file: P01303_blast_results.txt
# Ignoring file: P01303_blast_results.txt - No hits found
# Processing file: Q15303_blast_results.txt
# Processing file: P51587_blast_results.txt
# Ignoring file: P51587_blast_results.txt - No hits found
# Processing file: Q16611_blast_results.txt
# Processing file: Q9UHF0_blast_results.txt
# Ignoring file: Q9UHF0_blast_results.txt - No hits found
# Processing file: Q01629_blast_results.txt
# Ignoring file: Q01629_blast_results.txt - No hits found
# Processing file: P0C0P6_blast_results.txt
# Ignoring file: P0C0P6_blast_results.txt - No hits found
# Processing file: P16860_blast_results.txt
# Ignoring file: P16860_blast_results.txt - No hits found
# Processing file: Q92968_blast_results.txt
# Ignoring file: Q92968_blast_results.txt - No hits found
# Processing file: P35318_blast_results.txt
# Ignoring file: P35318_blast_results.txt - No hits found
# Processing file: P47898_blast_results.txt
# Processing file: P20591_blast_results.txt
# Processing file: O43745_blast_results.txt
# Ignoring file: O43745_blast_results.txt - No hits found
# Processing file: P55089_blast_results.txt
# Ignoring file: P55089_blast_results.txt - No hits found
# Processing file: P20592_blast_results.txt
# Processing file: Q13325_blast_results.txt
# Ignoring file: Q13325_blast_results.txt - No hits found
# Processing file: P32247_blast_results.txt
# Processing file: Q9Y3Z3_blast_results.txt
# Processing file: P01160_blast_results.txt
# Ignoring file: P01160_blast_results.txt - No hits found
# Processing file: Q9H293_blast_results.txt
# Ignoring file: Q9H293_blast_results.txt - No hits found
# Processing file: P08949_blast_results.txt
# Ignoring file: P08949_blast_results.txt - No hits found
# Processing file: O95399_blast_results.txt
# Ignoring file: O95399_blast_results.txt - No hits found
# Processing file: P06396_blast_results.txt
# Processing file: P01213_blast_results.txt
# Ignoring file: P01213_blast_results.txt - No hits found
# Processing file: P01210_blast_results.txt
# Ignoring file: P01210_blast_results.txt - No hits found
# Processing file: P10082_blast_results.txt
# Ignoring file: P10082_blast_results.txt - No hits found
# Processing file: Q15726_blast_results.txt
# Ignoring file: Q15726_blast_results.txt - No hits found
# Processing file: P80303_blast_results.txt
# Ignoring file: P80303_blast_results.txt - No hits found
# Processing file: P01574_blast_results.txt
# Ignoring file: P01574_blast_results.txt - No hits found
# Processing file: Q8IUX4_blast_results.txt
# Ignoring file: Q8IUX4_blast_results.txt - No hits found
# Processing file: P40763_blast_results.txt
# Ignoring file: P40763_blast_results.txt - No hits found
# Processing file: Q00526_blast_results.txt
# Processing file: O75192_blast_results.txt
# Ignoring file: O75192_blast_results.txt - No hits found
# Processing file: P55210_blast_results.txt
# Processing file: Q02388_blast_results.txt
# Processing file: P55211_blast_results.txt
# Ignoring file: P55211_blast_results.txt - No hits found
# Processing file: A0A097EV82_blast_results.txt
# Ignoring file: A0A097EV82_blast_results.txt - No hits found
# Processing file: P13164_blast_results.txt
# Ignoring file: P13164_blast_results.txt - No hits found
# Processing file: Q96RP3_blast_results.txt
# Ignoring file: Q96RP3_blast_results.txt - No hits found
# Processing file: P23142_blast_results.txt
# Ignoring file: P23142_blast_results.txt - No hits found
# Processing file: Q00535_blast_results.txt
# Processing file: Q99653_blast_results.txt
# Ignoring file: Q99653_blast_results.txt - No hits found
# Processing file: Q01453_blast_results.txt
# Ignoring file: Q01453_blast_results.txt - No hits found
# Processing file: Q7Z2W4_blast_results.txt
# Processing file: P42226_blast_results.txt
# Ignoring file: P42226_blast_results.txt - No hits found
# Processing file: P48645_blast_results.txt
# Ignoring file: P48645_blast_results.txt - No hits found
# Processing file: P01566_blast_results.txt
# Ignoring file: P01566_blast_results.txt - No hits found
# Processing file: O15130_blast_results.txt
# Ignoring file: O15130_blast_results.txt - No hits found
# Processing file: O96011_blast_results.txt
# Ignoring file: O96011_blast_results.txt - No hits found
# Processing file: P09914_blast_results.txt
# Ignoring file: P09914_blast_results.txt - No hits found
# Processing file: Q969E3_blast_results.txt
# Ignoring file: Q969E3_blast_results.txt - No hits found
# Processing file: P55265_blast_results.txt
# Processing file: Q12965_blast_results.txt
# Processing file: P02533_blast_results.txt
# Ignoring file: P02533_blast_results.txt - No hits found
# Processing file: Q9BTW9_blast_results.txt
# Ignoring file: Q9BTW9_blast_results.txt - No hits found
# Processing file: P10645_blast_results.txt
# Processing file: Q8N729_blast_results.txt
# Ignoring file: Q8N729_blast_results.txt - No hits found
# Processing file: P07492_blast_results.txt
# Ignoring file: P07492_blast_results.txt - No hits found
# Processing file: P43490_blast_results.txt
# Processing file: Q9P0W0_blast_results.txt
# Ignoring file: Q9P0W0_blast_results.txt - No hits found
# Processing file: Q03252_blast_results.txt
# Ignoring file: Q03252_blast_results.txt - No hits found
# Processing file: P25445_blast_results.txt
# Processing file: P42224_blast_results.txt
# Ignoring file: P42224_blast_results.txt - No hits found
# Processing file: Q13519_blast_results.txt
# Ignoring file: Q13519_blast_results.txt - No hits found
# Processing file: P04637_blast_results.txt
# Ignoring file: P04637_blast_results.txt - No hits found
# Processing file: P46663_blast_results.txt
# Processing file: Q14790_blast_results.txt
# Processing file: P30990_blast_results.txt
# Ignoring file: P30990_blast_results.txt - No hits found
# Processing file: P01344_blast_results.txt
# Processing file: Q00534_blast_results.txt
# Processing file: Q9Y5Y5_blast_results.txt
# Ignoring file: Q9Y5Y5_blast_results.txt - No hits found
# Processing file: Q14765_blast_results.txt
# Processing file: Q96BS2_blast_results.txt
# Ignoring file: Q96BS2_blast_results.txt - No hits found
# Processing file: Q99988_blast_results.txt
# Ignoring file: Q99988_blast_results.txt - No hits found
# Processing file: P06400_blast_results.txt
# Ignoring file: P06400_blast_results.txt - No hits found
# Processing file: P52630_blast_results.txt
# Ignoring file: P52630_blast_results.txt - No hits found
# Processing file: P19883_blast_results.txt
# Ignoring file: P19883_blast_results.txt - No hits found
# Processing file: Q01628_blast_results.txt
# Ignoring file: Q01628_blast_results.txt - No hits found
# Processing file: Q07812_blast_results.txt
# Processing file: P01241_blast_results.txt
# Ignoring file: P01241_blast_results.txt - No hits found
# Processing file: P06493_blast_results.txt
# Processing file: Q9Y5Q6_blast_results.txt
# Ignoring file: Q9Y5Q6_blast_results.txt - No hits found
# Processing file: P42574_blast_results.txt
# Ignoring file: P42574_blast_results.txt - No hits found
# Processing file: Q8NG41_blast_results.txt
# Ignoring file: Q8NG41_blast_results.txt - No hits found
# Processing file: Q10589_blast_results.txt
# Ignoring file: Q10589_blast_results.txt - No hits found
# Processing file: P01019_blast_results.txt
# Processing file: P15502_blast_results.txt
# Ignoring file: P15502_blast_results.txt - No hits found
# Processing file: P60484_blast_results.txt
# Processing file: P19525_blast_results.txt
# Processing file: P38398_blast_results.txt
# Processing file: O00910_blast_results.txt
# Processing file: O75381_blast_results.txt
# Ignoring file: O75381_blast_results.txt - No hits found
# Ignored files: 78
# CSV generation for no-hit queries complete.

# %% [markdown]
# ## Process files which produced No hits

# %%
import os
import re
import shutil

# Paths
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta"
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/"
no_hits_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits"

# Create an output directory for files which produced no hits
os.makedirs(no_hits_directory, exist_ok=True)

# Initialize count variables
ignored_files_count = 0

# Iterate through each BLAST output
for filename in os.listdir(blast_output_directory):
    if filename.endswith(".txt") and filename != ".txt":
        results_file_path = os.path.join(blast_output_directory, filename)
        
        # Open and read the results
        with open(results_file_path, "r") as results_file:
            results_text = results_file.read()
            
            # Check if "0 hits found" or "No hits found" is present
            if "0 hits found" in results_text or "No hits found" in results_text:
                ignored_files_count += 1
                # Determine the original fasta file
                fasta_filename = filename.replace("_blast_results.txt", ".fasta")
                fasta_file_path = os.path.join(fasta_directory, fasta_filename)
                
                # Move the original fasta file to the no_hits directory
                if os.path.exists(fasta_file_path):
                    shutil.move(fasta_file_path, os.path.join(no_hits_directory, fasta_filename))
                    print(f"Moved no-hit file: {fasta_filename} to {no_hits_directory}")

print(f"Ignored (no-hit) files: {ignored_files_count}")
print("No-hit files moved to the designated directory.")
# Out:
# Moved no-hit file: P12872.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P81605.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01579.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P18509.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01258.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01570.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P23582.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q9HC23.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P20366.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01568.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: O95760.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P06881.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q5H8A3.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01282.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P09912.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01225.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01303.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P51587.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q9UHF0.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q01629.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P0C0P6.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P16860.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q92968.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P35318.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: O43745.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P55089.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q13325.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01160.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q9H293.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P08949.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: O95399.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01213.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01210.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P10082.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q15726.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P80303.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01574.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q8IUX4.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P40763.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: O75192.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P55211.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: A0A097EV82.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P13164.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q96RP3.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P23142.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q99653.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q01453.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P42226.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P48645.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01566.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: O15130.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: O96011.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P09914.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q969E3.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P02533.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q9BTW9.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q8N729.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P07492.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q9P0W0.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q03252.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P42224.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q13519.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P04637.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P30990.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q9Y5Y5.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q96BS2.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q99988.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P06400.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P52630.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P19883.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q01628.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P01241.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q9Y5Q6.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P42574.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q8NG41.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: Q10589.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: P15502.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Moved no-hit file: O75381.fasta to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Ignored (no-hit) files: 78
# No-hit files moved to the designated directory.

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## Check NCBI Viral Non-Redundancies Database for hits

# %%
import os
import subprocess
import time

# Paths
no_hits_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits"
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/nr_blastp_results"
os.makedirs(blast_output_directory, exist_ok=True)

# BLAST parameters
db = "nr"
evalue = "0.06"
remote = "-remote"
entrez_query = '"viruses[orgn]"' 

# Record the start time
start_time = time.time()
start_time_local = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(start_time))
print(f"Start time (Local): {start_time_local}")

# Iterate through the FASTA files in the no_hits directory
for filename in os.listdir(no_hits_directory):
    if filename.endswith(".fasta"):
        fasta_file = os.path.join(no_hits_directory, filename)
        output_file = os.path.splitext(filename)[0] + "_blastp_results.txt"
        output_path = os.path.join(blast_output_directory, output_file)
        
        # Define the BLAST command
        command = f"blastp -db {db} -query {fasta_file} -out {output_path} -evalue {evalue} {remote} -entrez_query {entrez_query}"
        
        # Execute the BLAST command
        try:
            result = subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            if result.returncode == 0:
                print(f"BLAST command executed successfully for {filename}.")
            else:
                print(f"BLAST command failed for {filename} with return code {result.returncode}.")
        except subprocess.CalledProcessError as e:
            print(f"BLAST command failed for {filename} with error: {e.stderr.decode()}")
        
        # Record the end time
        end_time = time.time()
        end_time_local = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(end_time))

        # Calculate the duration
        duration = end_time - start_time
        duration_minutes, duration_seconds = divmod(duration, 60)

        print(f"End time (Local): {end_time_local}")
        print(f"Execution time for {filename}: {int(duration_minutes)} minutes and {duration_seconds:.2f} seconds")

# Calculate total run time
total_duration = time.time() - start_time
total_duration_minutes, total_duration_seconds = divmod(total_duration, 60)

print(f"Total execution time: {int(total_duration_minutes)} minutes and {total_duration_seconds:.2f} seconds")
# Out:
# Start time (Local): 2024-06-04 12:33:52
# BLAST command executed successfully for O96011.fasta.
# End time (Local): 2024-06-04 13:00:24
# Execution time for O96011.fasta: 26 minutes and 31.48 seconds
# BLAST command executed successfully for P07492.fasta.
# End time (Local): 2024-06-04 13:31:56
# Execution time for P07492.fasta: 58 minutes and 3.42 seconds
# BLAST command executed successfully for Q15726.fasta.
# End time (Local): 2024-06-04 14:48:39
# Execution time for Q15726.fasta: 134 minutes and 46.41 seconds
# BLAST command executed successfully for P06881.fasta.
# End time (Local): 2024-06-04 15:15:10
# Execution time for P06881.fasta: 161 minutes and 17.44 seconds
# BLAST command executed successfully for P20366.fasta.
# End time (Local): 2024-06-04 15:41:41
# Execution time for P20366.fasta: 187 minutes and 49.20 seconds
# BLAST command executed successfully for P35318.fasta.
# End time (Local): 2024-06-04 16:13:14
# Execution time for P35318.fasta: 219 minutes and 21.42 seconds
# BLAST command executed successfully for P12872.fasta.
# End time (Local): 2024-06-04 17:19:54
# Execution time for P12872.fasta: 286 minutes and 1.81 seconds
# BLAST command executed successfully for O95760.fasta.
# End time (Local): 2024-06-04 18:01:30
# Execution time for O95760.fasta: 327 minutes and 37.64 seconds
# BLAST command executed successfully for O43745.fasta.
# End time (Local): 2024-06-04 19:23:14
# Execution time for O43745.fasta: 409 minutes and 21.81 seconds
# BLAST command executed successfully for Q92968.fasta.
# End time (Local): 2024-06-04 19:39:43
# Execution time for Q92968.fasta: 425 minutes and 50.51 seconds
# BLAST command executed successfully for P02533.fasta.
# End time (Local): 2024-06-04 20:01:13
# Execution time for P02533.fasta: 447 minutes and 20.74 seconds
# BLAST command executed successfully for Q01629.fasta.
# End time (Local): 2024-06-04 21:17:57
# Execution time for Q01629.fasta: 524 minutes and 5.22 seconds
# BLAST command executed successfully for P0C0P6.fasta.
# End time (Local): 2024-06-04 22:29:41
# Execution time for P0C0P6.fasta: 595 minutes and 49.38 seconds
# BLAST command executed successfully for P06400.fasta.
# End time (Local): 2024-06-04 22:32:46
# Execution time for P06400.fasta: 598 minutes and 54.28 seconds
# BLAST command executed successfully for Q03252.fasta.
# End time (Local): 2024-06-04 22:36:54
# Execution time for Q03252.fasta: 603 minutes and 2.30 seconds
# BLAST command executed successfully for Q13519.fasta.
# End time (Local): 2024-06-04 22:44:12
# Execution time for Q13519.fasta: 610 minutes and 20.08 seconds
# BLAST command executed successfully for P01574.fasta.
# End time (Local): 2024-06-04 22:56:48
# Execution time for P01574.fasta: 622 minutes and 55.65 seconds
# BLAST command executed successfully for P19883.fasta.
# End time (Local): 2024-06-04 23:43:24
# Execution time for P19883.fasta: 669 minutes and 31.99 seconds
# BLAST command executed successfully for P01282.fasta.
# End time (Local): 2024-06-04 23:52:59
# Execution time for P01282.fasta: 679 minutes and 7.18 seconds
# BLAST command executed successfully for Q9Y5Q6.fasta.
# End time (Local): 2024-06-05 00:39:36
# Execution time for Q9Y5Q6.fasta: 725 minutes and 43.69 seconds
# BLAST command executed successfully for Q8IUX4.fasta.
# End time (Local): 2024-06-05 00:43:44
# Execution time for Q8IUX4.fasta: 729 minutes and 51.88 seconds
# BLAST command executed successfully for Q99988.fasta.
# End time (Local): 2024-06-05 00:47:52
# Execution time for Q99988.fasta: 733 minutes and 59.79 seconds
# BLAST command executed successfully for P48645.fasta.
# End time (Local): 2024-06-05 00:50:57
# Execution time for P48645.fasta: 737 minutes and 4.74 seconds
# BLAST command executed successfully for Q96BS2.fasta.
# End time (Local): 2024-06-05 00:56:27
# Execution time for Q96BS2.fasta: 742 minutes and 35.34 seconds
# BLAST command executed successfully for P42226.fasta.
# End time (Local): 2024-06-05 01:28:00
# Execution time for P42226.fasta: 774 minutes and 8.07 seconds
# BLAST command failed for P09914.fasta with error: Error: NCBI C++ Exception:
#     T0 "/home/coremake/release_build/build/PrepareRelease_Linux64-Centos_JSID_01_880026_130.14.18.128_9008__PrepareRelease_Linux64-Centos_1697736677/c++/compilers/unix/../../src/serial/rpcbase.cpp", line 325: Error: (CRPCClientException::eFailed) ncbi::CRPCClient_Base::x_Ask() - Failed to receive reply after 3 tries (Blast4-request)
#
#
# End time (Local): 2024-06-05 01:29:36
# Execution time for P09914.fasta: 775 minutes and 44.09 seconds
# BLAST command failed for O75192.fasta with error: Error: NCBI C++ Exception:
#     T0 "/home/coremake/release_build/build/PrepareRelease_Linux64-Centos_JSID_01_880026_130.14.18.128_9008__PrepareRelease_Linux64-Centos_1697736677/c++/compilers/unix/../../src/serial/rpcbase.cpp", line 325: Error: (CRPCClientException::eFailed) ncbi::CRPCClient_Base::x_Ask() - Failed to receive reply after 3 tries (Blast4-request)
#
#
# End time (Local): 2024-06-05 01:31:12
# Execution time for O75192.fasta: 777 minutes and 20.09 seconds
# BLAST command executed successfully for O95399.fasta.
# End time (Local): 2024-06-05 02:18:20
# Execution time for O95399.fasta: 824 minutes and 28.16 seconds
# BLAST command failed for P08949.fasta with error: Error: NCBI C++ Exception:
#     T0 "/home/coremake/release_build/build/PrepareRelease_Linux64-Centos_JSID_01_880026_130.14.18.128_9008__PrepareRelease_Linux64-Centos_1697736677/c++/compilers/unix/../../src/serial/rpcbase.cpp", line 325: Error: (CRPCClientException::eFailed) ncbi::CRPCClient_Base::x_Ask() - Failed to receive reply after 3 tries (Blast4-request)
#
#
# End time (Local): 2024-06-05 02:19:56
# Execution time for P08949.fasta: 826 minutes and 4.20 seconds
# BLAST command failed for Q01453.fasta with error: Error: NCBI C++ Exception:
#     T0 "/home/coremake/release_build/build/PrepareRelease_Linux64-Centos_JSID_01_880026_130.14.18.128_9008__PrepareRelease_Linux64-Centos_1697736677/c++/compilers/unix/../../src/serial/rpcbase.cpp", line 325: Error: (CRPCClientException::eFailed) ncbi::CRPCClient_Base::x_Ask() - Failed to receive reply after 3 tries (Blast4-request)
#
#
# End time (Local): 2024-06-05 02:21:32
# Execution time for Q01453.fasta: 827 minutes and 40.34 seconds
# BLAST command executed successfully for Q10589.fasta.
# End time (Local): 2024-06-05 02:25:50
# Execution time for Q10589.fasta: 831 minutes and 58.10 seconds
# BLAST command executed successfully for Q969E3.fasta.
# End time (Local): 2024-06-05 02:39:18
# Execution time for Q969E3.fasta: 845 minutes and 25.72 seconds
# BLAST command executed successfully for A0A097EV82.fasta.
# End time (Local): 2024-06-05 03:01:07
# Execution time for A0A097EV82.fasta: 867 minutes and 15.39 seconds
# BLAST command executed successfully for P55089.fasta.
# End time (Local): 2024-06-05 03:17:36
# Execution time for P55089.fasta: 883 minutes and 43.89 seconds
# BLAST command executed successfully for O75381.fasta.
# End time (Local): 2024-06-05 03:24:53
# Execution time for O75381.fasta: 891 minutes and 1.28 seconds
# BLAST command executed successfully for Q9P0W0.fasta.
# End time (Local): 2024-06-05 03:37:29
# Execution time for Q9P0W0.fasta: 903 minutes and 37.14 seconds
# BLAST command executed successfully for Q9H293.fasta.
# End time (Local): 2024-06-05 03:53:58
# Execution time for Q9H293.fasta: 920 minutes and 5.55 seconds
# BLAST command executed successfully for Q9BTW9.fasta.
# End time (Local): 2024-06-05 04:10:26
# Execution time for Q9BTW9.fasta: 936 minutes and 34.16 seconds
# BLAST command executed successfully for P42224.fasta.
# End time (Local): 2024-06-05 04:23:02
# Execution time for P42224.fasta: 949 minutes and 9.86 seconds
# BLAST command executed successfully for Q9HC23.fasta.
# End time (Local): 2024-06-05 04:23:48
# Execution time for Q9HC23.fasta: 949 minutes and 56.07 seconds
# BLAST command executed successfully for P01241.fasta.
# End time (Local): 2024-06-05 04:36:25
# Execution time for P01241.fasta: 962 minutes and 32.81 seconds
# BLAST command executed successfully for P01258.fasta.
# End time (Local): 2024-06-05 04:41:55
# Execution time for P01258.fasta: 968 minutes and 3.07 seconds
# BLAST command executed successfully for Q8NG41.fasta.
# End time (Local): 2024-06-05 04:54:30
# Execution time for Q8NG41.fasta: 980 minutes and 38.29 seconds
# BLAST command executed successfully for P10082.fasta.
# End time (Local): 2024-06-05 04:58:38
# Execution time for P10082.fasta: 984 minutes and 46.00 seconds
# BLAST command executed successfully for Q96RP3.fasta.
# End time (Local): 2024-06-05 05:08:18
# Execution time for Q96RP3.fasta: 994 minutes and 25.53 seconds
# BLAST command executed successfully for P01566.fasta.
# End time (Local): 2024-06-05 05:12:27
# Execution time for P01566.fasta: 998 minutes and 34.61 seconds
# BLAST command executed successfully for P01568.fasta.
# End time (Local): 2024-06-05 05:19:45
# Execution time for P01568.fasta: 1005 minutes and 52.85 seconds
# BLAST command executed successfully for P80303.fasta.
# End time (Local): 2024-06-05 05:32:20
# Execution time for P80303.fasta: 1018 minutes and 27.96 seconds
# BLAST command executed successfully for O15130.fasta.
# End time (Local): 2024-06-05 05:39:38
# Execution time for O15130.fasta: 1025 minutes and 45.61 seconds
# BLAST command executed successfully for Q99653.fasta.
# End time (Local): 2024-06-05 05:49:13
# Execution time for Q99653.fasta: 1035 minutes and 20.54 seconds
# BLAST command executed successfully for P01570.fasta.
# End time (Local): 2024-06-05 05:58:48
# Execution time for P01570.fasta: 1044 minutes and 55.55 seconds
# BLAST command executed successfully for P30990.fasta.
# End time (Local): 2024-06-05 06:00:27
# Execution time for P30990.fasta: 1046 minutes and 34.69 seconds
# BLAST command executed successfully for P23582.fasta.
# End time (Local): 2024-06-05 06:02:04
# Execution time for P23582.fasta: 1048 minutes and 12.02 seconds
# BLAST command executed successfully for P42574.fasta.
# End time (Local): 2024-06-05 06:03:44
# Execution time for P42574.fasta: 1049 minutes and 51.94 seconds
# BLAST command executed successfully for P16860.fasta.
# End time (Local): 2024-06-05 06:06:00
# Execution time for P16860.fasta: 1052 minutes and 7.50 seconds
# BLAST command executed successfully for P01579.fasta.
# End time (Local): 2024-06-05 06:08:15
# Execution time for P01579.fasta: 1054 minutes and 22.94 seconds
# BLAST command executed successfully for Q8N729.fasta.
# End time (Local): 2024-06-05 06:15:35
# Execution time for Q8N729.fasta: 1061 minutes and 43.38 seconds
# BLAST command executed successfully for P13164.fasta.
# End time (Local): 2024-06-05 06:19:43
# Execution time for P13164.fasta: 1065 minutes and 50.96 seconds
# BLAST command executed successfully for P18509.fasta.
# End time (Local): 2024-06-05 06:41:15
# Execution time for P18509.fasta: 1087 minutes and 22.99 seconds
# BLAST command executed successfully for P01160.fasta.
# End time (Local): 2024-06-05 06:57:43
# Execution time for P01160.fasta: 1103 minutes and 51.16 seconds
# BLAST command executed successfully for P81605.fasta.
# End time (Local): 2024-06-05 07:14:12
# Execution time for P81605.fasta: 1120 minutes and 19.62 seconds
# BLAST command executed successfully for P09912.fasta.
# End time (Local): 2024-06-05 07:30:40
# Execution time for P09912.fasta: 1136 minutes and 47.75 seconds
# BLAST command executed successfully for Q13325.fasta.
# End time (Local): 2024-06-05 07:43:15
# Execution time for Q13325.fasta: 1149 minutes and 23.02 seconds
# BLAST command executed successfully for P52630.fasta.
# End time (Local): 2024-06-05 07:59:44
# Execution time for P52630.fasta: 1165 minutes and 52.30 seconds
# BLAST command executed successfully for P01210.fasta.
# End time (Local): 2024-06-05 08:16:12
# Execution time for P01210.fasta: 1182 minutes and 20.35 seconds
# BLAST command executed successfully for P40763.fasta.
# End time (Local): 2024-06-05 08:19:17
# Execution time for P40763.fasta: 1185 minutes and 24.98 seconds
# BLAST command executed successfully for P01213.fasta.
# End time (Local): 2024-06-05 08:40:46
# Execution time for P01213.fasta: 1206 minutes and 54.24 seconds
# BLAST command executed successfully for Q01628.fasta.
# End time (Local): 2024-06-05 08:57:15
# Execution time for Q01628.fasta: 1223 minutes and 22.46 seconds
# BLAST command executed successfully for P23142.fasta.
# End time (Local): 2024-06-05 09:01:22
# Execution time for P23142.fasta: 1227 minutes and 30.05 seconds
# BLAST command executed successfully for Q9UHF0.fasta.
# End time (Local): 2024-06-05 09:13:57
# Execution time for Q9UHF0.fasta: 1240 minutes and 5.40 seconds
# BLAST command executed successfully for P51587.fasta.
# End time (Local): 2024-06-05 09:23:34
# Execution time for P51587.fasta: 1249 minutes and 41.50 seconds
# BLAST command executed successfully for P15502.fasta.
# End time (Local): 2024-06-05 10:00:07
# Execution time for P15502.fasta: 1286 minutes and 14.96 seconds
# BLAST command executed successfully for P04637.fasta.
# End time (Local): 2024-06-05 10:46:43
# Execution time for P04637.fasta: 1332 minutes and 50.97 seconds
# BLAST command executed successfully for Q5H8A3.fasta.
# End time (Local): 2024-06-05 10:52:13
# Execution time for Q5H8A3.fasta: 1338 minutes and 21.22 seconds
# BLAST command executed successfully for P55211.fasta.
# End time (Local): 2024-06-05 11:33:48
# Execution time for P55211.fasta: 1379 minutes and 55.98 seconds
# BLAST command executed successfully for Q9Y5Y5.fasta.
# End time (Local): 2024-06-05 12:10:22
# Execution time for Q9Y5Y5.fasta: 1416 minutes and 29.81 seconds
# BLAST command executed successfully for P01303.fasta.
# End time (Local): 2024-06-05 13:07:00
# Execution time for P01303.fasta: 1473 minutes and 7.98 seconds
# BLAST command executed successfully for P01225.fasta.
# End time (Local): 2024-06-05 13:08:09
# Execution time for P01225.fasta: 1474 minutes and 16.47 seconds
# Total execution time: 1474 minutes and 16.47 seconds

# %%
import os
import subprocess
import time
from datetime import datetime, timezone, timedelta

# Function to convert GMT to Dublin local time
def gmt_to_dublin(gmt_time):
    dublin_offset = timedelta(hours=1)
    return gmt_time + dublin_offset

# Paths
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits"
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results"

# Create the blast output directory if it doesn't exist
os.makedirs(blast_output_directory, exist_ok=True)

# Record the start time of the entire process in GMT
start_time = datetime.now(timezone.utc)
start_time_dublin = gmt_to_dublin(start_time)
print(f"Process started at: {start_time_dublin.strftime('%Y-%m-%d %H:%M:%S')} Dublin local time")

def get_accession_id(fasta_file):
    with open(fasta_file, 'r') as file:
        for line in file:
            if line.startswith('>'):
                return line.split()[0][1:]
    return None

# Initialize the file counters
num_files_processed = 0
num_files_skipped = 0

# Iterate through each fasta file in the directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):
        fasta_file = os.path.join(fasta_directory, filename)
        accession_id = get_accession_id(fasta_file)
        if not accession_id:
            print(f"No accession ID found in {filename}, skipping...")
            num_files_skipped += 1
            continue
        
        output_file = os.path.join(blast_output_directory, f"{filename.split('.')[0]}_blastp_results.txt")
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            print(f"Skipping {filename} as output file {output_file} already exists.")
            num_files_skipped += 1
            continue
        
        # Construct the blastp command for remote search
        blastp_command = [
            "blastp",
            "-query", fasta_file,
            "-db", "nr",
            "-out", output_file,
            "-evalue", "0.06",
            "-entrez_query", "viruses[orgn]",
            "-remote"
        ]
        
        # Record start time for this file
        file_start_time = time.time()
        
        # Execute the blastp command
        print(f"Running blast search for {filename} (Accession ID: {accession_id})...")
        try:
            result = subprocess.run(blastp_command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            if result.returncode == 0:
                print(f"BLAST command executed successfully for {filename}.")
            else:
                print(f"BLAST command failed for {filename} with return code {result.returncode}.")
        except subprocess.CalledProcessError as e:
            print(f"BLAST command failed for {filename} with error: {e.stderr.decode()}")
        
        # Calculate elapsed time for this file
        file_elapsed_time = time.time() - file_start_time
        
        # Print filename and elapsed time
        print(f"Blast search for {filename} completed in {file_elapsed_time:.2f} seconds.")
        
        # Increment the file counter
        num_files_processed += 1
        
        # Check if 30 minutes have elapsed since the start of the process
        if (datetime.now(timezone.utc) - start_time).seconds >= 1800:
            print(f"Process has been running for 30 minutes. Current time: {gmt_to_dublin(datetime.now(timezone.utc)).strftime('%Y-%m-%d %H:%M:%S')} Dublin local time")
            start_time = datetime.now(timezone.utc)

print(f"Blastp searches completed for all fasta files. Number of files processed: {num_files_processed}, Number of files skipped: {num_files_skipped}")
# Out:
# Process started at: 2024-07-06 18:02:17 Dublin local time
# Skipping O96011.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/O96011_blastp_results.txt already exists.
# Skipping P07492.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P07492_blastp_results.txt already exists.
# Skipping Q15726.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q15726_blastp_results.txt already exists.
# Skipping P06881.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P06881_blastp_results.txt already exists.
# Skipping P20366.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P20366_blastp_results.txt already exists.
# Skipping P35318.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P35318_blastp_results.txt already exists.
# Skipping P12872.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P12872_blastp_results.txt already exists.
# Skipping O95760.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/O95760_blastp_results.txt already exists.
# Skipping O43745.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/O43745_blastp_results.txt already exists.
# Skipping Q92968.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q92968_blastp_results.txt already exists.
# Skipping P02533.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P02533_blastp_results.txt already exists.
# Skipping Q01629.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q01629_blastp_results.txt already exists.
# Skipping P0C0P6.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P0C0P6_blastp_results.txt already exists.
# Skipping P06400.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P06400_blastp_results.txt already exists.
# Skipping Q03252.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q03252_blastp_results.txt already exists.
# Skipping Q13519.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q13519_blastp_results.txt already exists.
# Skipping P01574.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01574_blastp_results.txt already exists.
# Skipping P19883.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P19883_blastp_results.txt already exists.
# Skipping P01282.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01282_blastp_results.txt already exists.
# Skipping Q9Y5Q6.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q9Y5Q6_blastp_results.txt already exists.
# Skipping Q8IUX4.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q8IUX4_blastp_results.txt already exists.
# Skipping Q99988.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q99988_blastp_results.txt already exists.
# Skipping P48645.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P48645_blastp_results.txt already exists.
# Skipping Q96BS2.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q96BS2_blastp_results.txt already exists.
# Skipping P42226.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P42226_blastp_results.txt already exists.
# Skipping P09914.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P09914_blastp_results.txt already exists.
# Skipping concatenated_no_hits.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/concatenated_no_hits_blastp_results.txt already exists.
# Skipping O75192.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/O75192_blastp_results.txt already exists.
# Skipping O95399.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/O95399_blastp_results.txt already exists.
# Skipping P08949.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P08949_blastp_results.txt already exists.
# Skipping Q01453.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q01453_blastp_results.txt already exists.
# Skipping Q10589.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q10589_blastp_results.txt already exists.
# Skipping Q969E3.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q969E3_blastp_results.txt already exists.
# Skipping A0A097EV82.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/A0A097EV82_blastp_results.txt already exists.
# Skipping P55089.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P55089_blastp_results.txt already exists.
# Skipping O75381.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/O75381_blastp_results.txt already exists.
# Skipping Q9P0W0.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q9P0W0_blastp_results.txt already exists.
# Skipping Q9H293.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q9H293_blastp_results.txt already exists.
# Skipping Q9BTW9.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q9BTW9_blastp_results.txt already exists.
# Skipping P42224.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P42224_blastp_results.txt already exists.
# Skipping Q9HC23.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q9HC23_blastp_results.txt already exists.
# Skipping P01241.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01241_blastp_results.txt already exists.
# Skipping P01258.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01258_blastp_results.txt already exists.
# Skipping Q8NG41.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q8NG41_blastp_results.txt already exists.
# Skipping P10082.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P10082_blastp_results.txt already exists.
# Skipping Q96RP3.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q96RP3_blastp_results.txt already exists.
# Skipping P01566.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01566_blastp_results.txt already exists.
# Skipping P01568.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01568_blastp_results.txt already exists.
# Skipping P80303.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P80303_blastp_results.txt already exists.
# Skipping O15130.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/O15130_blastp_results.txt already exists.
# Skipping Q99653.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q99653_blastp_results.txt already exists.
# Skipping P01570.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01570_blastp_results.txt already exists.
# Skipping P30990.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P30990_blastp_results.txt already exists.
# Skipping P23582.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P23582_blastp_results.txt already exists.
# Skipping P42574.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P42574_blastp_results.txt already exists.
# Skipping P16860.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P16860_blastp_results.txt already exists.
# Skipping P01579.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01579_blastp_results.txt already exists.
# Skipping Q8N729.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q8N729_blastp_results.txt already exists.
# Skipping P13164.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P13164_blastp_results.txt already exists.
# Skipping P18509.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P18509_blastp_results.txt already exists.
# Skipping P01160.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01160_blastp_results.txt already exists.
# Skipping P81605.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P81605_blastp_results.txt already exists.
# Skipping P09912.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P09912_blastp_results.txt already exists.
# Skipping Q13325.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q13325_blastp_results.txt already exists.
# Skipping P52630.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P52630_blastp_results.txt already exists.
# Skipping P01210.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01210_blastp_results.txt already exists.
# Skipping P40763.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P40763_blastp_results.txt already exists.
# Skipping P01213.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01213_blastp_results.txt already exists.
# Skipping Q01628.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q01628_blastp_results.txt already exists.
# Skipping P23142.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P23142_blastp_results.txt already exists.
# Skipping Q9UHF0.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q9UHF0_blastp_results.txt already exists.
# Skipping P51587.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P51587_blastp_results.txt already exists.
# Skipping P15502.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P15502_blastp_results.txt already exists.
# Skipping P04637.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P04637_blastp_results.txt already exists.
# Skipping Q5H8A3.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q5H8A3_blastp_results.txt already exists.
# Skipping P55211.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P55211_blastp_results.txt already exists.
# Skipping Q9Y5Y5.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Q9Y5Y5_blastp_results.txt already exists.
# Skipping P01303.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01303_blastp_results.txt already exists.
# Skipping P01225.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/P01225_blastp_results.txt already exists.
# Blastp searches completed for all fasta files. Number of files processed: 0, Number of files skipped: 79

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/"

# Name of the master file
master_filename = "Vir_nr_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Vir_nr_master_blaster.txt

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Vir_nr_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line: 
                current_query_id = line.split("|")[1].strip()  
            elif ">" in line:  
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  

    # Calculate total hits for each accession ID
    total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

    # Rank and print total hits
    print("Ranked total hits for each accession ID:")
    for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
        print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")

    # Write results to CSV file
    output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Vir_nr_hit.csv"
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Query ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in query_hits.items():
            writer.writerow({'Query ID': query_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)
# Out:
# Ranked total hits for each accession ID:
# 1. Accession ID: P42574, Total Hits: 1
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/nr_blastp_results/Vir_nr_hit.csv'

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## Refseq Search

# %%
import os
import subprocess
import time
from datetime import datetime, timezone, timedelta

# Function to convert GMT to Dublin local time
def gmt_to_dublin(gmt_time):
    dublin_offset = timedelta(hours=1)  
    return gmt_time + dublin_offset

# Paths
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits"
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/"

# Create the blast output directory if it doesn't exist
os.makedirs(blast_output_directory, exist_ok=True)

# Record the start time of the entire process in GMT
start_time = datetime.now(timezone.utc)
start_time_dublin = gmt_to_dublin(start_time)
print(f"Process started at: {start_time_dublin.strftime('%Y-%m-%d %H:%M:%S')} Dublin local time")

def get_accession_id(fasta_file):
    with open(fasta_file, 'r') as file:
        for line in file:
            if line.startswith('>'):
                return line.split()[0][1:]  
    return None

# Initialize the file counters
num_files_processed = 0
num_files_skipped = 0

# Iterate through each fasta file in the directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):
        fasta_file = os.path.join(fasta_directory, filename)
        accession_id = get_accession_id(fasta_file)
        if not accession_id:
            print(f"No accession ID found in {filename}, skipping...")
            num_files_skipped += 1
            continue
        
        output_file = os.path.join(blast_output_directory, f"{filename.split('.')[0]}_blastp_results.txt")
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            print(f"Skipping {filename} as output file {output_file} already exists.")
            num_files_skipped += 1
            continue
        
        # Construct the blastp command for remote search
        blastp_command = [
            "blastp",
            "-query", fasta_file,
            "-db", "refseq_protein",
            "-out", output_file,
            "-evalue", "0.06",
            "-entrez_query", "viruses[orgn]",
            "-remote"
        ]
        
        # Record start time for this file
        file_start_time = time.time()
        
        # Execute the blastp command
        print(f"Running blast search for {filename} (Accession ID: {accession_id})...")
        try:
            result = subprocess.run(blastp_command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            if result.returncode == 0:
                print(f"BLAST command executed successfully for {filename}.")
            else:
                print(f"BLAST command failed for {filename} with return code {result.returncode}.")
        except subprocess.CalledProcessError as e:
            print(f"BLAST command failed for {filename} with error: {e.stderr.decode()}")
        
        # Calculate elapsed time for this file
        file_elapsed_time = time.time() - file_start_time
        
        # Print filename and elapsed time
        print(f"Blast search for {filename} completed in {file_elapsed_time:.2f} seconds.")
        
        # Increment the file counter
        num_files_processed += 1
        
        # Check if 30 minutes have elapsed since the start of the process
        if (datetime.now(timezone.utc) - start_time).seconds >= 1800:
            print(f"Process has been running for 30 minutes. Current time: {gmt_to_dublin(datetime.now(timezone.utc)).strftime('%Y-%m-%d %H:%M:%S')} Dublin local time")
            start_time = datetime.now(timezone.utc)

print(f"Blastp searches completed for all fasta files. Number of files processed: {num_files_processed}, Number of files skipped: {num_files_skipped}")
# Out:
# Process started at: 2024-07-06 18:25:39 Dublin local time
# Skipping O96011.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/O96011_blastp_results.txt already exists.
# Skipping P07492.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P07492_blastp_results.txt already exists.
# Skipping Q15726.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q15726_blastp_results.txt already exists.
# Skipping P06881.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P06881_blastp_results.txt already exists.
# Skipping P20366.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P20366_blastp_results.txt already exists.
# Skipping P35318.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P35318_blastp_results.txt already exists.
# Skipping P12872.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P12872_blastp_results.txt already exists.
# Skipping O95760.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/O95760_blastp_results.txt already exists.
# Skipping O43745.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/O43745_blastp_results.txt already exists.
# Skipping Q92968.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q92968_blastp_results.txt already exists.
# Skipping P02533.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P02533_blastp_results.txt already exists.
# Skipping Q01629.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q01629_blastp_results.txt already exists.
# Skipping P0C0P6.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P0C0P6_blastp_results.txt already exists.
# Skipping P06400.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P06400_blastp_results.txt already exists.
# Skipping Q03252.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q03252_blastp_results.txt already exists.
# Skipping Q13519.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q13519_blastp_results.txt already exists.
# Skipping P01574.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01574_blastp_results.txt already exists.
# Skipping P19883.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P19883_blastp_results.txt already exists.
# Skipping P01282.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01282_blastp_results.txt already exists.
# Skipping Q9Y5Q6.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q9Y5Q6_blastp_results.txt already exists.
# Skipping Q8IUX4.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q8IUX4_blastp_results.txt already exists.
# Skipping Q99988.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q99988_blastp_results.txt already exists.
# Skipping P48645.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P48645_blastp_results.txt already exists.
# Skipping Q96BS2.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q96BS2_blastp_results.txt already exists.
# Skipping P42226.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P42226_blastp_results.txt already exists.
# Skipping P09914.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P09914_blastp_results.txt already exists.
# Skipping concatenated_no_hits.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/concatenated_no_hits_blastp_results.txt already exists.
# Skipping O75192.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/O75192_blastp_results.txt already exists.
# Skipping O95399.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/O95399_blastp_results.txt already exists.
# Skipping P08949.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P08949_blastp_results.txt already exists.
# Skipping Q01453.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q01453_blastp_results.txt already exists.
# Skipping Q10589.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q10589_blastp_results.txt already exists.
# Skipping Q969E3.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q969E3_blastp_results.txt already exists.
# Skipping A0A097EV82.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/A0A097EV82_blastp_results.txt already exists.
# Skipping P55089.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P55089_blastp_results.txt already exists.
# Skipping O75381.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/O75381_blastp_results.txt already exists.
# Skipping Q9P0W0.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q9P0W0_blastp_results.txt already exists.
# Skipping Q9H293.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q9H293_blastp_results.txt already exists.
# Skipping Q9BTW9.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q9BTW9_blastp_results.txt already exists.
# Skipping P42224.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P42224_blastp_results.txt already exists.
# Skipping Q9HC23.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q9HC23_blastp_results.txt already exists.
# Skipping P01241.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01241_blastp_results.txt already exists.
# Skipping P01258.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01258_blastp_results.txt already exists.
# Skipping Q8NG41.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q8NG41_blastp_results.txt already exists.
# Skipping P10082.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P10082_blastp_results.txt already exists.
# Skipping Q96RP3.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q96RP3_blastp_results.txt already exists.
# Skipping P01566.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01566_blastp_results.txt already exists.
# Skipping P01568.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01568_blastp_results.txt already exists.
# Skipping P80303.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P80303_blastp_results.txt already exists.
# Skipping O15130.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/O15130_blastp_results.txt already exists.
# Skipping Q99653.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q99653_blastp_results.txt already exists.
# Skipping P01570.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01570_blastp_results.txt already exists.
# Skipping P30990.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P30990_blastp_results.txt already exists.
# Skipping P23582.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P23582_blastp_results.txt already exists.
# Skipping P42574.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P42574_blastp_results.txt already exists.
# Skipping P16860.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P16860_blastp_results.txt already exists.
# Skipping P01579.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01579_blastp_results.txt already exists.
# Skipping Q8N729.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q8N729_blastp_results.txt already exists.
# Skipping P13164.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P13164_blastp_results.txt already exists.
# Skipping P18509.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P18509_blastp_results.txt already exists.
# Skipping P01160.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01160_blastp_results.txt already exists.
# Skipping P81605.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P81605_blastp_results.txt already exists.
# Skipping P09912.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P09912_blastp_results.txt already exists.
# Skipping Q13325.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q13325_blastp_results.txt already exists.
# Skipping P52630.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P52630_blastp_results.txt already exists.
# Skipping P01210.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01210_blastp_results.txt already exists.
# Skipping P40763.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P40763_blastp_results.txt already exists.
# Skipping P01213.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01213_blastp_results.txt already exists.
# Skipping Q01628.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q01628_blastp_results.txt already exists.
# Skipping P23142.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P23142_blastp_results.txt already exists.
# Skipping Q9UHF0.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q9UHF0_blastp_results.txt already exists.
# Skipping P51587.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P51587_blastp_results.txt already exists.
# Skipping P15502.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P15502_blastp_results.txt already exists.
# Skipping P04637.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P04637_blastp_results.txt already exists.
# Skipping Q5H8A3.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q5H8A3_blastp_results.txt already exists.
# Skipping P55211.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P55211_blastp_results.txt already exists.
# Skipping Q9Y5Y5.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Q9Y5Y5_blastp_results.txt already exists.
# Skipping P01303.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01303_blastp_results.txt already exists.
# Skipping P01225.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/P01225_blastp_results.txt already exists.
# Blastp searches completed for all fasta files. Number of files processed: 0, Number of files skipped: 79

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %%
# !mv /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/concatenated_no_hits_blastp_results.txt /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/

# %% [markdown]
# ## Combine results from Refseq Search

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/"

# Name of the master file
master_filename = "Vir_refseq_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Vir_refseq_master_blaster.txt

# %% [markdown]
# ## Processing

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Vir_refseq_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line: 
                current_query_id = line.split("|")[1].strip()  
            elif ">" in line:  
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  

    # Calculate total hits for each accession ID
    total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

    # Rank and print total hits
    print("Ranked total hits for each accession ID:")
    for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
        print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")

    # Write results to CSV file
    output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Vir_refseq_hit.csv"
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Query ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in query_hits.items():
            writer.writerow({'Query ID': query_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)
# Out:
# Ranked total hits for each accession ID:
# 1. Accession ID: P02533, Total Hits: 24
# 2. Accession ID: Q03252, Total Hits: 20
# 3. Accession ID: P42574, Total Hits: 12
# 4. Accession ID: Q99988, Total Hits: 4
# 5. Accession ID: P15502, Total Hits: 3
# 6. Accession ID: P01241, Total Hits: 3
# 7. Accession ID: Q96BS2, Total Hits: 3
# 8. Accession ID: P52630, Total Hits: 3
# 9. Accession ID: Q10589, Total Hits: 3
# 10. Accession ID: P10082, Total Hits: 3
# 11. Accession ID: P01570, Total Hits: 3
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Vir_refseq_hit.csv'

# %%
import csv

# Path to the input text file
input_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Vir_refseq_master_blaster.txt"

# Path to the output CSV file
output_csv_path = '/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Vir_refseq_hit.csv'

# Initialize lists to store accession IDs and hit names
accession_ids = []
hit_names = []

# Read the input file and extract accession IDs and hit names
try:
    with open(input_file_path, "r") as input_file:
        current_accession_id = None
        for line in input_file:
            if "|" in line:
                current_accession_id = line.split("|")[1].strip()
            elif line.startswith(">"):
                if current_accession_id:
                    accession_ids.append(current_accession_id)
                    hit_name = line.strip()[1:] 
                    hit_names.append(hit_name)
except FileNotFoundError:
    print(f"Error: File '{input_file_path}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Write accession IDs and hit names to CSV file
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(["Accession ID", "Hit Name"])  
        for accession_id, hit_name in zip(accession_ids, hit_names):
            writer.writerow([accession_id, hit_name])
    print(f"Accession IDs and hit names saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Accession IDs and hit names saved to '/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/Vir_refseq_hit.csv'

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir =  "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/refseq_blastp_results/comp_Vir_refseq_data.csv"

# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Parse out required data from blast reaults
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        query_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0 
        hit_id = None 
        species_id = None 
        seq_length = None  
        evalue = None 
        score = None  
        identities = None  
        identities_percent = None
        positives = None 
        positives_percent = None  
        gaps = None  
        gaps_percent = None  
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1 
                hit_id = line.split(">")[1].split(" ")[0]
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
               

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
            elif hit_id and "Expect =" in line:
                evalue = line.split("Expect = ")[1].split(",")[0].strip()
                score = line.split("Score = ")[1].split(" bits")[0].strip()
            elif hit_id and "Identities =" in line:
                identities_str = line.split("Identities = ")[1].split(",")[0].strip()
                identities = identities_str.split(" ")[0]
                identities_fraction = identities.split("/")
                identities_percent = (int(identities_fraction[0]) / int(identities_fraction[1])) * 100
                positives_str = line.split("Positives = ")[1].split(",")[0].strip()
                positives = positives_str.split(" ")[0]
                positives_fraction = positives.split("/")
                positives_percent = (int(positives_fraction[0]) / int(positives_fraction[1])) * 100
                gaps_str = line.split("Gaps = ")[1].split(" ")[0].strip()
                gaps = gaps_str
                gaps_fraction = gaps.split("/")
                gaps_percent = (int(gaps_fraction[0]) / int(gaps_fraction[1])) * 100
                # Append all values to hits_data
                hits_data.append([
                    query_id, hit_id, hit_number, seq_length, species_id, evalue, score, 
                    identities, f"{identities_percent:.2f}%", positives, f"{positives_percent:.2f}%", gaps, f"{gaps_percent:.2f}%"
                ])
    return hits_data

# List to store parsed data
parsed_data = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"): 
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow([
        'Query ID', 'Hit ID', 'Hit Number', 'Sequence Length', 'Species ID', 'Evalue', 'Score', 
        'Identities', 'Identities (%)', 'Positives', 'Positives (%)', 'Gaps', 'Gaps (%)'
    ])
    # Write parsed data
    writer.writerows(parsed_data)

print("CSV file created successfully")
# Out:
# CSV file created successfully

# %% [markdown]
# ### Move Fasta's back

# %%
import os
import shutil

# Path to the directory containing the fasta files
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta/"

# Destination directory to move the fasta files
destination_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/matching_fasta_files/"

# Create the destination directory if it doesn't exist
os.makedirs(destination_directory, exist_ok=True)

# Counter for the number of files moved
files_moved_count = 0

# Iterate through each fasta file in the directory
for fasta_filename in os.listdir(fasta_directory):
    # Check if the file is a fasta file
    if fasta_filename.endswith(".fasta"):
        # Extract accession ID from the filename
        accession_id = fasta_filename.split("_")[0]
        
        # Check if the accession ID is in the blast results
        if accession_id in query_hits:
            # Path to the fasta file
            fasta_filepath = os.path.join(fasta_directory, fasta_filename)
            
            # Move the fasta file to the destination directory
            shutil.move(fasta_filepath, destination_directory)
            
            # Increment the count of files moved
            files_moved_count += 1
            
            print(f"Moved {fasta_filename} to {destination_directory}")

print(f"Finished moving {files_moved_count} fasta files.")
# Out:
# Finished moving 0 fasta files.

# %% [markdown]
# #

# %%
import os

# Paths
no_hits_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits"
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/nr_blastp_results"
blast_executable = "/home/osheakes/Research_Project_MMM/Fasta/ncbi-blast-2.15.0+/bin/tblastn_vdb"
db = "viruses_wgs"

# Check if the no_hits directory exists
if not os.path.isdir(no_hits_directory):
    raise FileNotFoundError(f"Directory not found: {no_hits_directory}")
else:
    print(f"Directory found: {no_hits_directory}")

# Check if the blast_output directory exists (if not, create it)
if not os.path.isdir(blast_output_directory):
    os.makedirs(blast_output_directory)
    print(f"Directory created: {blast_output_directory}")
else:
    print(f"Directory found: {blast_output_directory}")

# Check if the BLAST executable exists and is executable
if not os.path.isfile(blast_executable):
    raise FileNotFoundError(f"BLAST executable not found: {blast_executable}")
elif not os.access(blast_executable, os.X_OK):
    raise PermissionError(f"BLAST executable is not executable: {blast_executable}")
else:
    print(f"BLAST executable found and is executable: {blast_executable}")

# Check if there are any .fasta files in the no_hits directory
fasta_files = [f for f in os.listdir(no_hits_directory) if f.endswith(".fasta")]
if not fasta_files:
    raise FileNotFoundError(f"No .fasta files found in: {no_hits_directory}")
else:
    print(f"Found {len(fasta_files)} .fasta file(s) in: {no_hits_directory}")

print("Environment and path checks completed successfully.")
# Out:
# Directory found: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Directory found: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/nr_blastp_results
# BLAST executable found and is executable: /home/osheakes/Research_Project_MMM/Fasta/ncbi-blast-2.15.0+/bin/tblastn_vdb
# Found 79 .fasta file(s) in: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/no_hits
# Environment and path checks completed successfully.

# %% [markdown]
# #

# %% [markdown]
# ## 1.5 Creation of Master Blast file

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts"

# Name of the master file
master_filename = "viral_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blast_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/viral_master_blaster.txt

# %%
import pandas as pd
import re

# Load the data from the CSV file
data = pd.read_csv("/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/fmt5/VB_Results.csv")

# Define search
pattern = r'\bhuman\b'

# Initialize count
human_count = 0

# Iterate over each row
for index, row in data.iterrows():
    if re.search(pattern, str(row['Species']), flags=re.IGNORECASE):
        human_count += 1

# Print the count
print(human_count)

# Filter rows
human_entries = data[data['Species'].str.contains('Human', case=False)]

# Save to CSV file
human_entries.to_csv("human_entries.csv", index=False)
# Out:
# 616

# %% [markdown]
# ## 1.6 Create Counter to identify which query had the most hits across the Viral database

# %%
from collections import Counter

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/viral_master_blaster.txt"

# Read the contents of the master file
with open(master_filepath, "r") as master_file:
    # Read all lines from the file
    lines = master_file.readlines()

# Extract query sequence IDs from each line
query_ids = [line.split()[0] for line in lines if line.strip()]

# Count the occurrences of each query ID
query_counts = Counter(query_ids)

# Sort the queries based on the number of hits (descending order)
ranked_queries = sorted(query_counts.items(), key=lambda x: x[1], reverse=True)

# Print the ranked list of queries
print("Ranked list of queries based on the number of hits:")
for rank, (query, count) in enumerate(ranked_queries, start=1):
    print(f"{rank}. Query ID: {query}, Hits: {count}")
# Out:
# Ranked list of queries based on the number of hits:
# 1. Query ID: sp|Q02388|CO7A1_HUMAN, Hits: 14725
# 2. Query ID: sp|P19838|NFKB1_HUMAN, Hits: 1757
# 3. Query ID: #, Hits: 1499
# 4. Query ID: sp|Q15303|ERBB4_HUMAN, Hits: 1487
# 5. Query ID: sp|P19525|E2AK2_HUMAN, Hits: 1435
# 6. Query ID: sp|Q00534|CDK6_HUMAN, Hits: 1165
# 7. Query ID: sp|P06493|CDK1_HUMAN, Hits: 1127
# 8. Query ID: sp|Q00526|CDK3_HUMAN, Hits: 1121
# 9. Query ID: sp|P24941|CDK2_HUMAN, Hits: 1063
# 10. Query ID: sp|P11802|CDK4_HUMAN, Hits: 1019
# 11. Query ID: sp|Q00535|CDK5_HUMAN, Hits: 1011
# 12. Query ID: sp|Q8NFJ6|PKR2_HUMAN, Hits: 1001
# 13. Query ID: sp|P32247|BRS3_HUMAN, Hits: 1001
# 14. Query ID: sp|P43490|NAMPT_HUMAN, Hits: 1001
# 15. Query ID: sp|P46663|BKRB1_HUMAN, Hits: 1001
# 16. Query ID: sp|P01019|ANGT_HUMAN, Hits: 1001
# 17. Query ID: sp|P55265|DSRAD_HUMAN, Hits: 919
# 18. Query ID: sp|Q9Y3Z3|SAMH1_HUMAN, Hits: 231
# 19. Query ID: sp|P47898|5HT5A_HUMAN, Hits: 141
# 20. Query ID: sp|P25445|TNR6_HUMAN, Hits: 141
# 21. Query ID: sp|P20591|MX1_HUMAN, Hits: 63
# 22. Query ID: sp|P20592|MX2_HUMAN, Hits: 61
# 23. Query ID: sp|O95786|RIGI_HUMAN, Hits: 37
# 24. Query ID: sp|P38398|BRCA1_HUMAN, Hits: 37
# 25. Query ID: sp|O43808|PM34_HUMAN, Hits: 33
# 26. Query ID: sp|P01344|IGF2_HUMAN, Hits: 29
# 27. Query ID: sp|P55210|CASP7_HUMAN, Hits: 21
# 28. Query ID: sp|Q07812|BAX_HUMAN, Hits: 21
# 29. Query ID: sp|Q16611|BAK_HUMAN, Hits: 13
# 30. Query ID: sp|P06396|GELS_HUMAN, Hits: 13
# 31. Query ID: sp|O95390|GDF11_HUMAN, Hits: 9
# 32. Query ID: sp|O14879|IFIT3_HUMAN, Hits: 9
# 33. Query ID: sp|P60484|PTEN_HUMAN, Hits: 9
# 34. Query ID: sp|Q14790|CASP8_HUMAN, Hits: 7
# 35. Query ID: sp|P42574|CASP3_HUMAN, Hits: 7
# 36. Query ID: sp|P56199|ITA1_HUMAN, Hits: 5
# 37. Query ID: sp|Q7Z2W4|ZCCHV_HUMAN, Hits: 5
# 38. Query ID: sp|Q12965|MYO1E_HUMAN, Hits: 5
# 39. Query ID: sp|P10645|CMGA_HUMAN, Hits: 5
# 40. Query ID: sp|P01966|HBA_BOVIN, Hits: 3
# 41. Query ID: sp|Q14765|STAT4_HUMAN, Hits: 3
# 42. Query ID: sp|O00910|STATA_DICDI, Hits: 3

# %% [markdown]
# ## 1.7 Cleaning up of dataset

# %%
# Filter out lines with query ID "#"
filtered_queries = [(query, count) for query, count in ranked_queries if query != "#"]

# %% [markdown]
# ## 1.8 Create a Ranked table of the dataset

# %%
import csv

# Path to the output CSV file with the desired file name
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/Ranked_Hits_Tab.csv"

# Write the filtered list of queries to a CSV file
with open(output_csv_path, "w", newline="") as csv_file:
    # Create a CSV writer object
    csv_writer = csv.writer(csv_file)
    
    # Write the header row without the "Rank" column
    csv_writer.writerow(["Query ID", "Hits"])
    
    # Write each ranked query to the CSV file without the rank
    for query, count in filtered_queries:
        csv_writer.writerow([query, count])

print("Ranked list of queries (excluding '#') saved to:", output_csv_path)
# Out:
# Ranked list of queries (excluding '#') saved to: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/Ranked_Hits_Tab.csv

# %% [markdown]
# ## 1.9 Create a filtered Viral Masterfile

# %%
# Read query IDs from Ranked_Hits_Tab.csv
query_ids_from_csv = set()
with open("/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/Ranked_Hits_Tab.csv", "r") as csv_file:
    next(csv_file)  # Skip header row
    for line in csv_file:
        query_id = line.strip().split(",")[0]
        query_ids_from_csv.add(query_id)

# Create a new .txt file to store filtered results
output_txt_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/filtered_viral_master_blaster.txt"
with open("/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/viral_master_blaster.txt", "r") as input_file, open(output_txt_path, "w") as output_file:
    for line in input_file:
        query_id = line.strip().split("\t")[0]
        if query_id in query_ids_from_csv:
            output_file.write(line)

print(f"Filtered results saved to {output_txt_path}")
# Out:
# Filtered results saved to /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/filtered_viral_master_blaster.txt

# %% [markdown]
# ## 1.10 Create a Ranked Table for Sequence Homology

# %%
import csv

# Read the lines from the file
with open("/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/filtered_viral_master_blaster.txt", "r") as input_file:
    lines = input_file.readlines()

# Sort the lines based on the third column (sequence homology score) from highest to lowest
sorted_lines = sorted(lines, key=lambda x: float(x.strip().split("\t")[2]), reverse=True)

# Write the sorted lines to a CSV file with the header row
output_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/Ranked_Homology_Hits.csv"
with open(output_file_path, "w", newline="") as output_file:
    csv_writer = csv.writer(output_file)
    
    # Write the header row
    csv_writer.writerow(["query acc.ver", "subject acc.ver", "% identity", "alignment length", "mismatches", "gap opens", "q. start", "q. end", "s. start", "s. end", "evalue", "bit score"])
    
    # Write the sorted lines to the CSV file
    for line in sorted_lines:
        csv_writer.writerow(line.strip().split("\t"))

print(f"Ranked hits saved to: {output_file_path}")
# Out:
# Ranked hits saved to: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/Ranked_Homology_Hits.csv

# %% [markdown]
# ## 1.11 Retrieve Sequencing Data from Queries which Returned Hits

# %%
# !mkdir  /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq

# %%
import pandas as pd

# Path to the file
file_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/Ranked_Homology_Hits.csv"

# Read the file into a DataFrame
df = pd.read_csv(file_path, delimiter="\t")  # Adjust delimiter if necessary

# Count the unique Accession IDs
unique_accession_ids = df['Accession ID'].nunique()

# Print the number of unique Accession IDs
print(f"Number of unique Accession IDs: {unique_accession_ids}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/jupyterhub/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Accession ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-324480650910> in <module>
#       8
#       9 # Count the unique Accession IDs
# ---> 10 unique_accession_ids = df['Accession ID'].nunique()
#      11
#      12 # Print the number of unique Accession IDs
#
# /opt/jupyterhub/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /opt/jupyterhub/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Accession ID'

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # 2.0 Bacterial Blast

# %%
# !mkdir Bacterial_Blasts

# %%
# !blastp -db nr -query P01225.fasta -out P01225_TEST.txt -evalue 0.06 -remote -entrez_query "bacteria[orgn]"

# %%
import subprocess
import os

# Path to the directory containing fasta files
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta"

# Directory to store blast results
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts"

# Create the blast output directory if it doesn't exist
os.makedirs(blast_output_directory, exist_ok=True)

# Iterate through each fasta file in the directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):  
        fasta_file = os.path.join(fasta_directory, filename)
        output_file = os.path.join(blast_output_directory, f"{os.path.splitext(filename)[0]}_blastp_results.txt")
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            print(f"Skipping {filename} as output file already exists.")
            continue
        
        # Construct the blastp command
        blastp_command = [
            "blastp",
            "-db",
            "nr",
            "-query",
            fasta_file,
            "-out",
            output_file,
            "-evalue",
            "0.06",
            "-remote",
            "-entrez_query",
            "bacteria[orgn]"
        ]
        
        # Execute the blastp command
        subprocess.run(blastp_command)
        

print("Blastp searches completed for all fasta files.")
# Out:
# Skipping O96011.fasta as output file already exists.
# Skipping Q07812.fasta as output file already exists.
# Skipping Q8NFJ6.fasta as output file already exists.
# Skipping P07492.fasta as output file already exists.
# Skipping Q15303.fasta as output file already exists.
# Skipping Q15726.fasta as output file already exists.
# Skipping O00910.fasta as output file already exists.
# Skipping P38398.fasta as output file already exists.
# Skipping P06881.fasta as output file already exists.
# Skipping P46663.fasta as output file already exists.
# Skipping P32247.fasta as output file already exists.
# Skipping P60484.fasta as output file already exists.
# Skipping P20366.fasta as output file already exists.
# Skipping P35318.fasta as output file already exists.
# Skipping P12872.fasta as output file already exists.
# Skipping P10645.fasta as output file already exists.
# Skipping O95760.fasta as output file already exists.
# Skipping P01344.fasta as output file already exists.
# Skipping O14879.fasta as output file already exists.
# Skipping Q08722.fasta as output file already exists.
# Skipping O43745.fasta as output file already exists.
# Skipping Q92968.fasta as output file already exists.
# Skipping O95390.fasta as output file already exists.
# Skipping P02533.fasta as output file already exists.
# Skipping Q01629.fasta as output file already exists.
# Skipping P0C0P6.fasta as output file already exists.
# Skipping Q00534.fasta as output file already exists.
# Skipping P20592.fasta as output file already exists.
# Skipping Q13519.fasta as output file already exists.
# Skipping P01282.fasta as output file already exists.
# Skipping Q8IUX4.fasta as output file already exists.
# Skipping Q99988.fasta as output file already exists.
# Skipping P48645.fasta as output file already exists.
# Skipping O75192.fasta as output file already exists.
# Skipping O95399.fasta as output file already exists.
# Skipping P08949.fasta as output file already exists.
# Skipping Q969E3.fasta as output file already exists.
# Skipping A0A097EV82.fasta as output file already exists.
# Skipping P55089.fasta as output file already exists.
# Skipping Q9P0W0.fasta as output file already exists.
# Skipping Q9H293.fasta as output file already exists.
# Skipping Q9HC23.fasta as output file already exists.
# Skipping P01258.fasta as output file already exists.
# Skipping Q8NG41.fasta as output file already exists.
# Skipping P10082.fasta as output file already exists.
# Skipping Q96RP3.fasta as output file already exists.
# Skipping P01566.fasta as output file already exists.

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # 3.0 Archaeal Blast

# %%
# !mkdir Archaeal_Blasts

# %% [markdown]
# ## 3.1 Run Archaeal Blast

# %%
import subprocess
import os
import time
from datetime import datetime, timezone

# Path to the directory containing fasta files
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta"

# Directory to store blast results
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts"

# Create the blast output directory if it doesn't exist
os.makedirs(blast_output_directory, exist_ok=True)

# Record the start time of the entire process in GMT
start_time = datetime.now(timezone.utc)
print(f"Process started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')} GMT")

# Iterate through each fasta file in the directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):  
        fasta_file = os.path.join(fasta_directory, filename)
        output_file = os.path.join(blast_output_directory, f"{os.path.splitext(filename)[0]}_blastp_results.txt")
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            print(f"Skipping {filename} as output file already exists.")
            continue
        
        # Construct the blastp command
        blastp_command = [
            "blastp",
            "-db",
            "nr",
            "-query",
            fasta_file,
            "-out",
            output_file,
            "-evalue",
            "0.06",
            "-remote",
            "-entrez_query",
            "archaea[orgn]"
        ]
        
        # Record start time for this file
        file_start_time = time.time()
        
        # Execute the blastp command
        print(f"Running blast search for {filename}...")
        subprocess.run(blastp_command)
        
        # Calculate elapsed time for this file
        file_elapsed_time = time.time() - file_start_time
        
        # Print filename and elapsed time
        print(f"Blast search for {filename} completed in {file_elapsed_time:.2f} seconds.")
        
        # Check if 30 minutes have elapsed since the start of the process
        if (datetime.now(timezone.utc) - start_time).seconds >= 1800:
            print(f"Process has been running for 30 minutes. Current time: {datetime.now(timezone.utc).strftime('%Y-%m-%d %H:%M:%S')} GMT")
            start_time = datetime.now(timezone.utc)  

print("Blastp searches completed for all fasta files.")
# Out:
# Process started at: 2024-05-02 20:59:15 GMT
# Running blast search for O96011.fasta...
# Blast search for O96011.fasta completed in 18161.19 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-03 02:01:56 GMT
# Running blast search for Q07812.fasta...
# Blast search for Q07812.fasta completed in 4905.02 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-03 03:23:41 GMT
# Running blast search for Q8NFJ6.fasta...
# Blast search for Q8NFJ6.fasta completed in 7622.79 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-03 05:30:44 GMT
# Running blast search for P07492.fasta...
# Blast search for P07492.fasta completed in 7013.17 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-03 07:27:37 GMT
# Running blast search for Q15303.fasta...
# Blast search for Q15303.fasta completed in 7326.64 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-03 09:29:44 GMT
# Running blast search for Q15726.fasta...
# Blast search for Q15726.fasta completed in 6410.34 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-03 11:16:34 GMT
# Running blast search for O00910.fasta...
# Blast search for O00910.fasta completed in 7918.89 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-03 13:28:33 GMT
# Running blast search for P38398.fasta...
# Blast search for P38398.fasta completed in 20881.04 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-03 19:16:34 GMT
# Running blast search for P06881.fasta...
# Blast search for P06881.fasta completed in 15151.98 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-03 23:29:06 GMT
# Running blast search for P46663.fasta...
# Blast search for P46663.fasta completed in 9424.94 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 02:06:11 GMT
# Running blast search for P32247.fasta...
# Blast search for P32247.fasta completed in 12660.05 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 05:37:11 GMT
# Running blast search for P60484.fasta...
# Blast search for P60484.fasta completed in 107.31 seconds.
# Running blast search for P20366.fasta...
# Blast search for P20366.fasta completed in 3097.21 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 06:30:35 GMT
# Running blast search for P35318.fasta...
# Blast search for P35318.fasta completed in 247.97 seconds.
# Running blast search for P12872.fasta...
# Blast search for P12872.fasta completed in 330.19 seconds.
# Running blast search for P10645.fasta...
# Blast search for P10645.fasta completed in 1289.84 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 07:01:43 GMT
# Running blast search for O95760.fasta...
# Blast search for O95760.fasta completed in 988.63 seconds.
# Running blast search for P01344.fasta...
# Blast search for P01344.fasta completed in 755.54 seconds.
# Running blast search for O14879.fasta...
# Blast search for O14879.fasta completed in 199.85 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 07:34:07 GMT
# Running blast search for O43745.fasta...
# Blast search for O43745.fasta completed in 758.55 seconds.
# Running blast search for Q92968.fasta...
# Blast search for Q92968.fasta completed in 138.22 seconds.
# Running blast search for O95390.fasta...
# Blast search for O95390.fasta completed in 330.19 seconds.
# Running blast search for P02533.fasta...
# Blast search for P02533.fasta completed in 187.50 seconds.
# Running blast search for Q01629.fasta...
# Blast search for Q01629.fasta completed in 437.44 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 08:04:59 GMT
# Running blast search for P0C0P6.fasta...
# Blast search for P0C0P6.fasta completed in 248.07 seconds.
# Running blast search for Q00534.fasta...
# Blast search for Q00534.fasta completed in 146.93 seconds.
# Running blast search for P20592.fasta...
# Blast search for P20592.fasta completed in 250.90 seconds.
# Running blast search for P06493.fasta...
# Blast search for P06493.fasta completed in 447.08 seconds.
# Running blast search for P06400.fasta...
# Blast search for P06400.fasta completed in 185.05 seconds.
# Running blast search for Q03252.fasta...
# Blast search for Q03252.fasta completed in 437.21 seconds.
# Running blast search for P24941.fasta...
# Blast search for P24941.fasta completed in 340.10 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 08:39:15 GMT
# Running blast search for Q13519.fasta...
# Blast search for Q13519.fasta completed in 437.36 seconds.
# Running blast search for P01574.fasta...
# Blast search for P01574.fasta completed in 248.26 seconds.
# Running blast search for P19883.fasta...
# Blast search for P19883.fasta completed in 138.54 seconds.
# Running blast search for P01282.fasta...
# Blast search for P01282.fasta completed in 1289.84 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 09:14:29 GMT
# Running blast search for Q9Y5Q6.fasta...
# Blast search for Q9Y5Q6.fasta completed in 1290.20 seconds.
# Running blast search for Q8IUX4.fasta...
# Blast search for Q8IUX4.fasta completed in 989.43 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 09:52:28 GMT
# Running blast search for P55265.fasta...
# Blast search for P55265.fasta completed in 71.43 seconds.
# Running blast search for Q99988.fasta...
# Blast search for Q99988.fasta completed in 248.16 seconds.
# Running blast search for P48645.fasta...
# Blast search for P48645.fasta completed in 437.33 seconds.
# Running blast search for P06396.fasta...
# Blast search for P06396.fasta completed in 195.49 seconds.
# Running blast search for P01966.fasta...
# Blast search for P01966.fasta completed in 138.48 seconds.
# Running blast search for Q96BS2.fasta...
# Blast search for Q96BS2.fasta completed in 250.84 seconds.
# Running blast search for P47898.fasta...
# Blast search for P47898.fasta completed in 330.38 seconds.
# Running blast search for P42226.fasta...
# Blast search for P42226.fasta completed in 333.03 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 10:25:53 GMT
# Running blast search for P09914.fasta...
# Blast search for P09914.fasta completed in 262.19 seconds.
# Running blast search for O75192.fasta...
# Blast search for O75192.fasta completed in 248.06 seconds.
# Running blast search for O95399.fasta...
# Blast search for O95399.fasta completed in 330.74 seconds.
# Running blast search for P11802.fasta...
# Blast search for P11802.fasta completed in 447.72 seconds.
# Running blast search for P08949.fasta...
# Blast search for P08949.fasta completed in 184.98 seconds.
# Running blast search for Q01453.fasta...
# Blast search for Q01453.fasta completed in 437.53 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 10:57:45 GMT
# Running blast search for Q10589.fasta...
# Blast search for Q10589.fasta completed in 989.06 seconds.
# Running blast search for Q969E3.fasta...
# Blast search for Q969E3.fasta completed in 135.82 seconds.
# Running blast search for Q14790.fasta...
# Blast search for Q14790.fasta completed in 136.01 seconds.
# Running blast search for A0A097EV82.fasta...
# Blast search for A0A097EV82.fasta completed in 988.81 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 11:35:14 GMT
# Running blast search for P55089.fasta...
# Blast search for P55089.fasta completed in 988.77 seconds.
# Running blast search for O75381.fasta...
# Blast search for O75381.fasta completed in 185.88 seconds.
# Running blast search for Q9P0W0.fasta...
# Blast search for Q9P0W0.fasta completed in 330.39 seconds.
# Running blast search for Q9H293.fasta...
# Blast search for Q9H293.fasta completed in 755.89 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 12:12:55 GMT
# Running blast search for Q00535.fasta...
# Blast search for Q00535.fasta completed in 1300.07 seconds.
# Running blast search for P43490.fasta...
# Blast search for P43490.fasta completed in 1297.22 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 12:56:13 GMT
# Running blast search for Q9BTW9.fasta...
# Blast search for Q9BTW9.fasta completed in 100.35 seconds.
# Running blast search for P42224.fasta...
# Blast search for P42224.fasta completed in 250.92 seconds.
# Running blast search for Q00526.fasta...
# Blast search for Q00526.fasta completed in 446.71 seconds.
# Running blast search for Q9HC23.fasta...
# Blast search for Q9HC23.fasta completed in 575.58 seconds.
# Running blast search for P01241.fasta...
# Blast search for P01241.fasta completed in 331.92 seconds.
# Running blast search for Q16611.fasta...
# Blast search for Q16611.fasta completed in 331.58 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 13:30:10 GMT
# Running blast search for P56199.fasta...
# Blast search for P56199.fasta completed in 262.71 seconds.
# Running blast search for P01258.fasta...
# Blast search for P01258.fasta completed in 330.32 seconds.
# Running blast search for Q8NG41.fasta...
# Blast search for Q8NG41.fasta completed in 135.83 seconds.
# Running blast search for P10082.fasta...
# Blast search for P10082.fasta completed in 248.38 seconds.
# Running blast search for Q7Z2W4.fasta...
# Blast search for Q7Z2W4.fasta completed in 330.27 seconds.
# Running blast search for P19525.fasta...
# Blast search for P19525.fasta completed in 257.89 seconds.
# Running blast search for O43808.fasta...
# Blast search for O43808.fasta completed in 138.82 seconds.
# Running blast search for Q96RP3.fasta...
# Blast search for Q96RP3.fasta completed in 330.25 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 14:04:04 GMT
# Running blast search for P01566.fasta...
# Blast search for P01566.fasta completed in 185.63 seconds.
# Running blast search for P01568.fasta...
# Blast search for P01568.fasta completed in 330.57 seconds.
# Running blast search for P80303.fasta...
# Blast search for P80303.fasta completed in 137.57 seconds.
# Running blast search for O15130.fasta...
# Blast search for O15130.fasta completed in 575.46 seconds.
# Running blast search for P01019.fasta...
# Blast search for P01019.fasta completed in 999.60 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 14:41:13 GMT
# Running blast search for Q99653.fasta...
# Blast search for Q99653.fasta completed in 187.47 seconds.
# Running blast search for P01570.fasta...
# Blast search for P01570.fasta completed in 185.20 seconds.
# Running blast search for P30990.fasta...
# Blast search for P30990.fasta completed in 184.85 seconds.
# Running blast search for P23582.fasta...
# Blast search for P23582.fasta completed in 250.43 seconds.
# Running blast search for P42574.fasta...
# Blast search for P42574.fasta completed in 330.26 seconds.
# Running blast search for P16860.fasta...
# Blast search for P16860.fasta completed in 330.44 seconds.
# Running blast search for Q14765.fasta...
# Blast search for Q14765.fasta completed in 138.31 seconds.
# Running blast search for Q9Y3Z3.fasta...
# Blast search for Q9Y3Z3.fasta completed in 259.12 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 15:12:19 GMT
# Running blast search for P01579.fasta...
# Blast search for P01579.fasta completed in 98.14 seconds.
# Running blast search for Q02388.fasta...
# Blast search for Q02388.fasta completed in 267.22 seconds.
# Running blast search for Q8N729.fasta...
# Blast search for Q8N729.fasta completed in 184.93 seconds.
# Running blast search for O95786.fasta...
# Blast search for O95786.fasta completed in 195.71 seconds.
# Running blast search for P13164.fasta...
# Blast search for P13164.fasta completed in 991.10 seconds.
# Running blast search for P18509.fasta...
# Blast search for P18509.fasta completed in 136.33 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 15:43:33 GMT
# Running blast search for Q12965.fasta...
# Blast search for Q12965.fasta completed in 251.35 seconds.
# Running blast search for P01160.fasta...
# Blast search for P01160.fasta completed in 97.67 seconds.
# Running blast search for P81605.fasta...
# Blast search for P81605.fasta completed in 1289.70 seconds.
# Running blast search for P09912.fasta...
# Blast search for P09912.fasta completed in 437.31 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 16:18:09 GMT
# Running blast search for Q13325.fasta...
# Blast search for Q13325.fasta completed in 144.46 seconds.
# Running blast search for P20591.fasta...
# Blast search for P20591.fasta completed in 332.70 seconds.
# Running blast search for P52630.fasta...
# Blast search for P52630.fasta completed in 100.10 seconds.
# Running blast search for P01210.fasta...
# Blast search for P01210.fasta completed in 68.55 seconds.
# Running blast search for P40763.fasta...
# Blast search for P40763.fasta completed in 187.47 seconds.
# Running blast search for P01213.fasta...
# Blast search for P01213.fasta completed in 437.52 seconds.
# Running blast search for Q01628.fasta...
# Blast search for Q01628.fasta completed in 988.77 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 16:55:48 GMT
# Running blast search for P23142.fasta...
# Blast search for P23142.fasta completed in 100.08 seconds.
# Running blast search for Q9UHF0.fasta...
# Blast search for Q9UHF0.fasta completed in 755.90 seconds.
# Running blast search for P51587.fasta...
# Blast search for P51587.fasta completed in 437.76 seconds.
# Running blast search for P15502.fasta...
# Blast search for P15502.fasta completed in 580.47 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 17:27:02 GMT
# Running blast search for P19838.fasta...
# Blast search for P19838.fasta completed in 268.38 seconds.
# Running blast search for P04637.fasta...
# Blast search for P04637.fasta completed in 138.38 seconds.
# Running blast search for Q5H8A3.fasta...
# Blast search for Q5H8A3.fasta completed in 248.58 seconds.
# Running blast search for P55211.fasta...
# Blast search for P55211.fasta completed in 248.06 seconds.
# Running blast search for P25445.fasta...
# Blast search for P25445.fasta completed in 1590.82 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-04 18:08:37 GMT
# Running blast search for Q9Y5Y5.fasta...
# Blast search for Q9Y5Y5.fasta completed in 188.26 seconds.
# Running blast search for P01303.fasta...
# Blast search for P01303.fasta completed in 755.62 seconds.
# Running blast search for P55210.fasta...
# Blast search for P55210.fasta completed in 184.84 seconds.
# Running blast search for P01225.fasta...
# Blast search for P01225.fasta completed in 135.81 seconds.
# Blastp searches completed for all fasta files.

# %% [markdown]
# ## 3.2 Create Archaeal Master File

# %%
import os

# Specify Directory containing blast results
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts"

# Name the file
master_filename = "archaeal_master_blaster.txt"

# create Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blast_results.txt"):
            # Get the path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file
            with open(blast_result_filepath, "r") as blast_result_file:
                # Write contents to master file
                master_file.write(blast_result_file.read())
                # Separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/archaeal_master_blaster.txt

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/archaeal_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line: 
                current_query_id = line.split("|")[1].strip()  
            elif ">" in line: 
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

# Rank and print total hits
print("Ranked total hits for each accession ID:")
for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")

# Write results to CSV file
output_csv_path = " /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/archaeal_master_blaster.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Query ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in query_hits.items():
            writer.writerow({'Query ID': query_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Ranked total hits for each accession ID:
# An error occurred while writing to CSV: [Errno 2] No such file or directory: ' /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/archaeal_master_blaster.csv'

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ###

# %% [markdown]
# ## 4.0 Fungal Blast

# %%
# !mkdir /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/

# %%
import subprocess
import os
import time
from datetime import datetime, timezone

# Path to the directory containing fasta files
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta"

# Directory to store blast results
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts"

# Create the blast output directory if it doesn't exist
os.makedirs(blast_output_directory, exist_ok=True)

# Record the start time of the entire process in GMT
start_time = datetime.now(timezone.utc)
print(f"Process started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')} GMT")

# Iterate through each fasta file in the directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):  
        fasta_file = os.path.join(fasta_directory, filename)
        output_file = os.path.join(blast_output_directory, f"{os.path.splitext(filename)[0]}_blastp_results.txt")
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            print(f"Skipping {filename} as output file already exists.")
            continue
        
        # Construct the blastp command
        blastp_command = [
            "blastp",
            "-db",
            "nr",
            "-query",
            fasta_file,
            "-out",
            output_file,
            "-evalue",
            "0.06",
            "-remote",
            "-entrez_query",
            "fungi[orgn]"
        ]
        
        # Record start time for this file
        file_start_time = time.time()
        
        # Execute the blastp command
        print(f"Running blast search for {filename}...")
        subprocess.run(blastp_command)
        
        # Calculate elapsed time for this file
        file_elapsed_time = time.time() - file_start_time
        
        # Print filename and elapsed time
        print(f"Blast search for {filename} completed in {file_elapsed_time:.2f} seconds.")
        
        # Check if 30 minutes have elapsed since the start of the process
        if (datetime.now(timezone.utc) - start_time).seconds >= 1800:
            print(f"Process has been running for 30 minutes. Current time: {datetime.now(timezone.utc).strftime('%Y-%m-%d %H:%M:%S')} GMT")
            start_time = datetime.now(timezone.utc)  

print("Blastp searches completed for all fasta files.")
# Out:
# Process started at: 2024-05-05 02:31:31 GMT
# Running blast search for O96011.fasta...
# Blast search for O96011.fasta completed in 149.20 seconds.
# Running blast search for Q07812.fasta...
# Blast search for Q07812.fasta completed in 184.94 seconds.
# Running blast search for Q8NFJ6.fasta...
# Blast search for Q8NFJ6.fasta completed in 250.96 seconds.
# Running blast search for P07492.fasta...
# Blast search for P07492.fasta completed in 186.15 seconds.
# Running blast search for Q15303.fasta...
# Blast search for Q15303.fasta completed in 195.64 seconds.
# Running blast search for Q15726.fasta...
# Blast search for Q15726.fasta completed in 97.84 seconds.
# Running blast search for O00910.fasta...
# Blast search for O00910.fasta completed in 184.86 seconds.
# Running blast search for P38398.fasta...
# Blast search for P38398.fasta completed in 766.30 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 03:05:07 GMT
# Running blast search for P06881.fasta...
# Blast search for P06881.fasta completed in 185.03 seconds.
# Running blast search for P46663.fasta...
# Blast search for P46663.fasta completed in 138.30 seconds.
# Running blast search for P32247.fasta...
# Blast search for P32247.fasta completed in 187.92 seconds.
# Running blast search for P60484.fasta...
# Blast search for P60484.fasta completed in 258.58 seconds.
# Running blast search for P20366.fasta...
# Blast search for P20366.fasta completed in 185.03 seconds.
# Running blast search for P35318.fasta...
# Blast search for P35318.fasta completed in 248.14 seconds.
# Running blast search for P12872.fasta...
# Blast search for P12872.fasta completed in 135.74 seconds.
# Running blast search for P10645.fasta...
# Blast search for P10645.fasta completed in 248.15 seconds.
# Running blast search for O95760.fasta...
# Blast search for O95760.fasta completed in 248.06 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 03:35:42 GMT
# Running blast search for P01344.fasta...
# Blast search for P01344.fasta completed in 135.72 seconds.
# Running blast search for O14879.fasta...
# Blast search for O14879.fasta completed in 190.97 seconds.
# Running blast search for O43745.fasta...
# Blast search for O43745.fasta completed in 259.73 seconds.
# Running blast search for Q92968.fasta...
# Blast search for Q92968.fasta completed in 196.55 seconds.
# Running blast search for O95390.fasta...
# Blast search for O95390.fasta completed in 137.31 seconds.
# Running blast search for P02533.fasta...
# Blast search for P02533.fasta completed in 187.53 seconds.
# Running blast search for Q01629.fasta...
# Blast search for Q01629.fasta completed in 184.84 seconds.
# Running blast search for P0C0P6.fasta...
# Blast search for P0C0P6.fasta completed in 185.56 seconds.
# Running blast search for Q00534.fasta...
# Blast search for Q00534.fasta completed in 258.89 seconds.
# Running blast search for P20592.fasta...
# Blast search for P20592.fasta completed in 146.74 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 04:07:06 GMT
# Running blast search for P06493.fasta...
# Blast search for P06493.fasta completed in 194.93 seconds.
# Running blast search for P06400.fasta...
# Blast search for P06400.fasta completed in 100.74 seconds.
# Running blast search for Q03252.fasta...
# Blast search for Q03252.fasta completed in 187.82 seconds.
# Running blast search for P24941.fasta...
# Blast search for P24941.fasta completed in 194.93 seconds.
# Running blast search for Q13519.fasta...
# Blast search for Q13519.fasta completed in 97.76 seconds.
# Running blast search for P01574.fasta...
# Blast search for P01574.fasta completed in 71.18 seconds.
# Running blast search for P19883.fasta...
# Blast search for P19883.fasta completed in 72.57 seconds.
# Running blast search for P01282.fasta...
# Blast search for P01282.fasta completed in 97.58 seconds.
# Running blast search for Q9Y5Q6.fasta...
# Blast search for Q9Y5Q6.fasta completed in 756.10 seconds.
# Running blast search for Q8IUX4.fasta...
# Blast search for Q8IUX4.fasta completed in 184.91 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 04:39:44 GMT
# Running blast search for P55265.fasta...
# Blast search for P55265.fasta completed in 258.87 seconds.
# Running blast search for Q99988.fasta...
# Blast search for Q99988.fasta completed in 575.22 seconds.
# Running blast search for P48645.fasta...
# Blast search for P48645.fasta completed in 135.86 seconds.
# Running blast search for P06396.fasta...
# Blast search for P06396.fasta completed in 152.11 seconds.
# Running blast search for P01966.fasta...
# Blast search for P01966.fasta completed in 100.57 seconds.
# Running blast search for Q96BS2.fasta...
# Blast search for Q96BS2.fasta completed in 145.87 seconds.
# Running blast search for P47898.fasta...
# Blast search for P47898.fasta completed in 250.92 seconds.
# Running blast search for P42226.fasta...
# Blast search for P42226.fasta completed in 100.01 seconds.
# Running blast search for P09914.fasta...
# Blast search for P09914.fasta completed in 105.30 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 05:10:09 GMT
# Running blast search for O75192.fasta...
# Blast search for O75192.fasta completed in 107.69 seconds.
# Running blast search for O95399.fasta...
# Blast search for O95399.fasta completed in 185.17 seconds.
# Running blast search for P11802.fasta...
# Blast search for P11802.fasta completed in 78.51 seconds.
# Running blast search for P08949.fasta...
# Blast search for P08949.fasta completed in 68.91 seconds.
# Running blast search for Q01453.fasta...
# Blast search for Q01453.fasta completed in 135.71 seconds.
# Running blast search for Q10589.fasta...
# Blast search for Q10589.fasta completed in 100.68 seconds.
# Running blast search for Q969E3.fasta...
# Blast search for Q969E3.fasta completed in 68.61 seconds.
# Running blast search for Q14790.fasta...
# Blast search for Q14790.fasta completed in 97.74 seconds.
# Running blast search for A0A097EV82.fasta...
# Blast search for A0A097EV82.fasta completed in 97.72 seconds.
# Running blast search for P55089.fasta...
# Blast search for P55089.fasta completed in 97.64 seconds.
# Running blast search for O75381.fasta...
# Blast search for O75381.fasta completed in 146.44 seconds.
# Running blast search for Q9P0W0.fasta...
# Blast search for Q9P0W0.fasta completed in 101.32 seconds.
# Running blast search for Q9H293.fasta...
# Blast search for Q9H293.fasta completed in 101.13 seconds.
# Running blast search for Q00535.fasta...
# Blast search for Q00535.fasta completed in 146.47 seconds.
# Running blast search for P43490.fasta...
# Blast search for P43490.fasta completed in 77.47 seconds.
# Running blast search for Q9BTW9.fasta...
# Blast search for Q9BTW9.fasta completed in 108.93 seconds.
# Running blast search for P42224.fasta...
# Blast search for P42224.fasta completed in 578.13 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 05:48:27 GMT
# Running blast search for Q00526.fasta...
# Blast search for Q00526.fasta completed in 108.69 seconds.
# Running blast search for Q9HC23.fasta...
# Blast search for Q9HC23.fasta completed in 135.86 seconds.
# Running blast search for P01241.fasta...
# Blast search for P01241.fasta completed in 97.61 seconds.
# Running blast search for Q16611.fasta...
# Blast search for Q16611.fasta completed in 97.95 seconds.
# Running blast search for P56199.fasta...
# Blast search for P56199.fasta completed in 101.30 seconds.
# Running blast search for P01258.fasta...
# Blast search for P01258.fasta completed in 135.75 seconds.
# Running blast search for Q8NG41.fasta...
# Blast search for Q8NG41.fasta completed in 98.32 seconds.
# Running blast search for P10082.fasta...
# Blast search for P10082.fasta completed in 330.72 seconds.
# Running blast search for Q7Z2W4.fasta...
# Blast search for Q7Z2W4.fasta completed in 440.44 seconds.
# Running blast search for P19525.fasta...
# Blast search for P19525.fasta completed in 450.60 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 06:21:45 GMT
# Running blast search for O43808.fasta...
# Blast search for O43808.fasta completed in 147.02 seconds.
# Running blast search for Q96RP3.fasta...
# Blast search for Q96RP3.fasta completed in 184.88 seconds.
# Running blast search for P01566.fasta...
# Blast search for P01566.fasta completed in 99.97 seconds.
# Running blast search for P01568.fasta...
# Blast search for P01568.fasta completed in 137.98 seconds.
# Running blast search for P80303.fasta...
# Blast search for P80303.fasta completed in 104.06 seconds.
# Running blast search for O15130.fasta...
# Blast search for O15130.fasta completed in 184.81 seconds.
# Running blast search for P01019.fasta...
# Blast search for P01019.fasta completed in 100.06 seconds.
# Running blast search for Q99653.fasta...
# Blast search for Q99653.fasta completed in 194.59 seconds.
# Running blast search for P01570.fasta...
# Blast search for P01570.fasta completed in 100.06 seconds.
# Running blast search for P30990.fasta...
# Blast search for P30990.fasta completed in 247.93 seconds.
# Running blast search for P23582.fasta...
# Blast search for P23582.fasta completed in 330.82 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 06:52:17 GMT
# Running blast search for P42574.fasta...
# Blast search for P42574.fasta completed in 330.14 seconds.
# Running blast search for P16860.fasta...
# Blast search for P16860.fasta completed in 248.05 seconds.
# Running blast search for Q14765.fasta...
# Blast search for Q14765.fasta completed in 334.35 seconds.
# Running blast search for Q9Y3Z3.fasta...
# Blast search for Q9Y3Z3.fasta completed in 341.41 seconds.
# Running blast search for P01579.fasta...
# Blast search for P01579.fasta completed in 248.67 seconds.
# Running blast search for Q02388.fasta...
# Blast search for Q02388.fasta completed in 293.80 seconds.
# Running blast search for Q8N729.fasta...
# Blast search for Q8N729.fasta completed in 185.21 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 07:25:18 GMT
# Running blast search for O95786.fasta...
# Blast search for O95786.fasta completed in 341.26 seconds.
# Running blast search for P13164.fasta...
# Blast search for P13164.fasta completed in 330.15 seconds.
# Running blast search for P18509.fasta...
# Blast search for P18509.fasta completed in 135.79 seconds.
# Running blast search for Q12965.fasta...
# Blast search for Q12965.fasta completed in 586.81 seconds.
# Running blast search for P01160.fasta...
# Blast search for P01160.fasta completed in 330.11 seconds.
# Running blast search for P81605.fasta...
# Blast search for P81605.fasta completed in 330.33 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 07:59:33 GMT
# Running blast search for P09912.fasta...
# Blast search for P09912.fasta completed in 251.30 seconds.
# Running blast search for Q13325.fasta...
# Blast search for Q13325.fasta completed in 578.42 seconds.
# Running blast search for P20591.fasta...
# Blast search for P20591.fasta completed in 340.25 seconds.
# Running blast search for P52630.fasta...
# Blast search for P52630.fasta completed in 758.08 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 08:31:41 GMT
# Running blast search for P01210.fasta...
# Blast search for P01210.fasta completed in 755.67 seconds.
# Running blast search for P40763.fasta...
# Blast search for P40763.fasta completed in 577.99 seconds.
# Running blast search for P01213.fasta...
# Blast search for P01213.fasta completed in 184.87 seconds.
# Running blast search for Q01628.fasta...
# Blast search for Q01628.fasta completed in 184.93 seconds.
# Running blast search for P23142.fasta...
# Blast search for P23142.fasta completed in 187.99 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 09:03:12 GMT
# Running blast search for Q9UHF0.fasta...
# Blast search for Q9UHF0.fasta completed in 135.79 seconds.
# Running blast search for P51587.fasta...
# Blast search for P51587.fasta completed in 195.62 seconds.
# Running blast search for P15502.fasta...
# Blast search for P15502.fasta completed in 250.40 seconds.
# Running blast search for P19838.fasta...
# Blast search for P19838.fasta completed in 606.81 seconds.
# Running blast search for P04637.fasta...
# Blast search for P04637.fasta completed in 1289.60 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 09:44:31 GMT
# Running blast search for Q5H8A3.fasta...
# Blast search for Q5H8A3.fasta completed in 1591.23 seconds.
# Running blast search for P55211.fasta...
# Blast search for P55211.fasta completed in 437.40 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 10:18:19 GMT
# Running blast search for P25445.fasta...
# Blast search for P25445.fasta completed in 575.40 seconds.
# Running blast search for Q9Y5Y5.fasta...
# Blast search for Q9Y5Y5.fasta completed in 2203.77 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 11:04:38 GMT
# Running blast search for P01303.fasta...
# Blast search for P01303.fasta completed in 1289.80 seconds.
# Running blast search for P55210.fasta...
# Blast search for P55210.fasta completed in 1591.52 seconds.
# Process has been running for 30 minutes. Current time: 2024-05-05 11:52:40 GMT
# Running blast search for P01225.fasta...
# Blast search for P01225.fasta completed in 1591.69 seconds.
# Blastp searches completed for all fasta files.

# %% [markdown]
# ## 4.2 Create Fungal Master File

# %%
import os

# Specify Directory containing blast results
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts"

# Name the file
master_filename = "Fungal_master_blaster.txt"

# create Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blast_results.txt"):
            # Get the path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file
            with open(blast_result_filepath, "r") as blast_result_file:
                # Write contents to master file
                master_file.write(blast_result_file.read())
                # Separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_master_blaster.txt
