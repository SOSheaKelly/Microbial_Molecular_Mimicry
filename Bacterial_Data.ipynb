# %% [markdown]
# # Bacterial Blast Data Handling

# %% [markdown]
# ## 1.1 Create Bacterial Master file

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts"

# Name of the master file
master_filename = "bacterial_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster.txt

# %% [markdown]
# ### 1.1.1 Make Masterfile Csv

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts"

# Name of the master file
master_filename = "bacterial_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Counter for the number of files processed
file_count = 0

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            file_count += 1  # Increment the file count
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print(f"{file_count} blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# 44 blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster.txt

# %% [markdown]
# ### 1.1.2 Make additions to masterfile to analyse hits in regard to protein type and name

# %%
import pandas as pd

# File paths
bacterial_master_blaster_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv"
protein_names_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/protein_names.csv"
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_proteins_results.csv"

# Read the bacterial master blaster CSV
bacterial_master_blaster_df = pd.read_csv(bacterial_master_blaster_filepath)

# Read the protein names CSV
protein_names_df = pd.read_csv(protein_names_filepath)

# Merge the dataframes on 'Accession ID'
merged_df = pd.merge(bacterial_master_blaster_df, protein_names_df[['Accession ID', 'Protein Names', 'Protein Type']], on='Accession ID', how='left')

# Reorder columns to place 'Protein Names' and 'Protein Type' at the start
cols = ['Protein Names', 'Protein Type'] + [col for col in bacterial_master_blaster_df.columns if col not in ['Protein Names', 'Protein Type']]
merged_df = merged_df[cols]

# Write the merged dataframe to a new CSV file
merged_df.to_csv(output_csv_path, index=False)

# Count the number of unique protein names
unique_protein_names = merged_df['Protein Names'].nunique()
print(f"Number of unique protein names: {unique_protein_names}")

# Breakdown of each protein type
protein_type_counts = merged_df['Protein Type'].value_counts()
print("Breakdown of protein types:")
print(protein_type_counts)

print(f"Merged results saved to '{output_csv_path}'")
# Out:
# Number of unique protein names: 41
# Breakdown of protein types:
# Antiviral Proteins                            8
# Cell Cycle Regulation Proteins                6
# Cell Death and Survival Related               5
# Structural                                    4
# Cardiovascular and Renal Hormones             4
# Neuropeptides and Neurotransmitter            4
# Immune System - Cytokines                     3
# Gastrointestinal                              2
# Metabolic Hormones                            2
# Growth Factors/ Developmental Proteins        1
# Tumour Suppressors and DNA Repair Proteins    1
# Hypothalamic-Pituitary Axis Hormones          1
# Name: Protein Type, dtype: int64
# Merged results saved to '/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_proteins_results.csv'

# %% [markdown]
# ## 1.2 Print Total Hits and Accession ID's

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line:  
                current_query_id = line.split("|")[1].strip()
            elif ">" in line:  
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

# Rank and print total hits
print("Ranked total hits for each accession ID:")
for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Query ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in query_hits.items():
            writer.writerow({'Query ID': query_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Ranked total hits for each accession ID:
# 1. Accession ID: P11802, Total Hits: 250
# 2. Accession ID: Q01629, Total Hits: 250
# 3. Accession ID: P09914, Total Hits: 250
# 4. Accession ID: P60484, Total Hits: 250
# 5. Accession ID: Q01628, Total Hits: 250
# 6. Accession ID: Q00535, Total Hits: 250
# 7. Accession ID: P06493, Total Hits: 250
# 8. Accession ID: P13164, Total Hits: 250
# 9. Accession ID: Q00534, Total Hits: 250
# 10. Accession ID: O14879, Total Hits: 250
# 11. Accession ID: P55210, Total Hits: 250
# 12. Accession ID: Q13325, Total Hits: 250
# 13. Accession ID: Q00526, Total Hits: 250
# 14. Accession ID: P24941, Total Hits: 250
# 15. Accession ID: P01019, Total Hits: 250
# 16. Accession ID: P01966, Total Hits: 247
# 17. Accession ID: O43745, Total Hits: 133
# 18. Accession ID: P19883, Total Hits: 104
# 19. Accession ID: Q99653, Total Hits: 68
# 20. Accession ID: P42574, Total Hits: 56
# 21. Accession ID: O43808, Total Hits: 42
# 22. Accession ID: P47898, Total Hits: 28
# 23. Accession ID: P32247, Total Hits: 27
# 24. Accession ID: Q10589, Total Hits: 17
# 25. Accession ID: P46663, Total Hits: 15
# 26. Accession ID: Q8NFJ6, Total Hits: 9
# 27. Accession ID: P01241, Total Hits: 7
# 28. Accession ID: Q01453, Total Hits: 3
# 29. Accession ID: Q16611, Total Hits: 3
# 30. Accession ID: Q96BS2, Total Hits: 2
# 31. Accession ID: P01579, Total Hits: 2
# 32. Accession ID: Q07812, Total Hits: 2
# 33. Accession ID: P01210, Total Hits: 2
# 34. Accession ID: Q9Y5Q6, Total Hits: 2
# 35. Accession ID: P01574, Total Hits: 1
# 36. Accession ID: O75381, Total Hits: 1
# 37. Accession ID: P01568, Total Hits: 1
# 38. Accession ID: P09912, Total Hits: 1
# 39. Accession ID: P01213, Total Hits: 1
# 40. Accession ID: Q9Y5Y5, Total Hits: 1
# 41. Accession ID: P25445, Total Hits: 1
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv'

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line:  # Check if the line contains an accession ID
                current_query_id = line.split("|")[1].strip()  # Extract the query ID between "|"
            elif ">" in line:  # Check if the line contains a hit
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  # Extract hit and append to list
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Rank', 'Accession ID', 'Total Hits', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for rank, (query_id, hits) in enumerate(sorted(query_hits.items(), key=lambda x: len(x[1]), reverse=True), start=1):
            writer.writerow({'Rank': rank, 'Accession ID': query_id, 'Total Hits': total_hits[query_id], 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv'

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line:  # Check if the line contains an accession ID
                current_query_id = line.split("|")[1].strip()  # Extract the query ID between "|"
            elif ">" in line:  # Check if the line contains a hit
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  # Extract hit and append to list
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Accession ID', 'Total Hits', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in sorted(query_hits.items(), key=lambda x: len(x[1]), reverse=True):
            writer.writerow({'Accession ID': query_id, 'Total Hits': total_hits[query_id], 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")

# Print ranked total hits to screen
print("Ranked total hits for each accession ID:")
for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")
# Out:
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv'
# Ranked total hits for each accession ID:
# 1. Accession ID: P11802, Total Hits: 250
# 2. Accession ID: Q01629, Total Hits: 250
# 3. Accession ID: P09914, Total Hits: 250
# 4. Accession ID: P60484, Total Hits: 250
# 5. Accession ID: Q01628, Total Hits: 250
# 6. Accession ID: Q00535, Total Hits: 250
# 7. Accession ID: P06493, Total Hits: 250
# 8. Accession ID: P13164, Total Hits: 250
# 9. Accession ID: Q00534, Total Hits: 250
# 10. Accession ID: O14879, Total Hits: 250
# 11. Accession ID: P55210, Total Hits: 250
# 12. Accession ID: Q13325, Total Hits: 250
# 13. Accession ID: Q00526, Total Hits: 250
# 14. Accession ID: P24941, Total Hits: 250
# 15. Accession ID: P01019, Total Hits: 250
# 16. Accession ID: P01966, Total Hits: 247
# 17. Accession ID: O43745, Total Hits: 133
# 18. Accession ID: P19883, Total Hits: 104
# 19. Accession ID: Q99653, Total Hits: 68
# 20. Accession ID: P42574, Total Hits: 56
# 21. Accession ID: O43808, Total Hits: 42
# 22. Accession ID: P47898, Total Hits: 28
# 23. Accession ID: P32247, Total Hits: 27
# 24. Accession ID: Q10589, Total Hits: 17
# 25. Accession ID: P46663, Total Hits: 15
# 26. Accession ID: Q8NFJ6, Total Hits: 9
# 27. Accession ID: P01241, Total Hits: 7
# 28. Accession ID: Q01453, Total Hits: 3
# 29. Accession ID: Q16611, Total Hits: 3
# 30. Accession ID: Q96BS2, Total Hits: 2
# 31. Accession ID: P01579, Total Hits: 2
# 32. Accession ID: Q07812, Total Hits: 2
# 33. Accession ID: P01210, Total Hits: 2
# 34. Accession ID: Q9Y5Q6, Total Hits: 2
# 35. Accession ID: P01574, Total Hits: 1
# 36. Accession ID: O75381, Total Hits: 1
# 37. Accession ID: P01568, Total Hits: 1
# 38. Accession ID: P09912, Total Hits: 1
# 39. Accession ID: P01213, Total Hits: 1
# 40. Accession ID: Q9Y5Y5, Total Hits: 1
# 41. Accession ID: P25445, Total Hits: 1

# %%
import csv

# Path to the input text file
input_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster.txt"
# Path to the output CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacteria_results.csv"

# Initialize lists to store accession IDs and hit names
accession_ids = []
hit_names = []

# Read the input file and extract accession IDs and hit names
try:
    with open(input_file_path, "r") as input_file:
        current_accession_id = None
        for line in input_file:
            if "|" in line:
                current_accession_id = line.split("|")[1].strip()
            elif line.startswith(">"):
                if current_accession_id:
                    accession_ids.append(current_accession_id)
                    hit_name = line.strip()[1:] 
                    hit_names.append(hit_name)
except FileNotFoundError:
    print(f"Error: File '{input_file_path}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Write accession IDs and hit names to CSV file
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(["Accession ID", "Hit Name"])  
        for accession_id, hit_name in zip(accession_ids, hit_names):
            writer.writerow([accession_id, hit_name])
    print(f"Accession IDs and hit names saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Accession IDs and hit names saved to '/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacteria_results.csv'

# %% [markdown]
# ## 1.3 Filter for Queries which Produced Hits

# %%
import os
import shutil

# Function to check if the given file contains the phrase "No hits found" (case-insensitive)
def contains_no_hits(file_path):
    with open(file_path, 'r') as f:
        content = f.read()
        return "no hits found" not in content.lower()  

# Source directory containing blast result files
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/"

# Destination directory for files with hits
dest_dir = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits"

# Create destination directory if it doesn't exist
if not os.path.exists(dest_dir):
    os.makedirs(dest_dir)

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith(".txt"):  # Check if it's a text file
        file_path = os.path.join(source_dir, file_name)
        if contains_no_hits(file_path):
            # Move the file to the destination directory if it contains hits
            shutil.move(file_path, os.path.join(dest_dir, file_name))

# %% [markdown]
# ## 1.4 Create Initial Species CSV file from Master File

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/bacterial_hits_data.csv"

# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Function to parse data from blast result file
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        query_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0  
        hit_id = None  
        species_id = None  
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1  
                # Extract Hit ID
                hit_id = line.split(">")[1].split(" ")[0]
                # Extract species ID if present
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
                    
                # Manually add species ID for specific hit ID
                if hit_id == "MDO8640940.1":
                    species_id = "Nitrosarchaeum sp."

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
                hits_data.append([query_id, hit_id, hit_number, seq_length, species_id])
    return hits_data

# List to store parsed data
parsed_data = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"):  # Check if it's a blast result file
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow(['Query ID', 'Hit ID', 'Hit Number', 'Sequence Length', 'Species ID'])
    # Write parsed data
    writer.writerows(parsed_data)

print("CSV file created successfully")
# Out:
# CSV file created successfully

# %% [markdown]
# ## 1.5 Create comprehensive CSV table containing blast alignment results

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/comp_bacterial_data.csv"

# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Parse out required data from blast reaults
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        query_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0 
        hit_id = None 
        species_id = None 
        seq_length = None  
        evalue = None 
        score = None  
        identities = None  
        identities_percent = None
        positives = None 
        positives_percent = None  
        gaps = None  
        gaps_percent = None  
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1 
                hit_id = line.split(">")[1].split(" ")[0]
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
               

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
            elif hit_id and "Expect =" in line:
                evalue = line.split("Expect = ")[1].split(",")[0].strip()
                score = line.split("Score = ")[1].split(" bits")[0].strip()
            elif hit_id and "Identities =" in line:
                identities_str = line.split("Identities = ")[1].split(",")[0].strip()
                identities = identities_str.split(" ")[0]
                identities_fraction = identities.split("/")
                identities_percent = (int(identities_fraction[0]) / int(identities_fraction[1])) * 100
                positives_str = line.split("Positives = ")[1].split(",")[0].strip()
                positives = positives_str.split(" ")[0]
                positives_fraction = positives.split("/")
                positives_percent = (int(positives_fraction[0]) / int(positives_fraction[1])) * 100
                gaps_str = line.split("Gaps = ")[1].split(" ")[0].strip()
                gaps = gaps_str
                gaps_fraction = gaps.split("/")
                gaps_percent = (int(gaps_fraction[0]) / int(gaps_fraction[1])) * 100
                # Append all values to hits_data
                hits_data.append([
                    query_id, hit_id, hit_number, seq_length, species_id, evalue, score, 
                    identities, f"{identities_percent:.2f}%", positives, f"{positives_percent:.2f}%", gaps, f"{gaps_percent:.2f}%"
                ])
    return hits_data

# List to store parsed data
parsed_data = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"): 
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow([
        'Accession ID', 'Hit ID', 'Hit Number', 'Sequence Length', 'Species ID', 'Evalue', 'Score', 
        'Identities', 'Identities (%)', 'Positives', 'Positives (%)', 'Gaps', 'Gaps (%)'
    ])
    # Write parsed data
    writer.writerows(parsed_data)

print("CSV file created successfully")

# %%
import os
import pandas as pd
import shutil

# Define file paths and directories
csv_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/bac_vs_vir_hits.csv"
source_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq"
destination_directory = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs"

# Ensure the destination directory exists
os.makedirs(destination_directory, exist_ok=True)

# Read the CSV file to get the Accession IDs from the "bacterial hits" column
df = pd.read_csv(csv_file_path)
bacterial_hits = df['bacterial hits'].dropna().unique()

# Function to check if a file has a matching Accession ID
def has_matching_accession_id(file_name, accession_ids):
    # Extract the Accession ID from the file name
    accession_id = os.path.splitext(file_name)[0]
    return accession_id in accession_ids

# Counter to keep track of the number of files copied
num_files_copied = 0

# Scan the source directory for matching fasta files and copy them
for file_name in os.listdir(source_directory):
    if file_name.endswith(".fasta") and has_matching_accession_id(file_name, bacterial_hits):
        source_file_path = os.path.join(source_directory, file_name)
        destination_file_path = os.path.join(destination_directory, file_name)
        shutil.copy2(source_file_path, destination_file_path)
        num_files_copied += 1
        print(f"Copied: {file_name}")

print(f"Total files copied: {num_files_copied}")
# Out:
# Copied: Q07812.fasta
# Copied: Q8NFJ6.fasta
# Copied: P46663.fasta
# Copied: P32247.fasta
# Copied: P60484.fasta
# Copied: O14879.fasta
# Copied: Q00534.fasta
# Copied: P06493.fasta
# Copied: P24941.fasta
# Copied: P01966.fasta
# Copied: P47898.fasta
# Copied: P11802.fasta
# Copied: Q00535.fasta
# Copied: Q00526.fasta
# Copied: Q16611.fasta
# Copied: O43808.fasta
# Copied: P01019.fasta
# Copied: P25445.fasta
# Copied: P55210.fasta
# Total files copied: 19

# %% [markdown]
# ## 2.0 Upload bacterial Peptides

# %%
#Command to create a fasta file for each Accession ID. 
# The command denotes queries of different amino acid sequences under the same accession ID using "_{number}" sequentially. 
# Command also parses out fasta information out and adds it to the newly made fasta's. 

file_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_bacterial_seqs.txt"
output_dir = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits"


import os

def process_fasta(file_path, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    accession_count = {}
    sequence_data = {}
    
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    current_header = None
    current_sequence = []
    
    for line in lines:
        if line.startswith('>'):
            if current_header:
                accession_id = current_header.split('|')[1]
                accession_id_with_suffix = f"{accession_id}_{accession_count[accession_id]}"
                sequence_data[accession_id_with_suffix] = (current_header, ''.join(current_sequence))
            
            parts = line.split('|')
            accession_id = parts[1]
            
            if accession_id not in accession_count:
                accession_count[accession_id] = 1
            else:
                accession_count[accession_id] += 1
            
            current_header = line.strip()
            current_sequence = []
        else:
            current_sequence.append(line.strip())
    
    if current_header:
        accession_id = current_header.split('|')[1]
        accession_id_with_suffix = f"{accession_id}_{accession_count[accession_id]}"
        sequence_data[accession_id_with_suffix] = (current_header, ''.join(current_sequence))
    
    for accession_id_with_suffix, (header, sequence) in sequence_data.items():
        print(accession_id_with_suffix)
        fasta_filename = os.path.join(output_dir, f"{accession_id_with_suffix}.fasta")
        with open(fasta_filename, 'w') as fasta_file:
            fasta_file.write(f"{header}\n{sequence}\n")
            
process_fasta(file_path, output_dir)
# Out:
# O43745_1
# O75381_1
# P01210_1
# P01210_2
# P01210_3
# P01210_4
# P01210_5
# P01210_6
# P01210_7
# P01210_8
# P01210_9
# P01210_10
# P01210_11
# P01213_1
# P01213_2
# P01213_3
# P01213_4
# P01213_5
# P01213_6
# P01213_7
# P01213_8
# P01213_9
# P01213_10
# P01213_11
# P01241_1
# P01568_1
# P01574_1
# P01579_1
# P09912_1
# P09914_1
# P13164_1
# P19883_1
# Q01453_1
# Q01628_1
# Q01629_1
# Q10589_1
# Q13325_1
# Q96BS2_1
# Q99653_1
# Q9Y5Q6_1
# Q9Y5Q6_2
# Q9Y5Y5_1

# %%
import os
import shutil

# Source directory containing FASTA files
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/"

# Destination directory to move the files
destination_dir = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/"

try:
    # Create the destination directory if it doesn't exist
    os.makedirs(destination_dir, exist_ok=True)

    # Iterate over all files in the source directory
    for filename in os.listdir(source_dir):
        if filename.endswith(".fasta") or filename.endswith(".fa") or filename.endswith(".txt"):
            # Construct full paths to source and destination files
            source_file = os.path.join(source_dir, filename)
            destination_file = os.path.join(destination_dir, filename)
            
            # Move the file from source to destination
            shutil.move(source_file, destination_file)
            print(f"Moved {filename} to {destination_dir}")
        else:
            print(f"Skipped {filename} (not a FASTA file)")

    print("All files moved successfully.")

except FileNotFoundError:
    print(f"Error: Source directory '{source_dir}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Moved Q02388_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P46663_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q12965_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P55265_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P42224_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P19883_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Skipped bacterial_hits_data.csv (not a FASTA file)
# Moved Q01629_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_4.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P11802_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q01453_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01568_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01574_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01574_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P51587_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P32247_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved O75381_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q01629_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P47898_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Skipped comp_bacterial_data.csv (not a FASTA file)
# Moved P09914_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved O95390_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01966_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P04637_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P60484_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved processed_bacterial_seqs.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Skipped .ipynb_checkpoints (not a FASTA file)
# Moved P01568_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P15502_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_6.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P02533_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q8NFJ6_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q01628_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_7.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q01453_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P09914_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q96BS2_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q00535_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P06493_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_8.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_4.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P09912_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P43490_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q10589_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q9Y5Q6_2.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P40763_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved O75381_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_3.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q03252_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q9BTW9_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01241_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q99653_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q9Y3Z3_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q14765_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q15303_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved O43745_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Skipped bac_vs_vir_hits.csv (not a FASTA file)
# Moved O43745_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P06400_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q7Z2W4_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_9.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q96BS2_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01579_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P10645_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_3.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q13325_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P19525_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_2.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P55211_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q99653_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P19883_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P13164_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P52630_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_10.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q9Y5Q6_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q07812_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P19838_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P06396_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P13164_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_11.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_6.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q00534_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_8.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P42574_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_9.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P09912_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P23142_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q9Y5Y5_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P25445_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved O43808_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q01628_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q9Y5Q6_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved O95786_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved O14879_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P55210_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P20592_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q9Y5Y5_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P80303_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01241_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q10589_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q13325_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P56199_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_5.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Skipped processed_seqs (not a FASTA file)
# Moved P42226_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q00526_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q16611_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P20591_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01579_1.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01213_11.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_10.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_5.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved Q14790_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P24941_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01019_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved O00910_blastp_results.txt to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Skipped comp_Vir_refseq_data.csv (not a FASTA file)
# Moved P01213_7.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# Moved P01210_2.fasta to /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/
# All files moved successfully.

# %% [markdown]
# ## 3.0 Perform Blast on Bacterial Hits

# %%
# !mkdir home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results
# Out:
# mkdir: cannot create directory ‘home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results’: File exists

# %%
import os

# Define the directory path
directory = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results"

# Create the directory
os.makedirs(directory, exist_ok=True)

# Verify that the directory has been created
if os.path.exists(directory):
    print(f"The directory {directory} has been created.")
else:
    print(f"Failed to create the directory {directory}.")
# Out:
# The directory /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results has been created.

# %%
import subprocess
import os
import time
from datetime import datetime, timezone

# Path to the directory containing fasta files
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/"

# Directory to store blast results
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results"

# Create the blast output directory if it doesn't exist
os.makedirs(blast_output_directory, exist_ok=True)

# Record the start time of the entire process in GMT
start_time = datetime.now(timezone.utc)
print(f"Process started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')} GMT")

# Iterate through each fasta file in the directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):
        fasta_file = os.path.join(fasta_directory, filename)
        output_file = os.path.join(blast_output_directory, f"{os.path.splitext(filename)[0]}_blastp_results.txt")
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            print(f"Skipping {filename} as output file already exists.")
            continue
        
        # Construct the blastp command
        blastp_command = [
            "blastp",
            "-db",
            "nr",
            "-query",
            fasta_file,
            "-out",
            output_file,
            "-evalue",
            "0.06",
            "-remote",
            "-entrez_query",
            "bacteria[orgn]"
        ]
        
        # Record start time for this file
        file_start_time = time.time()
        
        # Execute the blastp command
        print(f"Running blast search for {filename}...")
        try:
            result = subprocess.run(blastp_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
            result.check_returncode()  # This will raise an error if the command failed
            print(f"Blast search for {filename} completed successfully.")
        except subprocess.CalledProcessError as e:
            print(f"Blast search for {filename} failed with return code {e.returncode}.")
            print(f"Error: {e.stderr}")
        
        # Calculate elapsed time for this file
        file_elapsed_time = time.time() - file_start_time
        
        # Print filename and elapsed time
        print(f"Blast search for {filename} completed in {file_elapsed_time:.2f} seconds.")
        
        # Check if 30 minutes have elapsed since the start of the process
        if (datetime.now(timezone.utc) - start_time).seconds >= 1800:
            print(f"Process has been running for 30 minutes. Current time: {datetime.now(timezone.utc).strftime('%Y-%m-%d %H:%M:%S')} GMT")
            start_time = datetime.now(timezone.utc)  

print("Blastp searches completed for all fasta files.")
# Out:
# Process started at: 2024-07-03 12:29:24 GMT
# Skipping Q07812.fasta as output file already exists.
# Skipping Q8NFJ6.fasta as output file already exists.
# Running blast search for P19883_1.fasta...
# Blast search for P19883_1.fasta completed successfully.
# Blast search for P19883_1.fasta completed in 1895.24 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 13:00:59 GMT
# Running blast search for Q01629_1.fasta...
# Blast search for Q01629_1.fasta completed successfully.
# Blast search for Q01629_1.fasta completed in 996.34 seconds.
# Running blast search for P01210_4.fasta...
# Blast search for P01210_4.fasta completed successfully.
# Blast search for P01210_4.fasta completed in 988.44 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 13:34:04 GMT
# Running blast search for Q01453_1.fasta...
# Blast search for Q01453_1.fasta completed successfully.
# Blast search for Q01453_1.fasta completed in 578.41 seconds.
# Running blast search for P01568_1.fasta...
# Blast search for P01568_1.fasta completed successfully.
# Blast search for P01568_1.fasta completed in 1289.81 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 14:05:12 GMT
# Skipping P46663.fasta as output file already exists.
# Skipping P32247.fasta as output file already exists.
# Running blast search for P01574_1.fasta...
# Blast search for P01574_1.fasta completed successfully.
# Blast search for P01574_1.fasta completed in 2496.47 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 14:46:49 GMT
# Skipping P60484.fasta as output file already exists.
# Skipping P01019_3.fasta as output file already exists.
# Running blast search for P01213_1.fasta...
# Blast search for P01213_1.fasta completed successfully.
# Blast search for P01213_1.fasta completed in 4000.60 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 15:53:29 GMT
# Skipping P01019_6.fasta as output file already exists.
# Skipping O14879.fasta as output file already exists.
# Skipping Q00534.fasta as output file already exists.
# Running blast search for P01213_6.fasta...
# Blast search for P01213_6.fasta completed successfully.
# Blast search for P01213_6.fasta completed in 1891.72 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 16:25:01 GMT
# Running blast search for P01210_7.fasta...
# Blast search for P01210_7.fasta completed successfully.
# Blast search for P01210_7.fasta completed in 4304.36 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 17:36:46 GMT
# Skipping P06493.fasta as output file already exists.
# Running blast search for P09914_1.fasta...
# Blast search for P09914_1.fasta completed successfully.
# Blast search for P09914_1.fasta completed in 1905.80 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 18:08:31 GMT
# Running blast search for Q96BS2_1.fasta...
# Blast search for Q96BS2_1.fasta completed successfully.
# Blast search for Q96BS2_1.fasta completed in 3999.29 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 19:15:11 GMT
# Running blast search for P01210_8.fasta...
# Blast search for P01210_8.fasta completed successfully.
# Blast search for P01210_8.fasta completed in 2194.96 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 19:51:46 GMT
# Running blast search for P01213_4.fasta...
# Blast search for P01213_4.fasta completed successfully.
# Blast search for P01213_4.fasta completed in 1892.65 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 20:23:18 GMT
# Running blast search for Q10589_1.fasta...
# Blast search for Q10589_1.fasta completed successfully.
# Blast search for Q10589_1.fasta completed in 1894.06 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 20:54:52 GMT
# Running blast search for Q9Y5Q6_2.fasta...
# Blast search for Q9Y5Q6_2.fasta completed successfully.
# Blast search for Q9Y5Q6_2.fasta completed in 4905.70 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 22:16:38 GMT
# Skipping P24941.fasta as output file already exists.
# Running blast search for O75381_1.fasta...
# Blast search for O75381_1.fasta completed successfully.
# Blast search for O75381_1.fasta completed in 4300.06 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-03 23:28:18 GMT
# Running blast search for P01210_3.fasta...
# Blast search for P01210_3.fasta completed successfully.
# Blast search for P01210_3.fasta completed in 1289.68 seconds.
# Running blast search for P01210_1.fasta...
# Blast search for P01210_1.fasta completed successfully.
# Blast search for P01210_1.fasta completed in 2494.65 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 00:31:22 GMT
# Skipping P01966.fasta as output file already exists.
# Running blast search for O43745_1.fasta...
# Blast search for O43745_1.fasta completed successfully.
# Blast search for O43745_1.fasta completed in 5209.59 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 01:58:12 GMT
# Skipping P47898.fasta as output file already exists.
# Skipping P01019_5.fasta as output file already exists.
# Running blast search for P01210_9.fasta...
# Blast search for P01210_9.fasta completed successfully.
# Blast search for P01210_9.fasta completed in 4030.23 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 03:05:22 GMT
# Skipping P01966_1.fasta as output file already exists.
# Skipping P11802.fasta as output file already exists.
# Running blast search for P01213_3.fasta...
# Blast search for P01213_3.fasta completed successfully.
# Blast search for P01213_3.fasta completed in 988.70 seconds.
# Running blast search for Q13325_1.fasta...
# Blast search for Q13325_1.fasta completed successfully.
# Blast search for Q13325_1.fasta completed in 1891.79 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 03:53:23 GMT
# Running blast search for P01213_2.fasta...
# Blast search for P01213_2.fasta completed successfully.
# Blast search for P01213_2.fasta completed in 3096.52 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 04:44:59 GMT
# Skipping P01019_7.fasta as output file already exists.
# Running blast search for Q99653_1.fasta...
# Blast search for Q99653_1.fasta completed successfully.
# Blast search for Q99653_1.fasta completed in 7017.80 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 06:41:57 GMT
# Skipping P01019_8.fasta as output file already exists.
# Running blast search for P01213_10.fasta...
# Blast search for P01213_10.fasta completed successfully.
# Blast search for P01213_10.fasta completed in 7013.18 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 08:38:50 GMT
# Running blast search for Q9Y5Q6_1.fasta...
# Blast search for Q9Y5Q6_1.fasta completed successfully.
# Blast search for Q9Y5Q6_1.fasta completed in 250.96 seconds.
# Skipping Q00535.fasta as output file already exists.
# Running blast search for P13164_1.fasta...
# Blast search for P13164_1.fasta completed successfully.
# Blast search for P13164_1.fasta completed in 258.35 seconds.
# Running blast search for P01210_11.fasta...
# Blast search for P01210_11.fasta completed successfully.
# Blast search for P01210_11.fasta completed in 185.99 seconds.
# Running blast search for P01210_6.fasta...
# Blast search for P01210_6.fasta completed successfully.
# Blast search for P01210_6.fasta completed in 330.29 seconds.
# Skipping Q00526.fasta as output file already exists.
# Skipping Q16611.fasta as output file already exists.
# Running blast search for P01213_8.fasta...
# Blast search for P01213_8.fasta completed successfully.
# Blast search for P01213_8.fasta completed in 755.10 seconds.
# Running blast search for P01213_9.fasta...
# Blast search for P01213_9.fasta completed successfully.
# Blast search for P01213_9.fasta completed in 1289.20 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 09:30:00 GMT
# Running blast search for P09912_1.fasta...
# Blast search for P09912_1.fasta completed successfully.
# Blast search for P09912_1.fasta completed in 439.12 seconds.
# Skipping O43808.fasta as output file already exists.
# Skipping P01019.fasta as output file already exists.
# Skipping P01019_1.fasta as output file already exists.
# Running blast search for Q01628_1.fasta...
# Blast search for Q01628_1.fasta completed successfully.
# Blast search for Q01628_1.fasta completed in 2502.81 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 10:19:02 GMT
# Skipping P01019_4.fasta as output file already exists.
# Running blast search for Q9Y5Y5_1.fasta...
# Blast search for Q9Y5Y5_1.fasta completed successfully.
# Blast search for Q9Y5Y5_1.fasta completed in 4304.53 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 11:30:47 GMT
# Running blast search for P01241_1.fasta...
# Blast search for P01241_1.fasta completed successfully.
# Blast search for P01241_1.fasta completed in 4910.40 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 12:52:37 GMT
# Running blast search for P01213_5.fasta...
# Blast search for P01213_5.fasta completed successfully.
# Blast search for P01213_5.fasta completed in 2193.88 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-04 13:29:11 GMT
# Running blast search for P01579_1.fasta...

# %% [markdown]
# # 4.0 Process Bacterial Processed Results

# %% [markdown]
# ## 4.1 Create Master file for processed hits

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results"

# Name of the master file
master_filename = "bacterial_processed_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/bacterial_processed_master_blaster.txt

# %% [markdown]
# ### 4.2 Count hits

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/bacterial_processed_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)
total_files = 0
files_with_hits = 0
files_without_hits = 0

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line:  
                current_query_id = line.split("|")[1].strip()
                total_files += 1  # Increment total files counter
            elif ">" in line:  
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  

    # Count files with and without hits
    for query_id, hits in query_hits.items():
        if hits:
            files_with_hits += 1
        else:
            files_without_hits += 1
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

# Rank and print total hits
print("Ranked total hits for each accession ID:")
for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")

print(f"\nTotal files processed: {total_files}")
print(f"Files with hits: {files_with_hits}")
print(f"Files without hits: {files_without_hits}")

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/bacterial_processed_master_blaster.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Query ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in query_hits.items():
            writer.writerow({'Query ID': query_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Ranked total hits for each accession ID:
# 1. Accession ID: P60484, Total Hits: 250
# 2. Accession ID: Q00535, Total Hits: 250
# 3. Accession ID: P06493, Total Hits: 250
# 4. Accession ID: Q00534, Total Hits: 250
# 5. Accession ID: Q00526, Total Hits: 250
# 6. Accession ID: P24941, Total Hits: 250
# 7. Accession ID: P01019, Total Hits: 250
# 8. Accession ID: P01966, Total Hits: 249
# 9. Accession ID: O43808, Total Hits: 41
# 10. Accession ID: P32247, Total Hits: 27
# 11. Accession ID: P46663, Total Hits: 15
# 12. Accession ID: Q8NFJ6, Total Hits: 9
# 13. Accession ID: P55210, Total Hits: 4
# 14. Accession ID: Q16611, Total Hits: 3
# 15. Accession ID: Q07812, Total Hits: 2
# 16. Accession ID: P25445, Total Hits: 1
#
# Total files processed: 25
# Files with hits: 16
# Files without hits: 0
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/bacterial_processed_master_blaster.csv'

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/bacterial_processed_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)
total_files = 0
files_with_hits = 0
files_without_hits = 0

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line:  
                current_query_id = line.split("|")[1].strip()
                total_files += 1  # Increment total files counter
            elif ">" in line:  
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  

    # Count files with and without hits
    for query_id, hits in query_hits.items():
        if hits:
            files_with_hits += 1
        else:
            files_without_hits += 1
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

# Rank and print total hits
print("Ranked total hits for each accession ID:")
for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")

print(f"\nTotal files processed: {total_files}")
print(f"Files with hits: {files_with_hits}")
print(f"Files without hits: {files_without_hits}")

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/bacterial_processed_master_blaster.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Query ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in query_hits.items():
            writer.writerow({'Query ID': query_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")

# %% [markdown]
# ### 4.3 Create comprehensive processed csv

# %%
import os
import csv
import re

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/comp_bacterial_processed_results.csv"

# Function to extract query ID from file name and remove suffixes
def extract_query_id(file_name):
    return re.sub(r'_[0-9]+.*$', '', file_name.replace("_blastp_results.txt", ""))

# Parse out required data from blast results
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        accession_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0 
        hit_id = None 
        species_id = None 
        seq_length = None  
        evalue = None 
        score = None  
        identities = None  
        positives = None  
        gaps = None  
        query_definition = None  
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1 
                hit_id = line.split(">")[1].split(" ")[0]
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
                query_definition = line  # Assuming entire line is query definition

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
            elif hit_id and "Expect =" in line:
                evalue = line.split("Expect = ")[1].split(",")[0].strip()
                score = line.split("Score = ")[1].split(" bits")[0].strip()
            elif hit_id and "Identities =" in line:
                identities_str = line.split("Identities = ")[1].split(",")[0].strip()
                identities = round(float(identities_str.split(" ")[0].split("/")[0]) / float(identities_str.split(" ")[0].split("/")[1]) * 100, 2)
                positives_str = line.split("Positives = ")[1].split(",")[0].strip()
                positives = positives_str.split(" ")[0]
                gaps_str = line.split("Gaps = ")[1].split(" ")[0].strip()
                gaps = gaps_str
                hits_data.append([
                    os.path.basename(file_path), accession_id, hit_number, hit_id, seq_length, species_id, 
                    query_definition, "N/A", score, evalue, identities, positives, gaps, "Query", "Subject", "Bacteria"
                ])
    return hits_data

# List to store parsed data
parsed_data = []

# List to store excluded file names
excluded_files = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"): 
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))
    else:
        excluded_files.append(file_name)  

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow([
        "File Name", "Accession ID", "Hit Number", "Hit ID", "Hit Length", "Species", 
        "Query Definition", "Hsp Bit Score", "Hsp Score", "Hsp E-value", 
        "Identity", "Positives", "Gaps", "Hsp Qseq", "Hsp Hseq", "Database"
    ])
    # Write parsed data
    writer.writerows(parsed_data)

print(f"CSV file created successfully with {len(parsed_data)} entries.")

# Print excluded file names
if excluded_files:
    print("\nExcluded files:")
    for file_name in excluded_files:
        print(file_name)
else:
    print("\nNo files were excluded.")
# Out:
# CSV file created successfully with 3587 entries.
#
# Excluded files:
# comp_bacterial_processed_results.csv
# merged_bacterial_processed_results.csv
# species
# bacterial_processed_master_blaster.txt
# Bacterial_peptide_names.csv
# .ipynb_checkpoints
# final_bacterial_processed_results.csv
# bacterial_processed_results.csv
# bacterial_processed_master_blaster.csv
# Bacterial_peptide_names.txt

# %% [markdown]
# ### 4.4 Add Protein Names

# %%
import csv

# Input and output file paths
input_file = "/home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/protein_names.txt"
output_file = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/protein_names.csv"

# Initialize a dictionary to track seen combinations of protein type and accession ID
seen_combinations = {}

# Process the lines to split data and prepare for CSV writing
data = []
with open(input_file, 'r', encoding='utf-8') as txt_file:
    try:
        reader = csv.reader(txt_file, delimiter='\t')
        for line_data in reader:
            # Skip empty lines
            if not line_data or all(cell.strip() == '' for cell in line_data):
                continue
            
            # Ensure each line has enough cells to contain at least Protein Type and Accession ID
            if len(line_data) >= 2:
                protein_type = line_data[0].strip()
                accession_id = line_data[1].strip()
                if accession_id: 
                   
                    key = (protein_type, accession_id)
                    if key not in seen_combinations:
                        seen_combinations[key] = True
                        data.append(line_data)
    except UnicodeDecodeError:
        print(f"Error decoding line in file: {input_file}")
        

# Write the processed data to CSV file
with open(output_file, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(data)

print(f"Converted {input_file} to CSV format at {output_file}")
# Out:
# Converted /home/osheakes/Research_Project_MMM/Fasta/Archaeal_Blasts/Archaeal_Hits/protein_names.txt to CSV format at /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/protein_names.csv

# %%
import csv

# Input file paths
comp_archaeal_file = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/comp_bacterial_processed_results.csv"
protein_names_file = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/protein_names.csv"
output_file = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/bacterial_processed_results.csv"


# Step 1: Load data from protein_names.csv into a dictionary
accession_info = {}
with open(protein_names_file, 'r', encoding='utf-8') as csv_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        accession_id = row['Accession ID'].strip()
        protein_type = row['Protein Type'].strip()
        protein_names = row['Protein Names'].strip()
        accession_info[accession_id] = {
            'ProteinType': protein_type,
            'ProteinNames': protein_names
        }

# Step 2: Merge data with comp_archaeal_processed_results.csv and add new columns
merged_data = []
with open(comp_archaeal_file, 'r', encoding='utf-8') as csv_file:
    reader = csv.reader(csv_file)
    header = next(reader)
    header.insert(1, 'Protein Type')
    header.insert(2, 'Protein Names')
    merged_data.append(header)

    for row in reader:
        accession_id = row[1].strip()

        if accession_id in accession_info:
            protein_type = accession_info[accession_id]['ProteinType']
            protein_names = accession_info[accession_id]['ProteinNames']
        else:
            protein_type = ''
            protein_names = ''

        row.insert(1, protein_type)
        row.insert(2, protein_names)
        merged_data.append(row)

# Step 3: Write merged data to final_archaeal_processed_results.csv
with open(output_file, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(merged_data)

print(f"Merged data from {comp_archaeal_file} and {protein_names_file} into {output_file}")
# Out:
# Merged data from /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/comp_bacterial_processed_results.csv and /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/protein_names.csv into /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/bacterial_processed_results.csv

# %% [markdown]
# ## 5.0 Extract some key metrics from the Processed Search

# %% [markdown]
# ### 5.1 Print Queries which Produced hits

# %%
import csv

# Path to the CSV file
csv_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/merged_bacterial_processed_results.csv"
# Initialize a set to store unique Accession IDs
unique_accession_ids = set()

try:
    # Open and read the CSV file
    with open(csv_file_path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        # Loop through each row in the CSV file
        for row in csv_reader:
            # Extract the Accession ID and add it to the set
            accession_id = row['Accession ID']  # Replace 'Accession ID' with the actual column name if different
            unique_accession_ids.add(accession_id)
    
    # Print each unique Accession ID
    for accession_id in unique_accession_ids:
        print(accession_id)
    
    # Print the total number of unique Accession IDs
    print(f"Total number of unique Accession IDs: {len(unique_accession_ids)}")

except FileNotFoundError:
    print(f"Error: File '{csv_file_path}' not found.")
except KeyError:
    print("Error: 'Accession ID' column not found in the CSV file. Please check the column name.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Q99653_1
# O43745_1
# Q00534
# P06493
# Q10589_1
# Q07812
# Q01628_1
# Q00526
# O43808
# P19883_1
# Q8NFJ6
# P13164_1
# P09914_1
# P09912_1
# P46663
# Q9Y5Q6_1
# P01574_1
# Q9Y5Y5_1
# P25445
# Q9Y5Q6_2
# Q16611
# Q01453_1
# P55210
# P01966
# P01019
# P60484
# Q00535
# Q01629_1
# P01241_1
# P24941
# P32247
# Total number of unique Accession IDs: 31

# %% [markdown]
# ### 5.2 Print the number of input files

# %%
import os

# Path to the directory
directory_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/"

# Initialize a counter for FASTA files
fasta_file_count = 0

# Iterate through the files in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".fasta") or file_name.endswith(".fa"): 
        fasta_file_count += 1

# Print the total number of FASTA files
print(f"Total number of FASTA files: {fasta_file_count}")
# Out:
# Total number of FASTA files: 69

# %% [markdown]
# #

# %% [markdown]
# ## 6.0 Perform species analysis

# %% [markdown]
# ### 6.1 Create directory

# %%
# !mkdir  "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/species"

# %% [markdown]
# ### 6.2 Create Unique list of species

# %%
# !awk -F "," '{ print $8 }' /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/bacterial_processed_results.csv | sort | uniq > /home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/species/unique_bacteria.txt

# %% [markdown]
# ### 6.3 Run Taxonkit on Unique Species

# %%
import subprocess

# Path to the unique-species.txt file
file_path =  "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacterial_results/species/unique_bacteria.txt"
# Path to the taxonkit binary
taxonkit_path = '/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit'

# Read the species names from the file
with open(file_path, 'r') as file:
    species_names = [line.strip() for line in file.readlines()]

# Define a function to apply the command to each species name
def process_species_name(species_name):
    # Construct the command
    cmd = f'echo "{species_name}" | {taxonkit_path} name2taxid | {taxonkit_path} reformat -I 2'
    # Run the command
    result = subprocess.run(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    # Debug: Print command and output
    print(f"Command: {cmd}")
    print(f"Stdout: {result.stdout.strip()}")
    print(f"Stderr: {result.stderr.strip()}")
    # Return the output
    return result.stdout.strip()

# Process each species name and store the results
results = {species: process_species_name(species) for species in species_names}

# Print the results
for species, output in results.items():
    print(f'{species}:\n{output}\n')

# Optionally, save the results to a new file
output_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacteria_results/species/processed_species.txt"
with open(output_file_path, 'w') as output_file:
    for species, output in results.items():
        output_file.write(f'{species}:\n{output}\n\n')
# Out:
# Command: echo "" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr:
# Command: echo "Acaryochloris sp. SU_5_25" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acaryochloris sp. SU_5_25	2720481	Bacteria;Cyanobacteriota;Cyanophyceae;Acaryochloridales;Acaryochloridaceae;Acaryochloris;Acaryochloris sp. SU_5_25
# Stderr:
# Command: echo "Acetobacter estunensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acetobacter estunensis	104097	Bacteria;Pseudomonadota;Alphaproteobacteria;Rhodospirillales;Acetobacteraceae;Acetobacter;Acetobacter estunensis
# Stderr:
# Command: echo "Acidaminobacter" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidaminobacter	65402	Bacteria;Bacillota;Clostridia;Peptostreptococcales;Acidaminobacteraceae;Acidaminobacter;
# Stderr:
# Command: echo "Acidicapsa acidisoli" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidicapsa acidisoli	1615681	Bacteria;Acidobacteriota;Terriglobia;Terriglobales;Acidobacteriaceae;Acidicapsa;Acidicapsa acidisoli
# Stderr:
# Command: echo "Acidiferrobacter" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidiferrobacter	986106	Bacteria;Pseudomonadota;Gammaproteobacteria;Acidiferrobacterales;Acidiferrobacteraceae;Acidiferrobacter;
# Stderr:
# Command: echo "Acidimicrobiaceae bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidimicrobiaceae bacterium	2024894	Bacteria;Actinomycetota;Acidimicrobiia;Acidimicrobiales;Acidimicrobiaceae;;Acidimicrobiaceae bacterium
# Stderr:
# Command: echo "Acidimicrobiales bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidimicrobiales bacterium	2201156	Bacteria;Actinomycetota;Acidimicrobiia;Acidimicrobiales;;;Acidimicrobiales bacterium
# Stderr:
# Command: echo "Acidisarcina polymorpha" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidisarcina polymorpha	2211140	Bacteria;Acidobacteriota;Terriglobia;Terriglobales;Acidobacteriaceae;Acidisarcina;Acidisarcina polymorpha
# Stderr:
# Command: echo "Acidobacteria bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:27:38.731 [ERRO] invalid TaxId:
# Command: echo "Acidobacteriaceae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidobacteriaceae	204434	Bacteria;Acidobacteriota;Terriglobia;Terriglobales;Acidobacteriaceae;;
# Stderr:
# Command: echo "Acidobacteriaceae bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidobacteriaceae bacterium	2052142	Bacteria;Acidobacteriota;Terriglobia;Terriglobales;Acidobacteriaceae;;Acidobacteriaceae bacterium
# Stderr:
# Command: echo "Acidobacteriota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidobacteriota	57723	Bacteria;Acidobacteriota;;;;;
# Stderr:
# Command: echo "Acidobacteriota bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidobacteriota bacterium	1978231	Bacteria;Acidobacteriota;;;;;Acidobacteriota bacterium
# Stderr:
# Command: echo "Acidobacterium sp. S8" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acidobacterium sp. S8	1641854	Bacteria;Acidobacteriota;Terriglobia;Terriglobales;Acidobacteriaceae;Acidobacterium;Acidobacterium sp. S8
# Stderr:
# Command: echo "Acinetobacter" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acinetobacter	469	Bacteria;Pseudomonadota;Gammaproteobacteria;Moraxellales;Moraxellaceae;Acinetobacter;
# Stderr:
# Command: echo "Acinetobacter baumannii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acinetobacter baumannii	470	Bacteria;Pseudomonadota;Gammaproteobacteria;Moraxellales;Moraxellaceae;Acinetobacter;Acinetobacter baumannii
# Stderr:
# Command: echo "Acinetobacter baylyi" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acinetobacter baylyi	202950	Bacteria;Pseudomonadota;Gammaproteobacteria;Moraxellales;Moraxellaceae;Acinetobacter;Acinetobacter baylyi
# Stderr:
# Command: echo "Acinetobacter junii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acinetobacter junii	40215	Bacteria;Pseudomonadota;Gammaproteobacteria;Moraxellales;Moraxellaceae;Acinetobacter;Acinetobacter junii
# Stderr:
# Command: echo "Acinetobacter junii CIP 107470 = MTCC 11364" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acinetobacter junii CIP 107470 = MTCC 11364	1217666	Bacteria;Pseudomonadota;Gammaproteobacteria;Moraxellales;Moraxellaceae;Acinetobacter;Acinetobacter junii
# Stderr:
# Command: echo "Acinetobacter pittii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acinetobacter pittii	48296	Bacteria;Pseudomonadota;Gammaproteobacteria;Moraxellales;Moraxellaceae;Acinetobacter;Acinetobacter pittii
# Stderr:
# Command: echo "Actinacidiphila soli" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinacidiphila soli	2487275	Bacteria;Actinomycetota;Actinomycetes;Kitasatosporales;Streptomycetaceae;Actinacidiphila;Actinacidiphila soli
# Stderr:
# Command: echo "Actinocrinis puniceicyclus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinocrinis puniceicyclus	977794	Bacteria;Actinomycetota;Actinomycetes;Catenulisporales;Actinospicaceae;Actinocrinis;Actinocrinis puniceicyclus
# Stderr:
# Command: echo "Actinomadura barringtoniae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomadura barringtoniae	1427535	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Thermomonosporaceae;Actinomadura;Actinomadura barringtoniae
# Stderr:
# Command: echo "Actinomadura fulvescens" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomadura fulvescens	46160	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Thermomonosporaceae;Actinomadura;Actinomadura fulvescens
# Stderr:
# Command: echo "Actinomadura keratinilytica" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomadura keratinilytica	547461	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Thermomonosporaceae;Actinomadura;Actinomadura keratinilytica
# Stderr:
# Command: echo "Actinomadura kijaniata" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomadura kijaniata	46161	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Thermomonosporaceae;Actinomadura;Actinomadura kijaniata
# Stderr:
# Command: echo "Actinomadura litoris" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomadura litoris	2678616	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Thermomonosporaceae;Actinomadura;Actinomadura litoris
# Stderr:
# Command: echo "Actinomadura namibiensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomadura namibiensis	182080	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Thermomonosporaceae;Actinomadura;Actinomadura namibiensis
# Stderr:
# Command: echo "Actinomadura parmotrematis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomadura parmotrematis	2864039	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Thermomonosporaceae;Actinomadura;Actinomadura parmotrematis
# Stderr:
# Command: echo "Actinomadura rudentiformis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomadura rudentiformis	359158	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Thermomonosporaceae;Actinomadura;Actinomadura rudentiformis
# Stderr:
# Command: echo "Actinomadura rupiterrae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomadura rupiterrae	559627	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Thermomonosporaceae;Actinomadura;Actinomadura rupiterrae
# Stderr:
# Command: echo "Actinomycetales bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomycetales bacterium	1911520	Bacteria;Actinomycetota;Actinomycetes;Actinomycetales;;;Actinomycetales bacterium
# Stderr:
# Command: echo "Actinomycetes bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomycetes bacterium	1883427	Bacteria;Actinomycetota;Actinomycetes;;;;Actinomycetes bacterium
# Stderr:
# Command: echo "Actinomycetota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomycetota	201174	Bacteria;Actinomycetota;;;;;
# Stderr:
# Command: echo "Actinomycetota bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomycetota bacterium	2900548	Bacteria;Actinomycetota;;;;;Actinomycetota bacterium
# Stderr:
# Command: echo "Actinophytocola xanthii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinophytocola xanthii	1912961	Bacteria;Actinomycetota;Actinomycetes;Pseudonocardiales;Pseudonocardiaceae;Actinophytocola;Actinophytocola xanthii
# Stderr:
# Command: echo "Actinoplanes auranticolor" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinoplanes auranticolor	47988	Bacteria;Actinomycetota;Actinomycetes;Micromonosporales;Micromonosporaceae;Actinoplanes;Actinoplanes auranticolor
# Stderr:
# Command: echo "Actinospica durhamensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinospica durhamensis	1508375	Bacteria;Actinomycetota;Actinomycetes;Catenulisporales;Actinospicaceae;Actinospica;Actinospica durhamensis
# Stderr:
# Command: echo "Actinotalea fermentans" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinotalea fermentans	43671	Bacteria;Actinomycetota;Actinomycetes;Micrococcales;Cellulomonadaceae;Actinotalea;Actinotalea fermentans
# Stderr:
# Command: echo "Actinotalea sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinotalea sp.	1872145	Bacteria;Actinomycetota;Actinomycetes;Micrococcales;Cellulomonadaceae;Actinotalea;Actinotalea sp.
# Stderr:
# Command: echo "Adhaeribacter arboris" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Adhaeribacter arboris	2072846	Bacteria;Bacteroidota;Cytophagia;Cytophagales;Hymenobacteraceae;Adhaeribacter;Adhaeribacter arboris
# Stderr:
# Command: echo "Aeoliella straminimaris" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeoliella straminimaris	2954799	Bacteria;Planctomycetota;Planctomycetia;Pirellulales;Lacipirellulaceae;Aeoliella;Aeoliella straminimaris
# Stderr:
# Command: echo "Aequorivita capsosiphonis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aequorivita capsosiphonis	487317	Bacteria;Bacteroidota;Flavobacteriia;Flavobacteriales;Flavobacteriaceae;Aequorivita;Aequorivita capsosiphonis
# Stderr:
# Command: echo "Aequorivita lipolytica" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aequorivita lipolytica	153267	Bacteria;Bacteroidota;Flavobacteriia;Flavobacteriales;Flavobacteriaceae;Aequorivita;Aequorivita lipolytica
# Stderr:
# Command: echo "Aequorivita sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aequorivita sp.	1872390	Bacteria;Bacteroidota;Flavobacteriia;Flavobacteriales;Flavobacteriaceae;Aequorivita;Aequorivita sp.
# Stderr:
# Command: echo "Aerococcus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aerococcus	1375	Bacteria;Bacillota;Bacilli;Lactobacillales;Aerococcaceae;Aerococcus;
# Stderr:
# Command: echo "Aerococcus urinaeequi" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aerococcus urinaeequi	51665	Bacteria;Bacillota;Bacilli;Lactobacillales;Aerococcaceae;Aerococcus;Aerococcus urinaeequi
# Stderr:
# Command: echo "Aerococcus viridans" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aerococcus viridans	1377	Bacteria;Bacillota;Bacilli;Lactobacillales;Aerococcaceae;Aerococcus;Aerococcus viridans
# Stderr:
# Command: echo "Aeromicrobium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromicrobium	2040	Bacteria;Actinomycetota;Actinomycetes;Propionibacteriales;Nocardioidaceae;Aeromicrobium;
# Stderr:
# Command: echo "Aeromicrobium duanguangcaii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromicrobium duanguangcaii	2968086	Bacteria;Actinomycetota;Actinomycetes;Propionibacteriales;Nocardioidaceae;Aeromicrobium;Aeromicrobium duanguangcaii
# Stderr:
# Command: echo "Aeromicrobium flavum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromicrobium flavum	416568	Bacteria;Actinomycetota;Actinomycetes;Propionibacteriales;Nocardioidaceae;Aeromicrobium;Aeromicrobium flavum
# Stderr:
# Command: echo "Aeromicrobium halocynthiae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromicrobium halocynthiae	560557	Bacteria;Actinomycetota;Actinomycetes;Propionibacteriales;Nocardioidaceae;Aeromicrobium;Aeromicrobium halocynthiae
# Stderr:
# Command: echo "Aeromicrobium phoceense" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromicrobium phoceense	2754045	Bacteria;Actinomycetota;Actinomycetes;Propionibacteriales;Nocardioidaceae;Aeromicrobium;Aeromicrobium phoceense
# Stderr:
# Command: echo "Aeromicrobium tamlense" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromicrobium tamlense	375541	Bacteria;Actinomycetota;Actinomycetes;Propionibacteriales;Nocardioidaceae;Aeromicrobium;Aeromicrobium tamlense
# Stderr:
# Command: echo "Aeromonas" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromonas	642	Bacteria;Pseudomonadota;Gammaproteobacteria;Aeromonadales;Aeromonadaceae;Aeromonas;
# Stderr:
# Command: echo "Aeromonas caviae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromonas caviae	648	Bacteria;Pseudomonadota;Gammaproteobacteria;Aeromonadales;Aeromonadaceae;Aeromonas;Aeromonas caviae
# Stderr:
# Command: echo "Aeromonas sanarellii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromonas sanarellii	633415	Bacteria;Pseudomonadota;Gammaproteobacteria;Aeromonadales;Aeromonadaceae;Aeromonas;Aeromonas sanarellii
# Stderr:
# Command: echo "Aeromonas sp. ASNIH5" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromonas sp. ASNIH5	1758179	Bacteria;Pseudomonadota;Gammaproteobacteria;Aeromonadales;Aeromonadaceae;Aeromonas;Aeromonas sp. ASNIH5
# Stderr:
# Command: echo "Aeromonas sp. FDAARGOS 1409" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromonas sp. FDAARGOS 1409	2778058	Bacteria;Pseudomonadota;Gammaproteobacteria;Aeromonadales;Aeromonadaceae;Aeromonas;Aeromonas sp. FDAARGOS 1409
# Stderr:
# Command: echo "Aeromonas sp. SrichE-2G" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromonas sp. SrichE-2G	2823359	Bacteria;Pseudomonadota;Gammaproteobacteria;Aeromonadales;Aeromonadaceae;Aeromonas;Aeromonas sp. SrichE-2G
# Stderr:
# Command: echo "Aeromonas taiwanensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromonas taiwanensis	633417	Bacteria;Pseudomonadota;Gammaproteobacteria;Aeromonadales;Aeromonadaceae;Aeromonas;Aeromonas taiwanensis
# Stderr:
# Command: echo "Aeromonas tecta" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromonas tecta	324617	Bacteria;Pseudomonadota;Gammaproteobacteria;Aeromonadales;Aeromonadaceae;Aeromonas;Aeromonas tecta
# Stderr:
# Command: echo "Aeromonas veronii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aeromonas veronii	654	Bacteria;Pseudomonadota;Gammaproteobacteria;Aeromonadales;Aeromonadaceae;Aeromonas;Aeromonas veronii
# Stderr:
# Command: echo "Aetherobacter fasciculatus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aetherobacter fasciculatus	888830	Bacteria;Myxococcota;;Polyangiales;Polyangiaceae;Aetherobacter;Aetherobacter fasciculatus
# Stderr:
# Command: echo "Aetokthonos hydrillicola" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aetokthonos hydrillicola	1550245	Bacteria;Cyanobacteriota;Cyanophyceae;Nostocales;Hapalosiphonaceae;Aetokthonos;Aetokthonos hydrillicola
# Stderr:
# Command: echo "Agathobacter" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Agathobacter	1766253	Bacteria;Bacillota;Clostridia;Lachnospirales;Lachnospiraceae;Agathobacter;
# Stderr:
# Command: echo "Agitococcus sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Agitococcus sp.	1872415	Bacteria;Pseudomonadota;Gammaproteobacteria;Moraxellales;Moraxellaceae;Agitococcus;Agitococcus sp.
# Stderr:
# Command: echo "Ahniella affigens" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ahniella affigens	2021234	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Rhodanobacteraceae;Ahniella;Ahniella affigens
# Stderr:
# Command: echo "Aliarcobacter" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aliarcobacter	2321111	Bacteria;Campylobacterota;Epsilonproteobacteria;Campylobacterales;Arcobacteraceae;Aliarcobacter;
# Stderr:
# Command: echo "Aliarcobacter butzleri" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aliarcobacter butzleri	28197	Bacteria;Campylobacterota;Epsilonproteobacteria;Campylobacterales;Arcobacteraceae;Aliarcobacter;Aliarcobacter butzleri
# Stderr:
# Command: echo "Aliikangiella coralliicola" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aliikangiella coralliicola	2592383	Bacteria;Pseudomonadota;Gammaproteobacteria;Oceanospirillales;Pleioneaceae;Aliikangiella;Aliikangiella coralliicola
# Stderr:
# Command: echo "Alkalicella caledoniensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Alkalicella caledoniensis	2731377	Bacteria;Bacillota;Clostridia;Eubacteriales;Proteinivoraceae;Alkalicella;Alkalicella caledoniensis
# Stderr:
# Command: echo "Allonocardiopsis opalescens" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Allonocardiopsis opalescens	1144618	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;;Allonocardiopsis;Allonocardiopsis opalescens
# Stderr:
# Command: echo "Alloprevotella sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Alloprevotella sp.	1872471	Bacteria;Bacteroidota;Bacteroidia;Bacteroidales;Prevotellaceae;Alloprevotella;Alloprevotella sp.
# Stderr:
# Command: echo "Alphaproteobacteria bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Alphaproteobacteria bacterium	1913988	Bacteria;Pseudomonadota;Alphaproteobacteria;;;;Alphaproteobacteria bacterium
# Stderr:
# Command: echo "Alphaproteobacteria bacterium HT1-32" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Alphaproteobacteria bacterium HT1-32	2665153	Bacteria;Pseudomonadota;Alphaproteobacteria;;;;Alphaproteobacteria bacterium HT1-32
# Stderr:
# Command: echo "Alteromonas sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Alteromonas sp.	232	Bacteria;Pseudomonadota;Gammaproteobacteria;Alteromonadales;Alteromonadaceae;Alteromonas;Alteromonas sp.
# Stderr:
# Command: echo "Amycolatopsis cynarae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amycolatopsis cynarae	2995223	Bacteria;Actinomycetota;Actinomycetes;Pseudonocardiales;Pseudonocardiaceae;Amycolatopsis;Amycolatopsis cynarae
# Stderr:
# Command: echo "Amycolatopsis rhizosphaerae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amycolatopsis rhizosphaerae	2053003	Bacteria;Actinomycetota;Actinomycetes;Pseudonocardiales;Pseudonocardiaceae;Amycolatopsis;Amycolatopsis rhizosphaerae
# Stderr:
# Command: echo "Anabaena sp. PCC 7108" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anabaena sp. PCC 7108	163908	Bacteria;Cyanobacteriota;Cyanophyceae;Nostocales;Nostocaceae;Anabaena;Anabaena sp. PCC 7108
# Stderr:
# Command: echo "Anabaena sp. UHCC 0451" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anabaena sp. UHCC 0451	2055235	Bacteria;Cyanobacteriota;Cyanophyceae;Nostocales;Nostocaceae;Anabaena;Anabaena sp. UHCC 0451
# Stderr:
# Command: echo "Anaerolineaceae bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anaerolineaceae bacterium	2024896	Bacteria;Chloroflexota;Anaerolineae;Anaerolineales;Anaerolineaceae;;Anaerolineaceae bacterium
# Stderr:
# Command: echo "Anaerolineae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anaerolineae	292625	Bacteria;Chloroflexota;Anaerolineae;;;;
# Stderr:
# Command: echo "Anaerolineae bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anaerolineae bacterium	2052143	Bacteria;Chloroflexota;Anaerolineae;;;;Anaerolineae bacterium
# Stderr:
# Command: echo "Anaerolineales bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anaerolineales bacterium	2073117	Bacteria;Chloroflexota;Anaerolineae;Anaerolineales;;;Anaerolineales bacterium
# Stderr:
# Command: echo "Anaerolineales bacterium HSG25" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anaerolineales bacterium HSG25	3055601	Bacteria;Chloroflexota;Anaerolineae;Anaerolineales;;;Anaerolineales bacterium HSG25
# Stderr:
# Command: echo "Anaeromyxobacter sp. RBG_16_69_14" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anaeromyxobacter sp. RBG_16_69_14	1797238	Bacteria;Myxococcota;Myxococcia;Myxococcales;Anaeromyxobacteraceae;Anaeromyxobacter;Anaeromyxobacter sp. RBG_16_69_14
# Stderr:
# Command: echo "Angustibacter aerolatus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Angustibacter aerolatus	1162965	Bacteria;Actinomycetota;Actinomycetes;Kineosporiales;Kineosporiaceae;Angustibacter;Angustibacter aerolatus
# Stderr:
# Command: echo "Angustibacter sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Angustibacter sp.	1871064	Bacteria;Actinomycetota;Actinomycetes;Kineosporiales;Kineosporiaceae;Angustibacter;Angustibacter sp.
# Stderr:
# Command: echo "Apibacter sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apibacter sp.	2023709	Bacteria;Bacteroidota;Flavobacteriia;Flavobacteriales;Weeksellaceae;Apibacter;Apibacter sp.
# Stderr:
# Command: echo "Apibacter sp. B3889" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apibacter sp. B3889	2656768	Bacteria;Bacteroidota;Flavobacteriia;Flavobacteriales;Weeksellaceae;Apibacter;Apibacter sp. B3889
# Stderr:
# Command: echo "Apibacter sp. B3935" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apibacter sp. B3935	2656773	Bacteria;Bacteroidota;Flavobacteriia;Flavobacteriales;Weeksellaceae;Apibacter;Apibacter sp. B3935
# Stderr:
# Command: echo "Aquificota bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aquificota bacterium	2202151	Bacteria;Aquificota;;;;;Aquificota bacterium
# Stderr:
# Command: echo "Arcobacter" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arcobacter	28196	Bacteria;Campylobacterota;Epsilonproteobacteria;Campylobacterales;Arcobacteraceae;Arcobacter;
# Stderr:
# Command: echo "Ardenticatenales bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ardenticatenales bacterium	2614248	Bacteria;Chloroflexota;Ardenticatenia;Ardenticatenales;;;Ardenticatenales bacterium
# Stderr:
# Command: echo "Arenimonas donghaensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arenimonas donghaensis	375061	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Arenimonas;Arenimonas donghaensis
# Stderr:
# Command: echo "Arenimonas donghaensis DSM 18148" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 01:31:40.875 [ERRO] invalid TaxId:
# Command: echo "Arenimonas sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arenimonas sp.	1872635	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Arenimonas;Arenimonas sp.
# Stderr:
# Command: echo "Armatimonadia bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Armatimonadia bacterium	2663015	Bacteria;Armatimonadota;Armatimonadia;;;;Armatimonadia bacterium
# Stderr:
# Command: echo "Armatimonadota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Armatimonadota	67819	Bacteria;Armatimonadota;;;;;
# Stderr:
# Command: echo "Armatimonadota bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Armatimonadota bacterium	2033014	Bacteria;Armatimonadota;;;;;Armatimonadota bacterium
# Stderr:
# Command: echo "Arthrobacter pascens" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arthrobacter pascens	1677	Bacteria;Actinomycetota;Actinomycetes;Micrococcales;Micrococcaceae;Arthrobacter;Arthrobacter pascens
# Stderr:
# Command: echo "Asticcacaulis sp. AC460" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Asticcacaulis sp. AC460	1282360	Bacteria;Pseudomonadota;Alphaproteobacteria;Caulobacterales;Caulobacteraceae;Asticcacaulis;Asticcacaulis sp. AC460
# Stderr:
# Command: echo "Bacilli bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacilli bacterium	1903720	Bacteria;Bacillota;Bacilli;;;;Bacilli bacterium
# Stderr:
# Command: echo "Bacillota" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacillota	1239	Bacteria;Bacillota;;;;;
# Stderr:
# Command: echo "Bacillota bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacillota bacterium	1879010	Bacteria;Bacillota;;;;;Bacillota bacterium
# Stderr:
# Command: echo "Bacillus spizizenii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacillus spizizenii	96241	Bacteria;Bacillota;Bacilli;Bacillales;Bacillaceae;Bacillus;Bacillus spizizenii
# Stderr:
# Command: echo "Bacillus subtilis BEST7613" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacillus subtilis BEST7613	1204343	Bacteria;Bacillota;Bacilli;Bacillales;Bacillaceae;Bacillus;Bacillus subtilis
# Stderr:
# Command: echo "Bacillus thuringiensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacillus thuringiensis	1428	Bacteria;Bacillota;Bacilli;Bacillales;Bacillaceae;Bacillus;Bacillus thuringiensis
# Stderr:
# Command: echo "Bacillus velezensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacillus velezensis	492670	Bacteria;Bacillota;Bacilli;Bacillales;Bacillaceae;Bacillus;Bacillus velezensis
# Stderr:
# Command: echo "Bacteria" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacteria	2	Bacteria;;;;;;
# Bacteria	629395	Eukaryota;Arthropoda;Insecta;Phasmatodea;Diapheromeridae;Bacteria Latreille et al. 1825;
# Stderr:
# Command: echo "bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: bacterium	1869227	Bacteria;;;;;;bacterium
# Stderr:
# Command: echo "bacterium ADurb.Bin363" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: bacterium ADurb.Bin363	1866927	Bacteria;;;;;;bacterium ADurb.Bin363
# Stderr:
# Command: echo "bacterium ADurb.Bin374" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: bacterium ADurb.Bin374	1866937	Bacteria;;;;;;bacterium ADurb.Bin374
# Stderr:
# Command: echo "bacterium BMS3Abin10" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: bacterium BMS3Abin10	2005718	Bacteria;;;;;;bacterium BMS3Abin10
# Stderr:
# Command: echo "bacterium BMS3Bbin08" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: bacterium BMS3Bbin08	2005731	Bacteria;;;;;;bacterium BMS3Bbin08
# Stderr:
# Command: echo "bacterium CG2_30_54_10" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: bacterium CG2_30_54_10	1805403	Bacteria;;;;;;bacterium CG2_30_54_10
# Stderr:
# Command: echo "bacterium HR14" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: bacterium HR14	2035409	Bacteria;;;;;;bacterium HR14
# Stderr:
# Command: echo "bacterium HR15" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: bacterium HR15	2035410	Bacteria;;;;;;bacterium HR15
# Stderr:
# Command: echo "bacterium TMED46" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: bacterium TMED46	1986782	Bacteria;;;;;;bacterium TMED46
# Stderr:
# Command: echo "Bacteroidaceae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacteroidaceae	815	Bacteria;Bacteroidota;Bacteroidia;Bacteroidales;Bacteroidaceae;;
# Stderr:
# Command: echo "Bacteroidales bacterium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacteroidales bacterium	2030927	Bacteria;Bacteroidota;Bacteroidia;Bacteroidales;;;Bacteroidales bacterium
# Stderr:
# Command: echo "Bacteroides fragilis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacteroides fragilis	817	Bacteria;Bacteroidota;Bacteroidia;Bacteroidales;Bacteroidaceae;Bacteroides;Bacteroides fragilis
# Stderr:
# Command: echo "Bacteroides sp." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Bacteroides sp.	29523	Bacteria;Bacteroidota;Bacteroidia;Bacteroidales;Bacteroidaceae;Bacteroides;Bacteroides sp.
# Stderr:
# ...
#
# Telmatocola sphagniphila:
# Telmatocola sphagniphila	1123043	Bacteria;Planctomycetota;Planctomycetia;Gemmatales;Gemmataceae;Telmatocola;Telmatocola sphagniphila
#
# Tenuifilaceae bacterium:
# Tenuifilaceae bacterium	2952975	Bacteria;Bacteroidota;Bacteroidia;Bacteroidales;Tenuifilaceae;;Tenuifilaceae bacterium
#
# Tepidimicrobium:
# Tepidimicrobium	285105	Bacteria;Bacillota;Tissierellia;Tissierellales;Tepidimicrobiaceae;Tepidimicrobium;
#
# Terriglobales bacterium:
# Terriglobales bacterium	2282142	Bacteria;Acidobacteriota;Terriglobia;Terriglobales;;;Terriglobales bacterium
#
# Terriglobia bacterium:
# Terriglobia bacterium	2081523	Bacteria;Acidobacteriota;Terriglobia;;;;Terriglobia bacterium
#
# Tetragenococcus:
# Tetragenococcus	51668	Bacteria;Bacillota;Bacilli;Lactobacillales;Enterococcaceae;Tetragenococcus;
#
# Tetragenococcus muriaticus PMC-11-5:
# Tetragenococcus muriaticus PMC-11-5	1302649	Bacteria;Bacillota;Bacilli;Lactobacillales;Enterococcaceae;Tetragenococcus;Tetragenococcus muriaticus
#
# Thalassoglobus polymorphus:
# Thalassoglobus polymorphus	2527994	Bacteria;Planctomycetota;Planctomycetia;Planctomycetales;Planctomycetaceae;Thalassoglobus;Thalassoglobus polymorphus
#
# Thermoanaerobaculia:
# Thermoanaerobaculia	1562571	Bacteria;Acidobacteriota;Thermoanaerobaculia;;;;
#
# Thermoanaerobaculia bacterium:
# Thermoanaerobaculia bacterium	2651171	Bacteria;Acidobacteriota;Thermoanaerobaculia;;;;Thermoanaerobaculia bacterium
#
# Thermodesulfobacteriota:
# Thermodesulfobacteriota	200940	Bacteria;Thermodesulfobacteriota;;;;;
#
# Thermodesulfobacteriota bacterium:
# Thermodesulfobacteriota bacterium	2202153	Bacteria;Thermodesulfobacteriota;;;;;Thermodesulfobacteriota bacterium
#
# Thermogemmata fonticola:
# Thermogemmata fonticola	2755323	Bacteria;Planctomycetota;Planctomycetia;Gemmatales;Gemmataceae;Thermogemmata;Thermogemmata fonticola
#
# Thermogemmatispora:
# Thermogemmatispora	768669	Bacteria;Chloroflexota;Ktedonobacteria;Thermogemmatisporales;Thermogemmatisporaceae;Thermogemmatispora;
#
# Thermogemmatispora carboxidivorans:
# Thermogemmatispora carboxidivorans	1382306	Bacteria;Chloroflexota;Ktedonobacteria;Thermogemmatisporales;Thermogemmatisporaceae;Thermogemmatispora;Thermogemmatispora carboxidivorans
#
# Thermogemmatispora sp.:
# Thermogemmatispora sp.	1968838	Bacteria;Chloroflexota;Ktedonobacteria;Thermogemmatisporales;Thermogemmatisporaceae;Thermogemmatispora;Thermogemmatispora sp.
#
# Thermoguttaceae bacterium:
# Thermoguttaceae bacterium	2691551	Bacteria;Planctomycetota;Planctomycetia;Pirellulales;Thermoguttaceae;;Thermoguttaceae bacterium
#
# Thermoleophilia bacterium:
# Thermoleophilia bacterium	2026888	Bacteria;Actinomycetota;Thermoleophilia;;;;Thermoleophilia bacterium
#
# Thermomicrobiales bacterium:
# Thermomicrobiales bacterium	2482790	Bacteria;Thermomicrobiota;Thermomicrobia;Thermomicrobiales;;;Thermomicrobiales bacterium
#
# Thermomonas hydrothermalis:
# Thermomonas hydrothermalis	213588	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Thermomonas;Thermomonas hydrothermalis
#
# Thermophagus xiamenensis:
# Thermophagus xiamenensis	385682	Bacteria;Bacteroidota;Bacteroidia;Marinilabiliales;Marinilabiliaceae;Thermophagus;Thermophagus xiamenensis
#
# Thermostichales cyanobacterium DRC_bins_46:
# Thermostichales cyanobacterium DRC_bins_46	3064319	Bacteria;Cyanobacteriota;Cyanophyceae;Thermostichales;;;Thermostichales cyanobacterium DRC_bins_46
#
# Thermostichales cyanobacterium SZTDM-1c_bins_54:
# Thermostichales cyanobacterium SZTDM-1c_bins_54	3064327	Bacteria;Cyanobacteriota;Cyanophyceae;Thermostichales;;;Thermostichales cyanobacterium SZTDM-1c_bins_54
#
# Thermotogaceae bacterium:
# Thermotogaceae bacterium	2268206	Bacteria;Thermotogota;Thermotogae;Thermotogales;Thermotogaceae;;Thermotogaceae bacterium
#
# Thermotogota bacterium:
# Thermotogota bacterium	2053689	Bacteria;Thermotogota;;;;;Thermotogota bacterium
#
# Thiobacillaceae bacterium:
# Thiobacillaceae bacterium	2528409	Bacteria;Pseudomonadota;Betaproteobacteria;Nitrosomonadales;Thiobacillaceae;;Thiobacillaceae bacterium
#
# Thiobacillus sp.:
# Thiobacillus sp.	924	Bacteria;Pseudomonadota;Betaproteobacteria;Nitrosomonadales;Thiobacillaceae;Thiobacillus;Thiobacillus sp.
#
# Thiobacillus sp. 63-78:
# Thiobacillus sp. 63-78	1895859	Bacteria;Pseudomonadota;Betaproteobacteria;Nitrosomonadales;Thiobacillaceae;Thiobacillus;Thiobacillus sp. 63-78
#
# Thiobacillus sp. 65-1059:
# Thiobacillus sp. 65-1059	1895860	Bacteria;Pseudomonadota;Betaproteobacteria;Nitrosomonadales;Thiobacillaceae;Thiobacillus;Thiobacillus sp. 65-1059
#
# Thiobacillus sp. 65-1402:
# Thiobacillus sp. 65-1402	1895861	Bacteria;Pseudomonadota;Betaproteobacteria;Nitrosomonadales;Thiobacillaceae;Thiobacillus;Thiobacillus sp. 65-1402
#
# Thiobacillus sp. SCN 64-317:
# Thiobacillus sp. SCN 64-317	1660143	Bacteria;Pseudomonadota;Betaproteobacteria;Nitrosomonadales;Thiobacillaceae;Thiobacillus;Thiobacillus sp. SCN 64-317
#
# Thiobacter sp. AK1:
# Thiobacter sp. AK1	3121275	Bacteria;Pseudomonadota;Betaproteobacteria;Burkholderiales;;Thiobacter;Thiobacter sp. AK1
#
# Thiocystis violacea:
# Thiocystis violacea	13725	Bacteria;Pseudomonadota;Gammaproteobacteria;Chromatiales;Chromatiaceae;Thiocystis;Thiocystis violacea
#
# Thiomargarita sp.:
# Thiomargarita sp.	2822435	Bacteria;Pseudomonadota;Gammaproteobacteria;Thiotrichales;Thiotrichaceae;Thiomargarita;Thiomargarita sp.
#
# Thiorhodococcus mannitoliphagus:
# Thiorhodococcus mannitoliphagus	329406	Bacteria;Pseudomonadota;Gammaproteobacteria;Chromatiales;Chromatiaceae;Thiorhodococcus;Thiorhodococcus mannitoliphagus
#
# Thiorhodococcus minor:
# Thiorhodococcus minor	57489	Bacteria;Pseudomonadota;Gammaproteobacteria;Chromatiales;Chromatiaceae;Thiorhodococcus;Thiorhodococcus minor
#
# Thiorhodovibrio:
# Thiorhodovibrio	61593	Bacteria;Pseudomonadota;Gammaproteobacteria;Chromatiales;Chromatiaceae;Thiorhodovibrio;
#
# Thiothrix sp.:
# Thiothrix sp.	1032	Bacteria;Pseudomonadota;Gammaproteobacteria;Thiotrichales;Thiotrichaceae;Thiothrix;Thiothrix sp.
#
# Trichocoleus sp. DQ-U1:
# Trichocoleus sp. DQ-U1	2933926	Bacteria;Cyanobacteriota;Cyanophyceae;Leptolyngbyales;Trichocoleusaceae;Trichocoleus;Trichocoleus sp. DQ-U1
#
# Tunturibacter psychrotolerans:
# Tunturibacter psychrotolerans	3069686	Bacteria;Acidobacteriota;Terriglobia;Terriglobales;Acidobacteriaceae;Tunturibacter;Tunturibacter psychrotolerans
#
# unclassified:
# unclassified	12908	;;;;;;
#
# unclassified Aquimarina:
# unclassified Aquimarina	2627091	Bacteria;Bacteroidota;Flavobacteriia;Flavobacteriales;Flavobacteriaceae;Aquimarina;
#
# unclassified Coleofasciculus:
# unclassified Coleofasciculus	2692782	Bacteria;Cyanobacteriota;Cyanophyceae;Coleofasciculales;Coleofasciculaceae;Coleofasciculus;
#
# unclassified Microbispora:
# unclassified Microbispora	2614687	Bacteria;Actinomycetota;Actinomycetes;Streptosporangiales;Streptosporangiaceae;Microbispora;
#
# unclassified Moorena:
# unclassified Moorena	2683338	Bacteria;Cyanobacteriota;Cyanophyceae;Oscillatoriales;Oscillatoriaceae;Moorena;
#
# unclassified Pseudoxanthomonas:
# unclassified Pseudoxanthomonas	2645906	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Pseudoxanthomonas;
#
# unclassified Stenotrophomonas:
# unclassified Stenotrophomonas	196198	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Stenotrophomonas;
#
# unclassified Thiobacillus:
# unclassified Thiobacillus	2646513	Bacteria;Pseudomonadota;Betaproteobacteria;Nitrosomonadales;Thiobacillaceae;Thiobacillus;
#
# unclassified Xanthomonas:
# unclassified Xanthomonas	2643310	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;
#
# uncultured:
#
#
# uncultured Acidovorax:
#
#
# uncultured Aquimarina sp.:
# uncultured Aquimarina sp.	575652	Bacteria;Bacteroidota;Flavobacteriia;Flavobacteriales;Flavobacteriaceae;Aquimarina;uncultured Aquimarina sp.
#
# uncultured Arenimonas sp.:
# uncultured Arenimonas sp.	546226	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Arenimonas;uncultured Arenimonas sp.
#
# uncultured Georgenia sp.:
# uncultured Georgenia sp.	378209	Bacteria;Actinomycetota;Actinomycetes;Micrococcales;Bogoriellaceae;Georgenia;uncultured Georgenia sp.
#
# uncultured Roseobacter:
# uncultured Roseobacter	114847	Bacteria;Pseudomonadota;Alphaproteobacteria;Rhodobacterales;Roseobacteraceae;Roseobacter;uncultured Roseobacter sp.
#
# uncultured Roseobacter sp.:
# uncultured Roseobacter sp.	114847	Bacteria;Pseudomonadota;Alphaproteobacteria;Rhodobacterales;Roseobacteraceae;Roseobacter;uncultured Roseobacter sp.
#
# uncultured Rothia sp.:
# uncultured Rothia sp.	316088	Bacteria;Actinomycetota;Actinomycetes;Micrococcales;Micrococcaceae;Rothia;uncultured Rothia sp.
#
# uncultured Rubinisphaera sp.:
# uncultured Rubinisphaera sp.	1678686	Bacteria;Planctomycetota;Planctomycetia;Planctomycetales;Planctomycetaceae;Rubinisphaera;uncultured Rubinisphaera sp.
#
# uncultured Stenotrophomonas sp.:
# uncultured Stenotrophomonas sp.	165438	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Stenotrophomonas;uncultured Stenotrophomonas sp.
#
# Urbifossiella limnaea:
# Urbifossiella limnaea	2528023	Bacteria;Planctomycetota;Planctomycetia;Gemmatales;Gemmataceae;Urbifossiella;Urbifossiella limnaea
#
# Urbifossiella sp.:
# Urbifossiella sp.	2807431	Bacteria;Planctomycetota;Planctomycetia;Gemmatales;Gemmataceae;Urbifossiella;Urbifossiella sp.
#
# Usitatibacter sp.:
# Usitatibacter sp.	2803847	Bacteria;Pseudomonadota;Betaproteobacteria;Nitrosomonadales;Usitatibacteraceae;Usitatibacter;Usitatibacter sp.
#
# Vagococcus:
# Vagococcus	2737	Bacteria;Bacillota;Bacilli;Lactobacillales;Enterococcaceae;Vagococcus;
#
# Verrucomicrobiales bacterium:
# Verrucomicrobiales bacterium	2026801	Bacteria;Verrucomicrobiota;Verrucomicrobiia;Verrucomicrobiales;;;Verrucomicrobiales bacterium
#
# Verrucomicrobiia:
# Verrucomicrobiia	203494	Bacteria;Verrucomicrobiota;Verrucomicrobiia;;;;
#
# Verrucomicrobiia bacterium:
# Verrucomicrobiia bacterium	2499141	Bacteria;Verrucomicrobiota;Verrucomicrobiia;;;;Verrucomicrobiia bacterium
#
# Verrucomicrobiota bacterium:
# Verrucomicrobiota bacterium	2026799	Bacteria;Verrucomicrobiota;;;;;Verrucomicrobiota bacterium
#
# Verrucomicrobium sp.:
# Verrucomicrobium sp.	72225	Bacteria;Verrucomicrobiota;Verrucomicrobiia;Verrucomicrobiales;Verrucomicrobiaceae;Verrucomicrobium;Verrucomicrobium sp.
#
# Verrucosispora sp. ts21:
# Verrucosispora sp. ts21	2069341	Bacteria;Actinomycetota;Actinomycetes;Micromonosporales;Micromonosporaceae;Micromonospora;Verrucosispora sp. ts21
#
# Vibrio parahaemolyticus:
# Vibrio parahaemolyticus	670	Bacteria;Pseudomonadota;Gammaproteobacteria;Vibrionales;Vibrionaceae;Vibrio;Vibrio parahaemolyticus
#
# Vibrio sp. Vb2131:
# Vibrio sp. Vb2131	3074649	Bacteria;Pseudomonadota;Gammaproteobacteria;Vibrionales;Vibrionaceae;Vibrio;Vibrio sp. Vb2131
#
# Vibrio vulnificus:
# Vibrio vulnificus	672	Bacteria;Pseudomonadota;Gammaproteobacteria;Vibrionales;Vibrionaceae;Vibrio;Vibrio vulnificus
#
# Vicinamibacterales bacterium:
# Vicinamibacterales bacterium	2910147	Bacteria;Acidobacteriota;Vicinamibacteria;Vicinamibacterales;;;Vicinamibacterales bacterium
#
# Vicinamibacteria bacterium:
# Vicinamibacteria bacterium	2793154	Bacteria;Acidobacteriota;Vicinamibacteria;;;;Vicinamibacteria bacterium
#
# Waddliaceae bacterium:
# Waddliaceae bacterium	2026802	Bacteria;Chlamydiota;Chlamydiia;Parachlamydiales;Waddliaceae;;Waddliaceae bacterium
#
# Weissella:
# Weissella	46255	Bacteria;Bacillota;Bacilli;Lactobacillales;Lactobacillaceae;Weissella;
#
# Wenzhouxiangella:
# Wenzhouxiangella	1676142	Bacteria;Pseudomonadota;Gammaproteobacteria;Chromatiales;Wenzhouxiangellaceae;Wenzhouxiangella;
#
# Wenzhouxiangella marina:
# Wenzhouxiangella marina	1579979	Bacteria;Pseudomonadota;Gammaproteobacteria;Chromatiales;Wenzhouxiangellaceae;Wenzhouxiangella;Wenzhouxiangella marina
#
# Woeseiaceae bacterium:
# Woeseiaceae bacterium	2026806	Bacteria;Pseudomonadota;Gammaproteobacteria;Woeseiales;Woeseiaceae;;Woeseiaceae bacterium
#
# Woeseia sp.:
# Woeseia sp.	1980636	Bacteria;Pseudomonadota;Gammaproteobacteria;Woeseiales;Woeseiaceae;Woeseia;Woeseia sp.
#
# Xanthocytophaga flavus:
# Xanthocytophaga flavus	3048013	Bacteria;Bacteroidota;Cytophagia;Cytophagales;Rhodocytophagaceae;Xanthocytophaga;Xanthocytophaga flavus
#
# Xanthomonas:
# Xanthomonas	338	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;
#
# Xanthomonas arboricola:
# Xanthomonas arboricola	56448	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas arboricola
#
# Xanthomonas axonopodis:
# Xanthomonas axonopodis	53413	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas axonopodis
#
# Xanthomonas cassavae:
# Xanthomonas cassavae	56450	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas cassavae
#
# Xanthomonas codiaei:
# Xanthomonas codiaei	56463	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas codiaei
#
# Xanthomonas floridensis:
# Xanthomonas floridensis	1843580	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas floridensis
#
# Xanthomonas hortorum:
# Xanthomonas hortorum	56454	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas hortorum
#
# Xanthomonas indica:
# Xanthomonas indica	2912242	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas indica
#
# Xanthomonas pisi:
# Xanthomonas pisi	56457	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas pisi
#
# Xanthomonas sacchari:
# Xanthomonas sacchari	56458	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas sacchari
#
# Xanthomonas sontii:
# Xanthomonas sontii	2650745	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas sontii
#
# Xanthomonas sp. LMG 8992:
# Xanthomonas sp. LMG 8992	1591157	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas sp. LMG 8992
#
# Xanthomonas sp. MUS 060:
# Xanthomonas sp. MUS 060	1588031	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas sp. MUS 060
#
# Xanthomonas translucens:
# Xanthomonas translucens	343	Bacteria;Pseudomonadota;Gammaproteobacteria;Lysobacterales;Lysobacteraceae;Xanthomonas;Xanthomonas translucens
#
# Xenococcaceae cyanobacterium:
#
#
# Xiashengella succiniciproducens:
# Xiashengella succiniciproducens	2949635	Bacteria;Bacteroidota;Bacteroidia;Marinilabiliales;Marinilabiliaceae;Xiashengella;Xiashengella succiniciproducens
#
# Yersinia pestis:
# Yersinia pestis	632	Bacteria;Pseudomonadota;Gammaproteobacteria;Enterobacterales;Yersiniaceae;Yersinia;Yersinia pestis
#
# Yinghuangia aomiensis:
# Yinghuangia aomiensis	676205	Bacteria;Actinomycetota;Actinomycetes;Kitasatosporales;Streptomycetaceae;Yinghuangia;Yinghuangia aomiensis
#
# Yinghuangia seranimata:
# Yinghuangia seranimata	408067	Bacteria;Actinomycetota;Actinomycetes;Kitasatosporales;Streptomycetaceae;Yinghuangia;Yinghuangia seranimata
#
# Yinghuangia soli:
# Yinghuangia soli	2908204	Bacteria;Actinomycetota;Actinomycetes;Kitasatosporales;Streptomycetaceae;Yinghuangia;Yinghuangia soli
#
# Yinghuangia sp.:
# Yinghuangia sp.	2846307	Bacteria;Actinomycetota;Actinomycetes;Kitasatosporales;Streptomycetaceae;Yinghuangia;Yinghuangia sp.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-6fd07a8b6282> in <module>
#      32 # Optionally, save the results to a new file
#      33 output_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacteria_results/species/processed_species.txt"
# ---> 34 with open(output_file_path, 'w') as output_file:
#      35     for species, output in results.items():
#      36         output_file.write(f'{species}:\n{output}\n\n')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/Bacterial_Hits/processed_seqs/processed_bacteria_results/species/processed_species.txt'
