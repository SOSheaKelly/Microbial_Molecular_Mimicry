# %%
# !pwd
# Out:
# /home/osheakes/Research_Project_MMM

# %% [markdown]
# # 1.0 Create Fasta Files from Accession ID inputs

# %%
import os
import requests

# Function to retrieve FASTA files from UniProt
def retrieve_fasta(accession_id):
    url = f"https://www.uniprot.org/uniprot/{accession_id}.fasta"
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to retrieve FASTA for {accession_id}")
        return None

# Function to write FASTA content to a file in the Fasta folder
def write_fasta_to_file(accession_id, fasta_content):
    folder = "/home/osheakes/Research_Project_MMM/Fasta"
    if not os.path.exists(folder):
        os.makedirs(folder)
    filename = os.path.join(folder, f"{accession_id}.fasta")
    with open(filename, "w") as f:
        f.write(fasta_content)
    print(f"FASTA file saved: {filename}")

# Main function
def main():
    # Read accession IDs from the text file
    accession_file = "Accession_ID_List.txt"
    with open(accession_file, "r") as f:
        accession_ids = [line.strip() for line in f if line.strip()]

    num_files_processed = 0 
    successful_files = 0  
    processed_ids = set() 

    # Retrieve and save FASTA files
    for accession_id in accession_ids:
        if accession_id in processed_ids:
            print(f"Duplicate accession ID found and skipped: {accession_id}")
            continue
        processed_ids.add(accession_id)

        num_files_processed += 1 
        fasta_content = retrieve_fasta(accession_id)
        if fasta_content:
            write_fasta_to_file(accession_id, fasta_content)
            successful_files += 1

    print(f"Number of files processed: {num_files_processed}")
    print(f"Number of successful FASTA files saved: {successful_files}")

if __name__ == "__main__":
    main()

# Additional script to count the number of FASTA files in the directory
directory_path = "/home/osheakes/Research_Project_MMM/Fasta/"

# Count the number of FASTA files in the directory
fasta_files = [file for file in os.listdir(directory_path) if file.endswith(".fasta")]
num_fasta_files = len(fasta_files)

print(f"Number of FASTA files in directory '{directory_path}': {num_fasta_files}")
# Out:
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01225.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01241.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P10082.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P12872.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P35318.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01282.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P18509.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P20366.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P46663.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01160.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P16860.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01258.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P06881.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P32247.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01210.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01213.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P0C0P6.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P30990.fasta
# Duplicate accession ID found and skipped: P20366
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q8N729.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q8NFJ6.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q9HC23.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O15130.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01303.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P48645.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q13519.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P08949.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q8NG41.fasta
# Duplicate accession ID found and skipped: P08949
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q5H8A3.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P10645.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q96RP3.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q969E3.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P55089.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O95399.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q15726.fasta
# Duplicate accession ID found and skipped: P35318
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01019.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q99653.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O43745.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q96BS2.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P23582.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P07492.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01344.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P43490.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/A0A097EV82.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P80303.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01966.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P19883.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O95390.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q99988.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q9Y5Q6.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q15303.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P47898.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P81605.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q9UHF0.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O95760.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q9H293.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q02388.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P06396.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q12965.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P02533.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q9BTW9.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P15502.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q03252.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O43808.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q9Y5Y5.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q92968.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O75381.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O75192.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O96011.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q01453.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P56199.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P23142.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P19525.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P19838.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P20591.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P20592.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P09914.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P13164.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q13325.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O14879.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q01629.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P09912.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q01628.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O95786.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P42224.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P52630.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P40763.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q14765.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/O00910.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P42226.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P04637.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P06400.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P60484.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P06493.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P24941.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q00526.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P11802.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q00535.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q00534.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P38398.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P51587.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q07812.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q16611.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P25445.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q14790.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P55211.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P42574.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P55210.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01568.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01570.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01566.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01579.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q9P0W0.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P01574.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q8IUX4.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/P55265.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q7Z2W4.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q9Y3Z3.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q10589.fasta
# FASTA file saved: /home/osheakes/Research_Project_MMM/Fasta/Q08722.fasta
# Number of files processed: 119
# Number of successful FASTA files saved: 119
# Number of FASTA files in directory '/home/osheakes/Research_Project_MMM/Fasta/': 119
