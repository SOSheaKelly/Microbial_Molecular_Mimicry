# %% [markdown]
# # Fungal Processed Search

# %% [markdown]
# ## 1.1 Create Fungal Master file

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts"

# Name of the master file
master_filename = "fungal_master_blaster.txt"


# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/fungal_master_blaster.txt

# %% [markdown]
# ## 1.2 Print Total Hits and Accession ID's

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/fungal_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract accession IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_accession_id = None
        for line in master_file:
            if "|" in line:  
                current_accession_id = line.split("|")[1].strip()
            elif ">" in line:  
                if current_accession_id:
                    query_hits[current_accession_id].append(line.split(">")[1].strip())  
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {accession_id: len(hits) for accession_id, hits in query_hits.items()}

# Rank and print total hits
print("Ranked total hits for each accession ID:")
for rank, (accession_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {accession_id}, Total Hits: {hits}")

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/fungal_master_blaster.csv"

try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Accession ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for accession_id, hits in query_hits.items():
            writer.writerow({'Accession ID': accession_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Ranked total hits for each accession ID:
# 1. Accession ID: Q12965, Total Hits: 1000
# 2. Accession ID: E...  102     7e-20, Total Hits: 1000
# 3. Accession ID: P11802, Total Hits: 1000
# 4. Accession ID: P51587, Total Hits: 1000
# 5. Accession ID: O75381, Total Hits: 1000
# 6. Accession ID: P09914, Total Hits: 1000
# 7. Accession ID: P60484, Total Hits: 1000
# 8. Accession ID: E...  58.9    3e-05, Total Hits: 1000
# 9. Accession ID: Q00535, Total Hits: 1000
# 10. Accession ID: P06493, Total Hits: 1000
# 11. Accession ID: P43490, Total Hits: 1000
# 12. Accession ID: Q9BTW9, Total Hits: 1000
# 13. Accession ID: Q99653, Total Hits: 1000
# 14. Accession ID: Q9Y3Z3, Total Hits: 1000
# 15. Accession ID: O96011, Total Hits: 1000
# 16. Accession ID: Q15303, Total Hits: 1000
# 17. Accession ID: O43745, Total Hits: 1000
# 18. Accession ID: Q96BS2, Total Hits: 1000
# 19. Accession ID: P19525, Total Hits: 1000
# 20. Accession ID: O75192, Total Hits: 1000
# 21. Accession ID: P19838, Total Hits: 1000
# 22. Accession ID: P06396, Total Hits: 1000
# 23. Accession ID: Q92968, Total Hits: 1000
# 24. Accession ID: Q00534, Total Hits: 1000
# 25. Accession ID: Q9Y5Y5, Total Hits: 1000
# 26. Accession ID: O43808, Total Hits: 1000
# 27. Accession ID: O95786, Total Hits: 1000
# 28. Accession ID: P20592, Total Hits: 1000
# 29. Accession ID: Q00526, Total Hits: 1000
# 30. Accession ID: P20591, Total Hits: 1000
# 31. Accession ID: P24941, Total Hits: 1000
# 32. Accession ID: Q02388, Total Hits: 952
# 33. Accession ID: O14879, Total Hits: 948
# 34. Accession ID: P80303, Total Hits: 900
# 35. Accession ID: P56199, Total Hits: 320
# 36. Accession ID: P09912, Total Hits: 308
# 37. Accession ID: Q7Z2W4, Total Hits: 268
# 38. Accession ID: P19883, Total Hits: 236
# 39. Accession ID: P32247, Total Hits: 224
# 40. Accession ID: P06400, Total Hits: 204
# 41. Accession ID: P47898, Total Hits: 128
# 42. Accession ID: Q10589, Total Hits: 112
# 43. Accession ID: P23142, Total Hits: 92
# 44. Accession ID: Q13325, Total Hits: 68
# 45. Accession ID: Q03252, Total Hits: 44
# 46. Accession ID: P01966, Total Hits: 32
# 47. Accession ID: Q8NFJ6, Total Hits: 28
# 48. Accession ID: P46663, Total Hits: 20
# 49. Accession ID: P02533, Total Hits: 8
# 50. Accession ID: P42224, Total Hits: 4
# 51. Accession ID: Q9P0W0, Total Hits: 4
# 52. Accession ID: P01574, Total Hits: 4
# 53. Accession ID: P01568, Total Hits: 4
# 54. Accession ID: P15502, Total Hits: 4
# 55. Accession ID: P01566, Total Hits: 4
# 56. Accession ID: P40763, Total Hits: 4
# 57. Accession ID: Q14765, Total Hits: 4
# 58. Accession ID: P52630, Total Hits: 4
# 59. Accession ID: P42226, Total Hits: 4
# 60. Accession ID: P01019, Total Hits: 4
# 61. Accession ID: P01570, Total Hits: 4
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/fungal_master_blaster.csv'

# %% [markdown]
# ### 1.2.1 Make additions to masterfile to analyse hits in regard to protein type and name

# %%
import pandas as pd

# File paths
bacterial_master_blaster_filepath = '/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/fungal_master_blaster.csv'
protein_names_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/protein_names.csv"
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/fungal_master_blaster_protein_results.csv"

# Read the bacterial master blaster CSV
bacterial_master_blaster_df = pd.read_csv(bacterial_master_blaster_filepath)

# Read the protein names CSV
protein_names_df = pd.read_csv(protein_names_filepath)

# Merge the dataframes on 'Accession ID'
merged_df = pd.merge(bacterial_master_blaster_df, protein_names_df[['Accession ID', 'Protein Names', 'Protein Type']], on='Accession ID', how='left')

# Reorder columns to place 'Protein Names' and 'Protein Type' at the start
cols = ['Protein Names', 'Protein Type'] + [col for col in bacterial_master_blaster_df.columns if col not in ['Protein Names', 'Protein Type']]
merged_df = merged_df[cols]

# Write the merged dataframe to a new CSV file
merged_df.to_csv(output_csv_path, index=False)

# Count the number of unique protein names
unique_protein_names = merged_df['Protein Names'].nunique()
print(f"Number of unique protein names: {unique_protein_names}")

# Breakdown of each protein type
protein_type_counts = merged_df['Protein Type'].value_counts()
print("Breakdown of protein types:")
print(protein_type_counts)

print(f"Merged results saved to '{output_csv_path}'")
# Out:
# Number of unique protein names: 59
# Breakdown of protein types:
# Structural                                    15
# Antiviral Proteins                            11
# Cell Cycle Regulation Proteins                 6
# Transcription Factors                          6
# Immune System - Cytokines                      5
# Metabolic Hormones                             5
# Cardiovascular and Renal Hormones              4
# Tumour Suppressors and DNA Repair Proteins     3
# Gastrointestinal                               2
# Neuropeptides and Neurotransmitter             2
# Name: Protein Type, dtype: int64
# Merged results saved to '/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/fungal_master_blaster_protein_results.csv'

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## 2.0 Run Blast on Fungal Processed Samples

# %% [markdown]
# ### 2.1 Create Working Directories

# %%
# !mkdir  /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/

# %%
# !mkdir  /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs
# Out:
# mkdir: cannot create directory ‘/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs’: File exists

# %% [markdown]
# ### 2.2 Pull Fasta's from Fungal processed sequences Text file

# %%
import os

# Input file path
file_path = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_fungal_blasts.txt"
# Output directory path
output_dir = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs"

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Function to extract accession ID from header line
def extract_accession_id(header):
    parts = header.split('|')
    if len(parts) > 1:
        return parts[1].strip()
    return None

# Initialize file count
file_count = 0

# Read the input file and process
with open(file_path, 'r') as infile:
    current_file = None
    current_file_path = None
    
    for line in infile:
        if line.startswith('>'):
            # Close the previous file if it was open
            if current_file:
                current_file.close()
            
            # Extract accession ID and create a new file
            accession_id = extract_accession_id(line)
            if accession_id:
                current_file_path = os.path.join(output_dir, f"{accession_id}.fasta")
                current_file = open(current_file_path, 'w')
                file_count += 1  
        
        # Write the current line to the current file
        if current_file:
            current_file.write(line)
    
    # Close the last file if it was open
    if current_file:
        current_file.close()

print(f"FASTA files have been successfully created. Number of files created: {file_count}")
# Out:
# FASTA files have been successfully created. Number of files created: 65

# %% [markdown]
# ## 2.3 Run Blast on Fungal Samples

# %%
# !mkdir  /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results

# %%
import subprocess
import os
import time
from datetime import datetime, timezone

# Path to the directory containing fasta files
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs"

# Directory to store blast results
blast_output_directory =  "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results"

# Create the blast output directory if it doesn't exist
os.makedirs(blast_output_directory, exist_ok=True)

# Record the start time of the entire process in GMT
start_time = datetime.now(timezone.utc)
print(f"Process started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')} GMT")

# Iterate through each fasta file in the directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):
        fasta_file = os.path.join(fasta_directory, filename)
        output_file = os.path.join(blast_output_directory, f"{os.path.splitext(filename)[0]}_blastp_results.txt")
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            print(f"Skipping {filename} as output file already exists.")
            continue
        
        # Construct the blastp command
        blastp_command = [
            "blastp",
            "-db",
            "nr",
            "-query",
            fasta_file,
            "-out",
            output_file,
            "-evalue",
            "0.06",
            "-remote",
            "-entrez_query",
            "fungi[orgn]"
        ]
        
        # Record start time for this file
        file_start_time = time.time()
        
        # Execute the blastp command
        print(f"Running blast search for {filename}...")
        try:
            result = subprocess.run(blastp_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
            result.check_returncode()  
            print(f"Blast search for {filename} completed successfully.")
        except subprocess.CalledProcessError as e:
            print(f"Blast search for {filename} failed with return code {e.returncode}.")
            print(f"Error: {e.stderr}")
        
        # Calculate elapsed time for this file
        file_elapsed_time = time.time() - file_start_time
        
        # Print filename and elapsed time
        print(f"Blast search for {filename} completed in {file_elapsed_time:.2f} seconds.")
        
        # Check if 30 minutes have elapsed since the start of the process
        if (datetime.now(timezone.utc) - start_time).seconds >= 1800:
            print(f"Process has been running for 30 minutes. Current time: {datetime.now(timezone.utc).strftime('%Y-%m-%d %H:%M:%S')} GMT")
            start_time = datetime.now(timezone.utc)  

print("Blastp searches completed for all fasta files.")
# Out:
# Process started at: 2024-07-07 12:41:05 GMT
# Running blast search for O96011.fasta...
# Blast search for O96011.fasta completed successfully.
# Blast search for O96011.fasta completed in 8827.62 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-07 15:08:13 GMT
# Running blast search for Q8NFJ6.fasta...
# Blast search for Q8NFJ6.fasta completed successfully.
# Blast search for Q8NFJ6.fasta completed in 2797.03 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-07 15:54:50 GMT
# Running blast search for Q15303.fasta...
# Blast search for Q15303.fasta completed successfully.
# Blast search for Q15303.fasta completed in 4010.21 seconds.
# Process has been running for 30 minutes. Current time: 2024-07-07 17:01:40 GMT
# Running blast search for P46663.fasta...

# %% [markdown]
# ## 3.0 Process Fungal Blast Results

# %% [markdown]
# ### 3.1 Collate hits from Processed Results

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results"

# Name of the master file
master_filename = "fungal_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/fungal_master_blaster.txt

# %% [markdown]
# ### 3.2 Print Total Hits and Accession ID's

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/fungal_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line:  
                current_query_id = line.split("|")[1].strip()
            elif ">" in line:  
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

# Rank and print total hits
print("Ranked total hits for each accession ID:")
for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/fungal_master_blaster.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Accession ID', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in query_hits.items():
            writer.writerow({'Accession ID': query_id, 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Ranked total hits for each accession ID:
# 1. Accession ID: Q12965, Total Hits: 250
# 2. Accession ID: P11802, Total Hits: 250
# 3. Accession ID: P51587, Total Hits: 250
# 4. Accession ID: O75381, Total Hits: 250
# 5. Accession ID: P09914, Total Hits: 250
# 6. Accession ID: P60484, Total Hits: 250
# 7. Accession ID: Q00535, Total Hits: 250
# 8. Accession ID: P06493, Total Hits: 250
# 9. Accession ID: P43490, Total Hits: 250
# 10. Accession ID: Q9BTW9, Total Hits: 250
# 11. Accession ID: Q99653, Total Hits: 250
# 12. Accession ID: Q9Y3Z3, Total Hits: 250
# 13. Accession ID: O96011, Total Hits: 250
# 14. Accession ID: Q15303, Total Hits: 250
# 15. Accession ID: O43745, Total Hits: 250
# 16. Accession ID: Q96BS2, Total Hits: 250
# 17. Accession ID: P19525, Total Hits: 250
# 18. Accession ID: O75192, Total Hits: 250
# 19. Accession ID: P19838, Total Hits: 250
# 20. Accession ID: P06396, Total Hits: 250
# 21. Accession ID: Q92968, Total Hits: 250
# 22. Accession ID: Q9Y5Y5, Total Hits: 250
# 23. Accession ID: O43808, Total Hits: 250
# 24. Accession ID: O95786, Total Hits: 250
# 25. Accession ID: P20592, Total Hits: 250
# 26. Accession ID: Q00526, Total Hits: 250
# 27. Accession ID: P20591, Total Hits: 250
# 28. Accession ID: P24941, Total Hits: 250
# 29. Accession ID: Q02388, Total Hits: 243
# 30. Accession ID: O14879, Total Hits: 235
# 31. Accession ID: P56199, Total Hits: 79
# 32. Accession ID: P09912, Total Hits: 77
# 33. Accession ID: Q7Z2W4, Total Hits: 69
# 34. Accession ID: P19883, Total Hits: 59
# 35. Accession ID: P32247, Total Hits: 56
# 36. Accession ID: P06400, Total Hits: 51
# 37. Accession ID: Q10589, Total Hits: 34
# 38. Accession ID: P47898, Total Hits: 32
# 39. Accession ID: P23142, Total Hits: 23
# 40. Accession ID: Q13325, Total Hits: 17
# 41. Accession ID: Q03252, Total Hits: 11
# 42. Accession ID: Q8NFJ6, Total Hits: 7
# 43. Accession ID: P46663, Total Hits: 5
# 44. Accession ID: P02533, Total Hits: 2
# 45. Accession ID: P42224, Total Hits: 1
# 46. Accession ID: Q9P0W0, Total Hits: 1
# 47. Accession ID: P01574, Total Hits: 1
# 48. Accession ID: P01568, Total Hits: 1
# 49. Accession ID: P01566, Total Hits: 1
# 50. Accession ID: P40763, Total Hits: 1
# 51. Accession ID: Q14765, Total Hits: 1
# 52. Accession ID: P52630, Total Hits: 1
# 53. Accession ID: P42226, Total Hits: 1
# 54. Accession ID: P01570, Total Hits: 1
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/fungal_master_blaster.csv'

# %% [markdown]
# ### 3.3 Create comprehensive processed csv

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/comp_fungal_processed_results.csv"

# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Parse out required data from blast results
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        accession_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0 
        hit_id = None 
        species_id = None 
        seq_length = None  
        evalue = None 
        score = None  
        identities = None  
        positives = None  
        gaps = None  
        query_definition = None  
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1 
                hit_id = line.split(">")[1].split(" ")[0]
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
                query_definition = line  # Assuming entire line is query definition

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
            elif hit_id and "Expect =" in line:
                evalue = line.split("Expect = ")[1].split(",")[0].strip()
                score = line.split("Score = ")[1].split(" bits")[0].strip()
            elif hit_id and "Identities =" in line:
                identities_str = line.split("Identities = ")[1].split(",")[0].strip()
                identities = round(float(identities_str.split(" ")[0].split("/")[0]) / float(identities_str.split(" ")[0].split("/")[1]) * 100, 2)
                positives_str = line.split("Positives = ")[1].split(",")[0].strip()
                positives = positives_str.split(" ")[0]
                gaps_str = line.split("Gaps = ")[1].split(" ")[0].strip()
                gaps = gaps_str
                hits_data.append([
                    os.path.basename(file_path), accession_id, hit_number, hit_id, seq_length, species_id, 
                    query_definition, "N/A", score, evalue, identities, positives, gaps, "Query", "Subject", "Fungal"
                ])
    return hits_data

# List to store parsed data
parsed_data = []

# List to store excluded file names
excluded_files = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"): 
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))
    else:
        excluded_files.append(file_name)  

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow([
        "File Name", "Accession ID", "Hit Number", "Hit ID", "Hit Length", "Species", 
        "Query Definition", "Hsp Bit Score", "Hsp Score", "Hsp E-value", 
        "Identity", "Positives", "Gaps", "Hsp Qseq", "Hsp Hseq", "Database"
    ])
    # Write parsed data
    writer.writerows(parsed_data)

print(f"CSV file created successfully with {len(parsed_data)} entries.")

# Print excluded file names
if excluded_files:
    print("\nExcluded files:")
    for file_name in excluded_files:
        print(file_name)
else:
    print("\nNo files were excluded.")
# Out:
# CSV file created successfully with 12885 entries.
#
# Excluded files:
# .ipynb_checkpoints
# fungal_master_blaster.csv
# fungal_master_blaster.txt

# %% [markdown]
# ### 4.4 Add Protein Names

# %%
import csv

# Input and output file paths
input_file = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/protein_names.txt"
output_file = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/protein_names.csv"

# Initialize a dictionary to track seen combinations of protein type and accession ID
seen_combinations = {}

# Process the lines to split data and prepare for CSV writing
data = []
with open(input_file, 'r', encoding='utf-8') as txt_file:
    try:
        reader = csv.reader(txt_file, delimiter='\t')
        for line_data in reader:
            # Skip empty lines
            if not line_data or all(cell.strip() == '' for cell in line_data):
                continue
            
            # Ensure each line has enough cells to contain at least Protein Type and Accession ID
            if len(line_data) >= 2:
                protein_type = line_data[0].strip()
                accession_id = line_data[1].strip()
                if accession_id: 
                   
                    key = (protein_type, accession_id)
                    if key not in seen_combinations:
                        seen_combinations[key] = True
                        data.append(line_data)
    except UnicodeDecodeError:
        print(f"Error decoding line in file: {input_file}")
        

# Write the processed data to CSV file
with open(output_file, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(data)

print(f"Converted {input_file} to CSV format at {output_file}")
# Out:
# Converted /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/protein_names.txt to CSV format at /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/protein_names.csv

# %%
import csv

# Input file paths
comp_archaeal_file = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/comp_fungal_processed_results.csv"
protein_names_file = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/protein_names.csv"
output_file = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/final_fungal_processed_results.csv"

# Step 1: Load data from protein_names.csv into a dictionary
accession_info = {}
with open(protein_names_file, 'r', encoding='utf-8') as csv_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        accession_id = row['Accession ID'].strip()
        protein_type = row['Protein Type'].strip()
        protein_names = row['Protein Names'].strip()
        accession_info[accession_id] = {
            'ProteinType': protein_type,
            'ProteinNames': protein_names
        }

# Step 2: Merge data with comp_archaeal_processed_results.csv and add new columns
merged_data = []
with open(comp_archaeal_file, 'r', encoding='utf-8') as csv_file:
    reader = csv.reader(csv_file)
    header = next(reader)
    header.insert(1, 'Protein Type')
    header.insert(2, 'Protein Names')
    merged_data.append(header)

    for row in reader:
        accession_id = row[1].strip()

        if accession_id in accession_info:
            protein_type = accession_info[accession_id]['ProteinType']
            protein_names = accession_info[accession_id]['ProteinNames']
        else:
            protein_type = ''
            protein_names = ''

        row.insert(1, protein_type)
        row.insert(2, protein_names)
        merged_data.append(row)

# Step 3: Write merged data to final_archaeal_processed_results.csv
with open(output_file, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(merged_data)

print(f"Merged data from {comp_archaeal_file} and {protein_names_file} into {output_file}")
# Out:
# Merged data from /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/comp_fungal_processed_results.csv and /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/protein_names.csv into /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/final_fungal_processed_results.csv

# %% [markdown]
# ### 4.5 Reorder Columns

# %%
import csv

input_file = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/final_fungal_processed_results.csv"
output_file = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/reordered_comp_fungal_processed_results.csv"
# Define the desired column order
desired_order = ['Protein Type', 'Protein Names', 'File Name', 'Accession ID', 'Hit Number', 'Hit ID', 'Hit Length', 'Species', 'Query Definition', 'Hsp Bit Score', 'Hsp Score', 'Hsp E-value', 'Identity', 'Positives', 'Gaps', 'Hsp Qseq', 'Hsp Hseq', 'Database']

# Read the original CSV file and reorder columns
with open(input_file, 'r', newline='', encoding='utf-8') as csv_file:
    reader = csv.reader(csv_file)
    header = next(reader)
    
    # Create a dictionary to map original indices to desired indices
    header_mapping = {header.index(col): idx for idx, col in enumerate(desired_order)}
    reordered_header = [header[idx] for idx in sorted(header_mapping.keys(), key=lambda x: header_mapping[x])]
    
    # Read and reorder rows
    rows = []
    for row in reader:
        reordered_row = [row[idx] for idx in sorted(header_mapping.keys(), key=lambda x: header_mapping[x])]
        rows.append(reordered_row)

# Write reordered data to a new CSV file
with open(output_file, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(reordered_header)
    writer.writerows(rows)

print(f"Reordered columns in {input_file} and saved to {output_file}")
# Out:
# Reordered columns in /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/final_fungal_processed_results.csv and saved to /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/reordered_comp_fungal_processed_results.csv

# %% [markdown]
# ## 5.0 Extract some key metrics from the Processed Search

# %% [markdown]
# ## 5.1 Print Queries which Produced hits

# %%
import csv

# Path to the CSV file
csv_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/reordered_comp_fungal_processed_results.csv"
# Initialize a set to store unique Accession IDs
unique_accession_ids = set()

try:
    # Open and read the CSV file
    with open(csv_file_path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        # Loop through each row in the CSV file
        for row in csv_reader:
            # Extract the Accession ID and add it to the set
            accession_id = row['Accession ID']  
            unique_accession_ids.add(accession_id)
    
    # Print each unique Accession ID
    for accession_id in unique_accession_ids:
        print(accession_id)
    
    # Print the total number of unique Accession IDs
    print(f"Total number of unique Accession IDs: {len(unique_accession_ids)}")

except FileNotFoundError:
    print(f"Error: File '{csv_file_path}' not found.")
except KeyError:
    print("Error: 'Accession ID' column not found in the CSV file. Please check the column name.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Q00526
# P06396
# Q9P0W0
# Q15303
# P42224
# P19838
# O75381
# O43808
# P56199
# Q10589
# P02533
# O96011
# Q14765
# P19525
# P06400
# O43745
# Q96BS2
# P60484
# P06493
# P09912
# Q9BTW9
# O75192
# P32247
# Q99653
# P09914
# P46663
# P19883
# P42226
# P47898
# P24941
# P01566
# P40763
# O14879
# Q7Z2W4
# Q03252
# Q9Y5Y5
# P43490
# O95786
# P01574
# P23142
# P01568
# Q8NFJ6
# Q9Y3Z3
# P20592
# P01570
# Q00535
# P11802
# Q12965
# P52630
# Q13325
# Q02388
# P20591
# P51587
# Q92968
# Total number of unique Accession IDs: 54

# %% [markdown]
# ### 5.2 Print the number of input files

# %%
import os

# Path to the directory
directory_path = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/"

# Initialize a counter for FASTA files
fasta_file_count = 0

# Iterate through the files in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".fasta") or file_name.endswith(".fa"):  
        fasta_file_count += 1

# Print the total number of FASTA files
print(f"Total number of FASTA files: {fasta_file_count}")
# Out:
# Total number of FASTA files: 65

# %% [markdown]
# #

# %% [markdown]
# ## 6.0 Perform species analysis

# %% [markdown]
# ### 6.1 Create directory

# %%
# !mkdir  "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/species"

# %% [markdown]
# ### 6.2 Create Unique list of species

# %%
! awk -F "," '{ print $8 }' /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/reordered_comp_fungal_processed_results.csv | sort | uniq > /home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/species/unique_fungi.txt

# %% [markdown]
# ### 6.3 Run Taxonkit on Unique Species

# %%
import subprocess

# Path to the unique-species.txt file
file_path = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/species/unique_fungi.txt"
# Path to the taxonkit binary
taxonkit_path = '/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit'

# Read the species names from the file
with open(file_path, 'r') as file:
    species_names = [line.strip() for line in file.readlines()]

# Define a function to apply the command to each species name
def process_species_name(species_name):
    # Construct the command
    cmd = f'echo "{species_name}" | {taxonkit_path} name2taxid | {taxonkit_path} reformat -I 2'
    # Run the command
    result = subprocess.run(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    # Debug: Print command and output
    print(f"Command: {cmd}")
    print(f"Stdout: {result.stdout.strip()}")
    print(f"Stderr: {result.stderr.strip()}")
    # Return the output
    return result.stdout.strip()

# Process each species name and store the results
results = {species: process_species_name(species) for species in species_names}

# Print the results
for species, output in results.items():
    print(f'{species}:\n{output}\n')

# Optionally, save the results to a new file
output_file_path = "/home/osheakes/Research_Project_MMM/Fasta/Fungal_Blasts/Fungal_Hits/processed_seqs/processed_fungal_results/species/processed_species.txt"
with open(output_file_path, 'w') as output_file:
    for species, output in results.items():
        output_file.write(f'{species}:\n{output}\n\n')
# Out:
# Command: echo "" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr:
# Command: echo "Abortiporus biennis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Abortiporus biennis	137743	Eukaryota;Basidiomycota;Agaricomycetes;Polyporales;Podoscyphaceae;Abortiporus;Abortiporus biennis
# Stderr:
# Command: echo "Absidia" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Absidia	4828	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Cunninghamellaceae;Absidia;
# Stderr:
# Command: echo "Absidia glauca" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Absidia glauca	4829	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Cunninghamellaceae;Absidia;Absidia glauca
# Stderr:
# Command: echo "Absidia repens" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Absidia repens	90262	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Cunninghamellaceae;Absidia;Absidia repens
# Stderr:
# Command: echo "Acaromyces ingoldii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acaromyces ingoldii	215250	Eukaryota;Basidiomycota;Exobasidiomycetes;Exobasidiales;Cryptobasidiaceae;Acaromyces;Acaromyces ingoldii
# Stderr:
# Command: echo "Acaulospora colombiana" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acaulospora colombiana	27376	Eukaryota;Mucoromycota;Glomeromycetes;Diversisporales;Acaulosporaceae;Acaulospora;Acaulospora colombiana
# Stderr:
# Command: echo "Acaulospora morrowiae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acaulospora morrowiae	94023	Eukaryota;Mucoromycota;Glomeromycetes;Diversisporales;Acaulosporaceae;Acaulospora;Acaulospora morrowiae
# Stderr:
# Command: echo "Achaetomium macrosporum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Achaetomium macrosporum	79813	Eukaryota;Ascomycota;Sordariomycetes;Sordariales;Chaetomiaceae;Achaetomium;Achaetomium macrosporum
# Stderr:
# Command: echo "Acrodontium crateriforme" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Acrodontium crateriforme	150365	Eukaryota;Ascomycota;Dothideomycetes;Mycosphaerellales;Teratosphaeriaceae;Acrodontium;Acrodontium crateriforme
# Stderr:
# Command: echo "Actinomortierella" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomortierella	2779867	Eukaryota;Mucoromycota;Mortierellomycetes;Mortierellales;Mortierellaceae;Actinomortierella;
# Stderr:
# Command: echo "Actinomortierella ambigua" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomortierella ambigua	1343610	Eukaryota;Mucoromycota;Mortierellomycetes;Mortierellales;Mortierellaceae;Actinomortierella;Actinomortierella ambigua
# Stderr:
# Command: echo "Actinomortierella wolfii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Actinomortierella wolfii	90253	Eukaryota;Mucoromycota;Mortierellomycetes;Mortierellales;Mortierellaceae;Actinomortierella;Actinomortierella wolfii
# Stderr:
# Command: echo "Agaricus bisporus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Agaricus bisporus	5341	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Agaricaceae;Agaricus;Agaricus bisporus
# Stderr:
# Command: echo "Agaricus bisporus var." | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 00:54:04.029 [ERRO] invalid TaxId:
# Command: echo "Agaricus bisporus var. burnettii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Agaricus bisporus var. burnettii	192524	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Agaricaceae;Agaricus;Agaricus bisporus
# Stderr:
# Command: echo "Agrocybe" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Agrocybe	5399	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Strophariaceae;Agrocybe;
# Stderr:
# Command: echo "Agrocybe chaxingu" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Agrocybe chaxingu	84603	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Strophariaceae;Agrocybe;Agrocybe chaxingu
# Stderr:
# Command: echo "Agrocybe pediades" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Agrocybe pediades	84607	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Strophariaceae;Agrocybe;Agrocybe pediades
# Stderr:
# Command: echo "Agyrium rufum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Agyrium rufum	443868	Eukaryota;Ascomycota;Lecanoromycetes;Pertusariales;Pertusariaceae;Agyrium;Agyrium rufum
# Stderr:
# Command: echo "Akanthomyces lecanii RCEF" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 00:54:22.278 [ERRO] invalid TaxId:
# Command: echo "Akanthomyces muscarius" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Akanthomyces muscarius	2231603	Eukaryota;Ascomycota;Sordariomycetes;Hypocreales;Cordycipitaceae;Akanthomyces;Akanthomyces muscarius
# Stderr:
# Command: echo "Alectoria fallacina" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Alectoria fallacina	1903189	Eukaryota;Ascomycota;Lecanoromycetes;Lecanorales;Parmeliaceae;Alectoria;Alectoria fallacina
# Stderr:
# Command: echo "Alectoria sarmentosa" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Alectoria sarmentosa	111643	Eukaryota;Ascomycota;Lecanoromycetes;Lecanorales;Parmeliaceae;Alectoria;Alectoria sarmentosa
# Stderr:
# Command: echo "Allomyces arbusculus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Allomyces arbusculus	64504	Eukaryota;Blastocladiomycota;Blastocladiomycetes;Blastocladiales;Blastocladiaceae;Allomyces;Allomyces arbusculus
# Stderr:
# Command: echo "Allomyces javanicus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Allomyces javanicus	64505	Eukaryota;Blastocladiomycota;Blastocladiomycetes;Blastocladiales;Blastocladiaceae;Allomyces;Allomyces javanicus
# Stderr:
# Command: echo "Allomyces macrogynus ATCC 38327" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Allomyces macrogynus ATCC 38327	578462	Eukaryota;Blastocladiomycota;Blastocladiomycetes;Blastocladiales;Blastocladiaceae;Allomyces;Allomyces macrogynus
# Stderr:
# Command: echo "Amanita" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amanita	41955	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Amanitaceae;Amanita;
# Stderr:
# Command: echo "Amanita brunnescens Koide BX004" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amanita brunnescens Koide BX004	1457509	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Amanitaceae;Amanita;Amanita brunnescens
# Stderr:
# Command: echo "Amanita inopinata Kibby_2008" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amanita inopinata Kibby_2008	1457513	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Amanitaceae;Amanita;Amanita inopinata
# Stderr:
# Command: echo "Amanita muscaria Koide" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 00:54:52.511 [ERRO] invalid TaxId:
# Command: echo "Amanita phalloides" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amanita phalloides	67723	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Amanitaceae;Amanita;Amanita phalloides
# Stderr:
# Command: echo "Amanita polypyramis BW_CC" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amanita polypyramis BW_CC	1457511	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Amanitaceae;Amanita;Amanita polypyramis
# Stderr:
# Command: echo "Amanita rubescens" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amanita rubescens	71933	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Amanitaceae;Amanita;Amanita rubescens
# Stderr:
# Command: echo "Amanita thiersii Skay4041" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amanita thiersii Skay4041	703135	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Amanitaceae;Amanita;Amanita thiersii
# Stderr:
# Command: echo "Ambispora gerdemannii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ambispora gerdemannii	144530	Eukaryota;Mucoromycota;Glomeromycetes;Archaeosporales;Ambisporaceae;Ambispora;Ambispora gerdemannii
# Stderr:
# Command: echo "Ambispora leptoticha" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ambispora leptoticha	144679	Eukaryota;Mucoromycota;Glomeromycetes;Archaeosporales;Ambisporaceae;Ambispora;Ambispora leptoticha
# Stderr:
# Command: echo "Ambrosiozyma monospora" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ambrosiozyma monospora	43982	Eukaryota;Ascomycota;Saccharomycetes;Saccharomycetales;;Ambrosiozyma;Ambrosiozyma monospora
# Stderr:
# Command: echo "Amorphotheca resinae ATCC" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 00:55:17.162 [ERRO] invalid TaxId:
# Command: echo "Amylocarpus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amylocarpus	45427	Eukaryota;Ascomycota;Leotiomycetes;Helotiales;;Amylocarpus;
# Stderr:
# Command: echo "Amylocystis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amylocystis	202699	Eukaryota;Basidiomycota;Agaricomycetes;Polyporales;Postiaceae;Amylocystis;
# Stderr:
# Command: echo "Amylocystis lapponica" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amylocystis lapponica	202700	Eukaryota;Basidiomycota;Agaricomycetes;Polyporales;Postiaceae;Amylocystis;Amylocystis lapponica
# Stderr:
# Command: echo "Amylostereum chailletii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Amylostereum chailletii	55340	Eukaryota;Basidiomycota;Agaricomycetes;Russulales;Stereaceae;Amylostereum;Amylostereum chailletii
# Stderr:
# Command: echo "Anaeromyces" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anaeromyces	105135	Eukaryota;Chytridiomycota;Neocallimastigomycetes;Neocallimastigales;Neocallimastigaceae;Anaeromyces;
# Stderr:
# Command: echo "Anaeromyces robustus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Anaeromyces robustus	1754192	Eukaryota;Chytridiomycota;Neocallimastigomycetes;Neocallimastigales;Neocallimastigaceae;Anaeromyces;Anaeromyces robustus
# Stderr:
# Command: echo "Annulohypoxylon bovei" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Annulohypoxylon bovei	326616	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Hypoxylaceae;Annulohypoxylon;Annulohypoxylon bovei
# Stderr:
# Command: echo "Annulohypoxylon maeteangense" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Annulohypoxylon maeteangense	1927788	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Hypoxylaceae;Annulohypoxylon;Annulohypoxylon maeteangense
# Stderr:
# Command: echo "Annulohypoxylon moriforme" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Annulohypoxylon moriforme	326622	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Hypoxylaceae;Annulohypoxylon;Annulohypoxylon moriforme
# Stderr:
# Command: echo "Annulohypoxylon nitens" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Annulohypoxylon nitens	326626	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Hypoxylaceae;Annulohypoxylon;Annulohypoxylon nitens
# Stderr:
# Command: echo "Annulohypoxylon stygium" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Annulohypoxylon stygium	326628	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Hypoxylaceae;Annulohypoxylon;Annulohypoxylon stygium
# Stderr:
# Command: echo "Annulohypoxylon truncatum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Annulohypoxylon truncatum	327061	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Hypoxylaceae;Annulohypoxylon;Annulohypoxylon truncatum
# Stderr:
# Command: echo "Aphanocladium album" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aphanocladium album	12942	Eukaryota;Ascomycota;Sordariomycetes;Hypocreales;;Aphanocladium;Aphanocladium album
# Stderr:
# Command: echo "Apiosordaria" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apiosordaria	192815	Eukaryota;Ascomycota;Sordariomycetes;Sordariales;Lasiosphaeriaceae;Apiosordaria;
# Stderr:
# Command: echo "Apiospora arundinis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apiospora arundinis	335852	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Apiosporaceae;Apiospora;Apiospora arundinis
# Stderr:
# Command: echo "Apiotrichum porosum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apiotrichum porosum	105984	Eukaryota;Basidiomycota;Tremellomycetes;Trichosporonales;Trichosporonaceae;Apiotrichum;Apiotrichum porosum
# Stderr:
# Command: echo "Aplosporella prunicola" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aplosporella prunicola	462254	Eukaryota;Ascomycota;Dothideomycetes;Botryosphaeriales;Aplosporellaceae;Aplosporella;Aplosporella prunicola
# Stderr:
# Command: echo "Apodospora" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apodospora	516988	Eukaryota;Ascomycota;Sordariomycetes;Sordariales;Lasiosphaeriaceae;Apodospora;
# Stderr:
# Command: echo "Apodospora peruviana" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apodospora peruviana	516989	Eukaryota;Ascomycota;Sordariomycetes;Sordariales;Lasiosphaeriaceae;Apodospora;Apodospora peruviana
# Stderr:
# Command: echo "Apophysomyces" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apophysomyces	90268	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Mucoraceae;Apophysomyces;
# Stderr:
# Command: echo "Apophysomyces ossiformis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apophysomyces ossiformis	679940	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Mucoraceae;Apophysomyces;Apophysomyces ossiformis
# Stderr:
# Command: echo "Apophysomyces sp. BC1015" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apophysomyces sp. BC1015	2184030	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Mucoraceae;Apophysomyces;Apophysomyces sp. BC1015
# Stderr:
# Command: echo "Apophysomyces sp. BC1021" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apophysomyces sp. BC1021	2184031	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Mucoraceae;Apophysomyces;Apophysomyces sp. BC1021
# Stderr:
# Command: echo "Apophysomyces sp. BC1034" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Apophysomyces sp. BC1034	2184029	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Mucoraceae;Apophysomyces;Apophysomyces sp. BC1034
# Stderr:
# Command: echo "Arachnomyces sp. PD_36" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arachnomyces sp. PD_36	2135914	Eukaryota;Ascomycota;Eurotiomycetes;Onygenales;Arachnomycetaceae;Arachnomyces;Arachnomyces sp. PD_36
# Stderr:
# Command: echo "Arthrobotrys conoides" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arthrobotrys conoides	74498	Eukaryota;Ascomycota;Orbiliomycetes;Orbiliales;Orbiliaceae;Arthrobotrys;Arthrobotrys conoides
# Stderr:
# Command: echo "Arthrobotrys megalospora" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arthrobotrys megalospora	2528406	Eukaryota;Ascomycota;Orbiliomycetes;Orbiliales;Orbiliaceae;Arthrobotrys;Arthrobotrys megalospora
# Stderr:
# Command: echo "Arthroderma sp. PD_2" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arthroderma sp. PD_2	2135919	Eukaryota;Ascomycota;Eurotiomycetes;Onygenales;Arthrodermataceae;Arthroderma;Arthroderma sp. PD_2
# Stderr:
# Command: echo "Arthroderma uncinatum" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arthroderma uncinatum	74035	Eukaryota;Ascomycota;Eurotiomycetes;Onygenales;Arthrodermataceae;Arthroderma;Arthroderma uncinatum
# Stderr:
# Command: echo "Arthromyces matolae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Arthromyces matolae	530044	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Lyophyllaceae;Arthromyces;Arthromyces matolae
# Stderr:
# Command: echo "Artomyces pyxidatus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Artomyces pyxidatus	48021	Eukaryota;Basidiomycota;Agaricomycetes;Russulales;Auriscalpiaceae;Artomyces;Artomyces pyxidatus
# Stderr:
# Command: echo "Arxiozyma heterogenica" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 00:56:47.582 [ERRO] invalid TaxId:
# Command: echo "Ascobolus immersus RN42" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ascobolus immersus RN42	1160509	Eukaryota;Ascomycota;Pezizomycetes;Pezizales;Ascobolaceae;Ascobolus;Ascobolus immersus
# Stderr:
# Command: echo "Ascochyta lentis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ascochyta lentis	205686	Eukaryota;Ascomycota;Dothideomycetes;Pleosporales;Didymellaceae;Ascochyta;Ascochyta lentis
# Stderr:
# Command: echo "Ascochyta rabiei" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ascochyta rabiei	5454	Eukaryota;Ascomycota;Dothideomycetes;Pleosporales;Didymellaceae;Ascochyta;Ascochyta rabiei
# Stderr:
# Command: echo "Ascodesmis nigricans" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ascodesmis nigricans	341454	Eukaryota;Ascomycota;Pezizomycetes;Pezizales;Ascodesmidaceae;Ascodesmis;Ascodesmis nigricans
# Stderr:
# Command: echo "Ascosphaera atra" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Ascosphaera atra	51567	Eukaryota;Ascomycota;Eurotiomycetes;Onygenales;Ascosphaeraceae;Ascosphaera;Ascosphaera atra
# Stderr:
# Command: echo "Aspergillus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus	5052	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;
# Stderr:
# Command: echo "Aspergillus aculeatus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus aculeatus	5053	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus aculeatus
# Stderr:
# Command: echo "Aspergillus alliaceus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus alliaceus	209559	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus alliaceus
# Stderr:
# Command: echo "Aspergillus arachidicola" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus arachidicola	656916	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus arachidicola
# Stderr:
# Command: echo "Aspergillus avenaceus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus avenaceus	36643	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus avenaceus
# Stderr:
# Command: echo "Aspergillus bombycis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus bombycis	109264	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus bombycis
# Stderr:
# Command: echo "Aspergillus brasiliensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus brasiliensis	319629	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus brasiliensis
# Stderr:
# Command: echo "Aspergillus calidoustus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus calidoustus	454130	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus calidoustus
# Stderr:
# Command: echo "Aspergillus campestris" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus campestris	41068	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus campestris
# Stderr:
# Command: echo "Aspergillus campestris IBT 28561" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus campestris IBT 28561	1392248	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus campestris
# Stderr:
# Command: echo "Aspergillus candidus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus candidus	41067	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus candidus
# Stderr:
# Command: echo "Aspergillus carbonarius" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus carbonarius	40993	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus carbonarius
# Stderr:
# Command: echo "Aspergillus carlsbadensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus carlsbadensis	1810906	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus carlsbadensis
# Stderr:
# Command: echo "Aspergillus chevalieri" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus chevalieri	182096	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus chevalieri
# Stderr:
# Command: echo "Aspergillus clavatus NRRL 1" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus clavatus NRRL 1	344612	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus clavatus
# Stderr:
# Command: echo "Aspergillus costaricaensis CBS 115574" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus costaricaensis CBS 115574	1448317	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus costaricensis
# Stderr:
# Command: echo "Aspergillus cristatus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus cristatus	573508	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus cristatus
# Stderr:
# Command: echo "Aspergillus egyptiacus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus egyptiacus	41743	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus egyptiacus
# Stderr:
# Command: echo "Aspergillus fischeri NRRL 181" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus fischeri NRRL 181	331117	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus fischeri
# Stderr:
# Command: echo "Aspergillus flavus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus flavus	5059	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus flavus
# Stderr:
# Command: echo "Aspergillus flavus AF70" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus flavus AF70	1392242	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus flavus
# Stderr:
# Command: echo "Aspergillus flavus NRRL3357" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus flavus NRRL3357	332952	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus flavus
# Stderr:
# Command: echo "Aspergillus fumigatiaffinis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus fumigatiaffinis	340414	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus fumigatiaffinis
# Stderr:
# Command: echo "Aspergillus fumigatus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus fumigatus	746128	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus fumigatus
# Stderr:
# Command: echo "Aspergillus fumigatus A1163" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus fumigatus A1163	451804	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus fumigatus
# Stderr:
# Command: echo "Aspergillus fumigatus Af293" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus fumigatus Af293	330879	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus fumigatus
# Stderr:
# Command: echo "Aspergillus fumigatus Z5" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus fumigatus Z5	1437362	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus fumigatus
# Stderr:
# Command: echo "Aspergillus glaucus CBS" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 00:58:19.681 [ERRO] invalid TaxId:
# Command: echo "Aspergillus hancockii" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus hancockii	1873369	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus hancockii
# Stderr:
# Command: echo "Aspergillus heteromorphus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus heteromorphus	51019	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus heteromorphus
# Stderr:
# Command: echo "Aspergillus hiratsukae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus hiratsukae	1194566	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus hiratsukae
# Stderr:
# Command: echo "Aspergillus homomorphus CBS" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 00:58:32.076 [ERRO] invalid TaxId:
# Command: echo "Aspergillus ibericus CBS 121593" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus ibericus CBS 121593	1448316	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus ibericus
# Stderr:
# Command: echo "Aspergillus lentulus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus lentulus	293939	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus lentulus
# Stderr:
# Command: echo "Aspergillus leporis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus leporis	41062	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus leporis
# Stderr:
# Command: echo "Aspergillus luchuensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus luchuensis	1069201	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus luchuensis
# Stderr:
# Command: echo "Aspergillus melleus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus melleus	138277	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus melleus
# Stderr:
# Command: echo "Aspergillus minisclerotigenes" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus minisclerotigenes	656917	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus minisclerotigenes
# Stderr:
# Command: echo "Aspergillus mulundensis" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus mulundensis	1810919	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus mulundensis
# Stderr:
# Command: echo "Aspergillus nidulans FGSC A4" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus nidulans FGSC A4	227321	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus nidulans
# Stderr:
# Command: echo "Aspergillus niger" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus niger	5061	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus niger
# Stderr:
# Command: echo "Aspergillus novofumigatus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus novofumigatus	340412	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus novofumigatus
# Stderr:
# Command: echo "Aspergillus novofumigatus IBT" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout:
# Stderr: 00:59:03.080 [ERRO] invalid TaxId:
# Command: echo "Aspergillus novoparasiticus" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus novoparasiticus	986946	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus novoparasiticus
# Stderr:
# Command: echo "Aspergillus oryzae" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus oryzae	5062	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus oryzae
# Stderr:
# Command: echo "Aspergillus oryzae 3.042" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus oryzae 3.042	1160506	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus oryzae
# Stderr:
# Command: echo "Aspergillus oryzae RIB40" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus oryzae RIB40	510516	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus oryzae
# Stderr:
# Command: echo "Aspergillus piperis CBS 112811" | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit name2taxid | /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/processed_viral_seq/species/taxonkit reformat -I 2
# Stdout: Aspergillus piperis CBS 112811	1448313	Eukaryota;Ascomycota;Eurotiomycetes;Eurotiales;Aspergillaceae;Aspergillus;Aspergillus piperis
# Stderr:
# ...
#
# Tulasnella sp. 331:
# Tulasnella sp. 331	2600221	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 331
#
# Tulasnella sp. 332:
# Tulasnella sp. 332	2600222	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 332
#
# Tulasnella sp. 403:
# Tulasnella sp. 403	2600223	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 403
#
# Tulasnella sp. 408:
# Tulasnella sp. 408	2600224	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 408
#
# Tulasnella sp. 417:
# Tulasnella sp. 417	2600225	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 417
#
# Tulasnella sp. 418:
# Tulasnella sp. 418	2600226	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 418
#
# Tulasnella sp. 419:
# Tulasnella sp. 419	2600227	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 419
#
# Tulasnella sp. 424:
# Tulasnella sp. 424	2600228	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 424
#
# Tulasnella sp. 425:
# Tulasnella sp. 425	2600229	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 425
#
# Tulasnella sp. 427:
# Tulasnella sp. 427	2600231	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. 427
#
# Tulasnella sp. JGI-2019a:
# Tulasnella sp. JGI-2019a	2600232	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;;Tulasnella sp. JGI-2019a
#
# Tulasnella sp. UAMH 9824:
# Tulasnella sp. UAMH 9824	2601502	Eukaryota;Basidiomycota;Agaricomycetes;Cantharellales;Tulasnellaceae;Tulasnella;Tulasnella sp. UAMH 9824
#
# Tulosesus angulatus:
# Tulosesus angulatus	980116	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Psathyrellaceae;Tulosesus;Tulosesus angulatus
#
# Umbelopsis:
# Umbelopsis	64561	Eukaryota;Mucoromycota;Umbelopsidomycetes;Umbelopsidales;Umbelopsidaceae;Umbelopsis;
#
# Umbelopsis isabellina:
# Umbelopsis isabellina	91625	Eukaryota;Mucoromycota;Umbelopsidomycetes;Umbelopsidales;Umbelopsidaceae;Umbelopsis;Umbelopsis isabellina
#
# Umbelopsis ramanniana:
# Umbelopsis ramanniana	41833	Eukaryota;Mucoromycota;Umbelopsidomycetes;Umbelopsidales;Umbelopsidaceae;Umbelopsis;Umbelopsis ramanniana
#
# Umbelopsis sp.:
# Umbelopsis sp.	1891170	Eukaryota;Mucoromycota;Umbelopsidomycetes;Umbelopsidales;Umbelopsidaceae;Umbelopsis;Umbelopsis sp.
#
# Umbelopsis sp. AD052:
# Umbelopsis sp. AD052	1883073	Eukaryota;Mucoromycota;Umbelopsidomycetes;Umbelopsidales;Umbelopsidaceae;Umbelopsis;Umbelopsis sp. AD052
#
# Umbelopsis sp. PMI_123:
# Umbelopsis sp. PMI_123	1896174	Eukaryota;Mucoromycota;Umbelopsidomycetes;Umbelopsidales;Umbelopsidaceae;Umbelopsis;Umbelopsis sp. PMI_123
#
# Umbelopsis vinacea:
# Umbelopsis vinacea	44442	Eukaryota;Mucoromycota;Umbelopsidomycetes;Umbelopsidales;Umbelopsidaceae;Umbelopsis;Umbelopsis vinacea
#
# Umbilicaria vellea:
# Umbilicaria vellea	87287	Eukaryota;Ascomycota;Lecanoromycetes;Umbilicariales;Umbilicariaceae;Umbilicaria;Umbilicaria vellea
#
# Ustilaginoidea virens:
# Ustilaginoidea virens	1159556	Eukaryota;Ascomycota;Sordariomycetes;Hypocreales;Clavicipitaceae;Ustilaginoidea;Ustilaginoidea virens
#
# Ustilago bromivora:
# Ustilago bromivora	307758	Eukaryota;Basidiomycota;Ustilaginomycetes;Ustilaginales;Ustilaginaceae;Ustilago;Ustilago bromivora
#
# Ustilago hordei:
# Ustilago hordei	120017	Eukaryota;Basidiomycota;Ustilaginomycetes;Ustilaginales;Ustilaginaceae;Ustilago;Ustilago hordei
#
# Ustilago loliicola:
# Ustilago loliicola	2031085	Eukaryota;Basidiomycota;Ustilaginomycetes;Ustilaginales;Ustilaginaceae;Ustilago;Ustilago loliicola
#
# Ustilago maydis 521:
# Ustilago maydis 521	237631	Eukaryota;Basidiomycota;Ustilaginomycetes;Ustilaginales;Ustilaginaceae;Ustilago;Ustilago maydis
#
# Ustilago nuda:
# Ustilago nuda	86802	Eukaryota;Basidiomycota;Ustilaginomycetes;Ustilaginales;Ustilaginaceae;Ustilago;Ustilago nuda
#
# Ustilago sp. UG-2017a:
# Ustilago sp. UG-2017a	2043610	Eukaryota;Basidiomycota;Ustilaginomycetes;Ustilaginales;Ustilaginaceae;Ustilago;Ustilago sp. UG-2017a
#
# Ustilago sp. UG-2017b:
# Ustilago sp. UG-2017b	2043611	Eukaryota;Basidiomycota;Ustilaginomycetes;Ustilaginales;Ustilaginaceae;Ustilago;Ustilago sp. UG-2017b
#
# Ustilago trichophora:
# Ustilago trichophora	86804	Eukaryota;Basidiomycota;Ustilaginomycetes;Ustilaginales;Ustilaginaceae;Ustilago;Ustilago trichophora
#
# Ustilago tritici:
# Ustilago tritici	117174	Eukaryota;Basidiomycota;Ustilaginomycetes;Ustilaginales;Ustilaginaceae;Ustilago;Ustilago tritici
#
# Ustulina deusta:
# Ustulina deusta	110526	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Ustulina;Ustulina deusta
#
# Vairimorpha:
# Vairimorpha	6038	Eukaryota;Microsporidia;;;Nosematidae;Vairimorpha;
#
# Valsa mali:
# Valsa mali	105487	Eukaryota;Ascomycota;Sordariomycetes;Diaporthales;Valsaceae;Valsa;Valsa mali
#
# Valsa malicola:
# Valsa malicola	356882	Eukaryota;Ascomycota;Sordariomycetes;Diaporthales;Valsaceae;Valsa;Valsa malicola
#
# Valsa mali var.:
#
#
# Valsa sordida:
# Valsa sordida	252740	Eukaryota;Ascomycota;Sordariomycetes;Diaporthales;Valsaceae;Valsa;Valsa sordida
#
# Vanrija humicola:
# Vanrija humicola	5417	Eukaryota;Basidiomycota;Tremellomycetes;Trichosporonales;Trichosporonaceae;Vanrija;Vanrija humicola
#
# Vanrija pseudolonga:
# Vanrija pseudolonga	143232	Eukaryota;Basidiomycota;Tremellomycetes;Trichosporonales;Trichosporonaceae;Vanrija;Vanrija pseudolonga
#
# Vararia minispora:
# Vararia minispora	1314805	Eukaryota;Basidiomycota;Agaricomycetes;Russulales;Lachnocladiaceae;Vararia;Vararia minispora
#
# Varicellaria rhodocarpa:
# Varicellaria rhodocarpa	160984	Eukaryota;Ascomycota;Lecanoromycetes;Pertusariales;Pertusariaceae;Varicellaria;Varicellaria rhodocarpa
#
# Venturia inaequalis:
# Venturia inaequalis	5025	Eukaryota;Ascomycota;Dothideomycetes;Venturiales;Venturiaceae;Venturia;Venturia inaequalis
#
# Venustampulla echinocandica:
# Venustampulla echinocandica	2656787	Eukaryota;Ascomycota;Leotiomycetes;Helotiales;Pleuroascaceae;Venustampulla;Venustampulla echinocandica
#
# Vermiconidia calcicola:
# Vermiconidia calcicola	1690605	Eukaryota;Ascomycota;Dothideomycetes;Mycosphaerellales;Extremaceae;Vermiconidia;Vermiconidia calcicola
#
# Verruconis gallopava:
# Verruconis gallopava	253628	Eukaryota;Ascomycota;Dothideomycetes;Venturiales;Sympoventuriaceae;Verruconis;Verruconis gallopava
#
# Verticillium:
# Verticillium	1036719	Eukaryota;Ascomycota;Sordariomycetes;Glomerellales;Plectosphaerellaceae;Verticillium;
#
# Verticillium alfalfae:
# Verticillium alfalfae	1051613	Eukaryota;Ascomycota;Sordariomycetes;Glomerellales;Plectosphaerellaceae;Verticillium;Verticillium alfalfae
#
# Verticillium dahliae:
# Verticillium dahliae	27337	Eukaryota;Ascomycota;Sordariomycetes;Glomerellales;Plectosphaerellaceae;Verticillium;Verticillium dahliae
#
# Verticillium dahliae VDG2:
# Verticillium dahliae VDG2	1007914	Eukaryota;Ascomycota;Sordariomycetes;Glomerellales;Plectosphaerellaceae;Verticillium;Verticillium dahliae
#
# Verticillium longisporum:
# Verticillium longisporum	100787	Eukaryota;Ascomycota;Sordariomycetes;Glomerellales;Plectosphaerellaceae;Verticillium;Verticillium longisporum
#
# Verticillium nonalfalfae:
# Verticillium nonalfalfae	1051616	Eukaryota;Ascomycota;Sordariomycetes;Glomerellales;Plectosphaerellaceae;Verticillium;Verticillium nonalfalfae
#
# Vezdaea acicularis:
# Vezdaea acicularis	2939408	Eukaryota;Ascomycota;;Vezdaeales;Vezdaeaceae;Vezdaea;Vezdaea acicularis
#
# Vezdaea aestivalis:
# Vezdaea aestivalis	2939405	Eukaryota;Ascomycota;;Vezdaeales;Vezdaeaceae;Vezdaea;Vezdaea aestivalis
#
# Violaceomyces palustris:
# Violaceomyces palustris	1673888	Eukaryota;Basidiomycota;Ustilaginomycetes;Violaceomycetales;Violaceomycetaceae;Violaceomyces;Violaceomyces palustris
#
# Volvariella volvacea WC 439:
# Volvariella volvacea WC 439	1457512	Eukaryota;Basidiomycota;Agaricomycetes;Agaricales;Pluteaceae;Volvariella;Volvariella volvacea
#
# Wallemia hederae:
# Wallemia hederae	1540922	Eukaryota;Basidiomycota;Wallemiomycetes;Wallemiales;Wallemiaceae;Wallemia;Wallemia hederae
#
# Wallemia ichthyophaga EXF-994:
# Wallemia ichthyophaga EXF-994	1299270	Eukaryota;Basidiomycota;Wallemiomycetes;Wallemiales;Wallemiaceae;Wallemia;Wallemia ichthyophaga
#
# Wallemia mellicola:
# Wallemia mellicola	1708541	Eukaryota;Basidiomycota;Wallemiomycetes;Wallemiales;Wallemiaceae;Wallemia;Wallemia mellicola
#
# Wallemia mellicola CBS:
#
#
# Wallemia mellicola CBS 633.66:
# Wallemia mellicola CBS 633.66	671144	Eukaryota;Basidiomycota;Wallemiomycetes;Wallemiales;Wallemiaceae;Wallemia;Wallemia mellicola
#
# Watsoniomyces obsoletus:
# Watsoniomyces obsoletus	2796175	Eukaryota;Ascomycota;Lichinomycetes;Lichinales;Lichinaceae;Watsoniomyces;Watsoniomyces obsoletus
#
# Westerdykella ornata:
# Westerdykella ornata	318751	Eukaryota;Ascomycota;Dothideomycetes;Pleosporales;Sporormiaceae;Westerdykella;Westerdykella ornata
#
# Wickerhamomyces anomalus:
# Wickerhamomyces anomalus	4927	Eukaryota;Ascomycota;Saccharomycetes;Saccharomycetales;Phaffomycetaceae;Wickerhamomyces;Wickerhamomyces anomalus
#
# Wickerhamomyces ciferrii:
# Wickerhamomyces ciferrii	1041607	Eukaryota;Ascomycota;Saccharomycetes;Saccharomycetales;Phaffomycetaceae;Wickerhamomyces;Wickerhamomyces ciferrii
#
# Wickerhamomyces mucosus:
# Wickerhamomyces mucosus	1378264	Eukaryota;Ascomycota;Saccharomycetes;Saccharomycetales;Phaffomycetaceae;Wickerhamomyces;Wickerhamomyces mucosus
#
# Wilcoxina mikolae CBS 423.85:
# Wilcoxina mikolae CBS 423.85	1314677	Eukaryota;Ascomycota;Pezizomycetes;Pezizales;Pyronemataceae;Wilcoxina;Wilcoxina mikolae
#
# Wolfiporia cocos MD-104 SS10:
# Wolfiporia cocos MD-104 SS10	742152	Eukaryota;Basidiomycota;Agaricomycetes;Polyporales;Phaeolaceae;Wolfiporia;Wolfiporia cocos
#
# Xanthomendoza cf. fulva:
# Xanthomendoza cf. fulva	2903221	Eukaryota;Ascomycota;Lecanoromycetes;Teloschistales;Teloschistaceae;Xanthomendoza;Xanthomendoza cf. fulva
#
# Xanthoria aureola:
# Xanthoria aureola	262315	Eukaryota;Ascomycota;Lecanoromycetes;Teloschistales;Teloschistaceae;Xanthoria;Xanthoria aureola
#
# Xylaria arbuscula:
# Xylaria arbuscula	114810	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria arbuscula
#
# Xylaria bambusicola:
# Xylaria bambusicola	326684	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria bambusicola
#
# Xylariaceae sp.:
# Xylariaceae sp.	1881983	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;;Xylariaceae sp.
#
# Xylariaceae sp. AK1471:
# Xylariaceae sp. AK1471	2723393	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;;Xylariaceae sp. AK1471
#
# Xylariaceae sp. FL0016:
# Xylariaceae sp. FL0016	2614588	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;;Xylariaceae sp. FL0016
#
# Xylariaceae sp. FL0255:
# Xylariaceae sp. FL0255	2614589	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;;Xylariaceae sp. FL0255
#
# Xylariaceae sp. FL0594:
# Xylariaceae sp. FL0594	2614590	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;;Xylariaceae sp. FL0594
#
# Xylariaceae sp. FL0804:
# Xylariaceae sp. FL0804	2663375	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;;Xylariaceae sp. FL0804
#
# Xylariaceae sp. FL1019:
# Xylariaceae sp. FL1019	2614591	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;;Xylariaceae sp. FL1019
#
# Xylariaceae sp. FL1272:
# Xylariaceae sp. FL1272	2663376	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;;Xylariaceae sp. FL1272
#
# Xylariaceae sp. FL1651:
# Xylariaceae sp. FL1651	2614592	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;;Xylariaceae sp. FL1651
#
# Xylaria cubensis:
# Xylaria cubensis	114814	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria cubensis
#
# Xylaria digitata:
# Xylaria digitata	323540	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria digitata
#
# Xylaria flabelliformis:
# Xylaria flabelliformis	2512241	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria flabelliformis
#
# Xylaria grammica:
# Xylaria grammica	363999	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria grammica
#
# Xylaria hypoxylon:
# Xylaria hypoxylon	37992	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria hypoxylon
#
# Xylaria intraflava:
# Xylaria intraflava	492091	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria intraflava
#
# Xylariales sp. No.14919:
# Xylariales sp. No.14919	1813822	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;;;Xylariales sp. No.14919
#
# Xylaria multiplex:
# Xylaria multiplex	323545	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria multiplex
#
# Xylaria nigripes:
# Xylaria nigripes	490159	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria nigripes
#
# Xylaria palmicola:
# Xylaria palmicola	665665	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria palmicola
#
# Xylaria polymorpha:
# Xylaria polymorpha	77046	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria polymorpha
#
# Xylaria sp. CBS:
#
#
# Xylaria sp. FL0933:
# Xylaria sp. FL0933	2614584	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria sp. FL0933
#
# Xylaria sp. FL1042:
# Xylaria sp. FL1042	2614583	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria sp. FL1042
#
# Xylaria telfairii:
# Xylaria telfairii	477509	Eukaryota;Ascomycota;Sordariomycetes;Xylariales;Xylariaceae;Xylaria;Xylaria telfairii
#
# Xylariomycetidae sp.:
# Xylariomycetidae sp.	2572554	Eukaryota;Ascomycota;Sordariomycetes;;;;Xylariomycetidae sp.
#
# Xylariomycetidae sp. FL0641:
# Xylariomycetidae sp. FL0641	2614611	Eukaryota;Ascomycota;Sordariomycetes;;;;Xylariomycetidae sp. FL0641
#
# Xylographa bjoerkii:
# Xylographa bjoerkii	1590129	Eukaryota;Ascomycota;Lecanoromycetes;Trapeliales;Trapeliaceae;Xylographa;Xylographa bjoerkii
#
# Xylographa carneopallida:
# Xylographa carneopallida	1590122	Eukaryota;Ascomycota;Lecanoromycetes;Trapeliales;Trapeliaceae;Xylographa;Xylographa carneopallida
#
# Xylographa opegraphella:
# Xylographa opegraphella	1453797	Eukaryota;Ascomycota;Lecanoromycetes;Trapeliales;Trapeliaceae;Xylographa;Xylographa opegraphella
#
# Xylographa pallens:
# Xylographa pallens	1590118	Eukaryota;Ascomycota;Lecanoromycetes;Trapeliales;Trapeliaceae;Xylographa;Xylographa pallens
#
# Xylographa parallela:
# Xylographa parallela	1453798	Eukaryota;Ascomycota;Lecanoromycetes;Trapeliales;Trapeliaceae;Xylographa;Xylographa parallela
#
# Xylographa soralifera:
# Xylographa soralifera	1590126	Eukaryota;Ascomycota;Lecanoromycetes;Trapeliales;Trapeliaceae;Xylographa;Xylographa soralifera
#
# Xylographa trunciseda:
# Xylographa trunciseda	1453799	Eukaryota;Ascomycota;Lecanoromycetes;Trapeliales;Trapeliaceae;Xylographa;Xylographa trunciseda
#
# Xylographa vitiligo:
# Xylographa vitiligo	223429	Eukaryota;Ascomycota;Lecanoromycetes;Trapeliales;Trapeliaceae;Xylographa;Xylographa vitiligo
#
# Yarrowia lipolytica:
# Yarrowia lipolytica	4952	Eukaryota;Ascomycota;Saccharomycetes;Saccharomycetales;Dipodascaceae;Yarrowia;Yarrowia lipolytica
#
# Yarrowia sp. B02:
# Yarrowia sp. B02	2768839	Eukaryota;Ascomycota;Saccharomycetes;Saccharomycetales;Dipodascaceae;Yarrowia;Yarrowia sp. B02
#
# Yarrowia sp. E02:
# Yarrowia sp. E02	2768841	Eukaryota;Ascomycota;Saccharomycetes;Saccharomycetales;Dipodascaceae;Yarrowia;Yarrowia sp. E02
#
# Zalerion maritima:
# Zalerion maritima	339359	Eukaryota;Ascomycota;Sordariomycetes;Lulworthiales;Lulworthiaceae;Zalerion;Zalerion maritima
#
# Zasmidium cellare ATCC:
#
#
# Zopfia:
# Zopfia	160034	Eukaryota;Ascomycota;Dothideomycetes;;Zopfiaceae;Zopfia;
#
# Zopfia rhizophila CBS:
#
#
# Zopfochytrium:
# Zopfochytrium	2709238	Eukaryota;Chytridiomycota;Chytridiomycetes;Chytridiales;Chytridiaceae;Zopfochytrium;
#
# Zopfochytrium polystomum:
# Zopfochytrium polystomum	2211651	Eukaryota;Chytridiomycota;Chytridiomycetes;Chytridiales;Chytridiaceae;Zopfochytrium;Zopfochytrium polystomum
#
# Zychaea:
# Zychaea	64651	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Lichtheimiaceae;Zychaea;
#
# Zychaea mexicana:
# Zychaea mexicana	64656	Eukaryota;Mucoromycota;Mucoromycetes;Mucorales;Lichtheimiaceae;Zychaea;Zychaea mexicana
