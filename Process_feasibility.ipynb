# %% [markdown]
# ## Create Multiple Fasta's from the One Input File

# %%
def split_fasta(input_file):
    with open(input_file, 'r') as file:
        content = file.read()
        
    # Split the content based on '>'
    fasta_entries = content.split('>')
    
    # The first entry is empty if the file starts with '>'
    if fasta_entries[0] == '':
        fasta_entries = fasta_entries[1:]
    
    for entry in fasta_entries:
        # Split the entry into lines
        lines = entry.strip().split('\n')
        # The first line is the header
        header = lines[0]
        # The rest is the sequence
        sequence = '\n'.join(lines[1:])
        # Get the file name from the header
        file_name = header.split()[0]
        
        # Write the entry to a new file
        with open(f"{file_name}.fasta", 'w') as output_file:
            output_file.write(f">{header}\n{sequence}\n")

# Usage
input_file = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/safety_net.txt"
split_fasta(input_file)

# %% [markdown]
# ## 1.2 Perform Viral Genome Search on Fasta's

# %%
import os
import subprocess
import time
from datetime import datetime, timezone, timedelta

# Function to convert GMT to Dublin local time
def gmt_to_dublin(gmt_time):
    dublin_offset = timedelta(hours=1)
    return gmt_time + dublin_offset

# Paths
fasta_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/"
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results"

# Create the blast output directory if it doesn't exist
os.makedirs(blast_output_directory, exist_ok=True)

# Record the start time of the entire process in GMT
start_time = datetime.now(timezone.utc)
start_time_dublin = gmt_to_dublin(start_time)
print(f"Process started at: {start_time_dublin.strftime('%Y-%m-%d %H:%M:%S')} Dublin local time")

def get_accession_id(fasta_file):
    with open(fasta_file, 'r') as file:
        for line in file:
            if line.startswith('>'):
                return line.split()[0][1:]
    return None

# Iterate through each fasta file in the directory
for filename in os.listdir(fasta_directory):
    if filename.endswith(".fasta"):
        fasta_file = os.path.join(fasta_directory, filename)
        accession_id = get_accession_id(fasta_file)
        if not accession_id:
            print(f"No accession ID found in {filename}, skipping...")
            continue
        
        output_file = os.path.join(blast_output_directory, f"{filename.split('.')[0]}_blastp_results.txt")
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            print(f"Skipping {filename} as output file {output_file} already exists.")
            continue
        
        # Construct the blastp command for remote search
        blastp_command = [
            "blastp",
            "-query", fasta_file,
            "-db", "genomic/Viruses/Viral_Protein_Sequences",
            "-out", output_file,
            "-evalue", "0.06",
            "-entrez_query", "viruses[orgn]",
            "-remote"
        ]
        
        # Record start time for this file
        file_start_time = time.time()
        
        # Execute the blastp command
        print(f"Running blast search for {filename} (Accession ID: {accession_id})...")
        try:
            result = subprocess.run(blastp_command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            if result.returncode == 0:
                print(f"BLAST command executed successfully for {filename}.")
            else:
                print(f"BLAST command failed for {filename} with return code {result.returncode}.")
        except subprocess.CalledProcessError as e:
            print(f"BLAST command failed for {filename} with error: {e.stderr.decode()}")
        
        # Calculate elapsed time for this file
        file_elapsed_time = time.time() - file_start_time
        
        # Print filename and elapsed time
        print(f"Blast search for {filename} completed in {file_elapsed_time:.2f} seconds.")
        
        # Check if 30 minutes have elapsed since the start of the process
        if (datetime.now(timezone.utc) - start_time).seconds >= 1800:
            print(f"Process has been running for 30 minutes. Current time: {gmt_to_dublin(datetime.now(timezone.utc)).strftime('%Y-%m-%d %H:%M:%S')} Dublin local time")
            start_time = datetime.now(timezone.utc)

print("Blastp searches completed for all fasta files.")
# Out:
# Process started at: 2024-06-18 14:27:55 Dublin local time
# Skipping hor006381.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006381_blastp_results.txt already exists.
# Skipping hor003462.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003462_blastp_results.txt already exists.
# Skipping hor005582.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005582_blastp_results.txt already exists.
# Skipping hor004014.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004014_blastp_results.txt already exists.
# Skipping hor003229.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003229_blastp_results.txt already exists.
# Skipping hor001506.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001506_blastp_results.txt already exists.
# Skipping hor001504.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001504_blastp_results.txt already exists.
# Skipping hor004994.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004994_blastp_results.txt already exists.
# Skipping hor002895.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002895_blastp_results.txt already exists.
# Skipping hor001909.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001909_blastp_results.txt already exists.
# Skipping hor003973.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003973_blastp_results.txt already exists.
# Skipping hor002719.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002719_blastp_results.txt already exists.
# Skipping hor001531.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001531_blastp_results.txt already exists.
# Skipping hor003018.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003018_blastp_results.txt already exists.
# Skipping hor000579.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000579_blastp_results.txt already exists.
# Skipping hor003509.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003509_blastp_results.txt already exists.
# Skipping hor002191.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002191_blastp_results.txt already exists.
# Skipping hor006153.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006153_blastp_results.txt already exists.
# Skipping hor005043.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005043_blastp_results.txt already exists.
# Skipping hor004205.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004205_blastp_results.txt already exists.
# Skipping hor004724.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004724_blastp_results.txt already exists.
# Skipping hor005352.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005352_blastp_results.txt already exists.
# Skipping hor006604.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006604_blastp_results.txt already exists.
# Skipping hor006145.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006145_blastp_results.txt already exists.
# Skipping hor001162.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001162_blastp_results.txt already exists.
# Skipping hor003040.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003040_blastp_results.txt already exists.
# Skipping hor006292.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006292_blastp_results.txt already exists.
# Skipping hor003088.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003088_blastp_results.txt already exists.
# Skipping hor001204.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001204_blastp_results.txt already exists.
# Skipping hor003078.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003078_blastp_results.txt already exists.
# Skipping hor001484.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001484_blastp_results.txt already exists.
# Skipping hor005627.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005627_blastp_results.txt already exists.
# Skipping hor005483.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005483_blastp_results.txt already exists.
# Skipping hor001910.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001910_blastp_results.txt already exists.
# Skipping hor000279.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000279_blastp_results.txt already exists.
# Skipping hor006438.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006438_blastp_results.txt already exists.
# Skipping hor002076.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002076_blastp_results.txt already exists.
# Skipping hor001604.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001604_blastp_results.txt already exists.
# Skipping hor005740.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005740_blastp_results.txt already exists.
# Skipping hor006249.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006249_blastp_results.txt already exists.
# Skipping hor006417.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006417_blastp_results.txt already exists.
# Skipping hor005533.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005533_blastp_results.txt already exists.
# Skipping hor006686.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006686_blastp_results.txt already exists.
# Skipping hor001274.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001274_blastp_results.txt already exists.
# Skipping hor000878.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000878_blastp_results.txt already exists.
# Skipping hor004833.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004833_blastp_results.txt already exists.
# Skipping hor005277.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005277_blastp_results.txt already exists.
# Skipping hor000336.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000336_blastp_results.txt already exists.
# Skipping hor001051.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001051_blastp_results.txt already exists.
# Skipping hor002798.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002798_blastp_results.txt already exists.
# Skipping hor000631.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000631_blastp_results.txt already exists.
# Skipping hor006009.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006009_blastp_results.txt already exists.
# Skipping hor001632.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001632_blastp_results.txt already exists.
# Skipping hor004661.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004661_blastp_results.txt already exists.
# Skipping hor000812.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000812_blastp_results.txt already exists.
# Skipping hor006593.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006593_blastp_results.txt already exists.
# Skipping hor005067.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005067_blastp_results.txt already exists.
# Skipping hor000989.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000989_blastp_results.txt already exists.
# Skipping hor003922.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003922_blastp_results.txt already exists.
# Skipping hor002140.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002140_blastp_results.txt already exists.
# Skipping hor004563.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004563_blastp_results.txt already exists.
# Skipping hor000203.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000203_blastp_results.txt already exists.
# Skipping hor000502.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000502_blastp_results.txt already exists.
# Skipping hor005256.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005256_blastp_results.txt already exists.
# Skipping hor004042.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004042_blastp_results.txt already exists.
# Skipping hor004804.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004804_blastp_results.txt already exists.
# Skipping hor002671.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002671_blastp_results.txt already exists.
# Skipping hor001796.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001796_blastp_results.txt already exists.
# Skipping hor000853.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000853_blastp_results.txt already exists.
# Skipping hor005052.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005052_blastp_results.txt already exists.
# Skipping hor005174.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005174_blastp_results.txt already exists.
# Skipping hor003985.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003985_blastp_results.txt already exists.
# Skipping hor001499.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001499_blastp_results.txt already exists.
# Skipping hor000771.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000771_blastp_results.txt already exists.
# Skipping hor004149.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004149_blastp_results.txt already exists.
# Skipping hor002337.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002337_blastp_results.txt already exists.
# Skipping hor005049.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005049_blastp_results.txt already exists.
# Skipping hor005206.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005206_blastp_results.txt already exists.
# Skipping hor003898.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003898_blastp_results.txt already exists.
# Skipping hor004004.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004004_blastp_results.txt already exists.
# Skipping hor006151.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006151_blastp_results.txt already exists.
# Skipping hor006343.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006343_blastp_results.txt already exists.
# Skipping hor005786.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005786_blastp_results.txt already exists.
# Skipping hor005240.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005240_blastp_results.txt already exists.
# Skipping hor004644.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004644_blastp_results.txt already exists.
# Skipping hor004259.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004259_blastp_results.txt already exists.
# Skipping hor004367.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004367_blastp_results.txt already exists.
# Skipping hor000902.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000902_blastp_results.txt already exists.
# Skipping hor005670.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005670_blastp_results.txt already exists.
# Skipping hor004935.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004935_blastp_results.txt already exists.
# Skipping hor003244.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003244_blastp_results.txt already exists.
# Skipping hor004605.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004605_blastp_results.txt already exists.
# Skipping hor006283.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006283_blastp_results.txt already exists.
# Skipping hor000934.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000934_blastp_results.txt already exists.
# Skipping hor004471.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004471_blastp_results.txt already exists.
# Skipping hor002449.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002449_blastp_results.txt already exists.
# Skipping hor006315.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006315_blastp_results.txt already exists.
# Skipping hor001163.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001163_blastp_results.txt already exists.
# Skipping hor002978.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002978_blastp_results.txt already exists.
# Skipping hor004581.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004581_blastp_results.txt already exists.
# Skipping hor002100.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002100_blastp_results.txt already exists.
# Skipping hor000453.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000453_blastp_results.txt already exists.
# Skipping hor004496.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004496_blastp_results.txt already exists.
# Skipping hor004227.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004227_blastp_results.txt already exists.
# Skipping hor004442.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004442_blastp_results.txt already exists.
# Skipping hor003463.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003463_blastp_results.txt already exists.
# Skipping hor000272.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000272_blastp_results.txt already exists.
# Skipping hor000220.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000220_blastp_results.txt already exists.
# Skipping hor003637.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003637_blastp_results.txt already exists.
# Skipping hor005214.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005214_blastp_results.txt already exists.
# Skipping hor005882.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005882_blastp_results.txt already exists.
# Skipping hor002217.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002217_blastp_results.txt already exists.
# Skipping hor002041.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002041_blastp_results.txt already exists.
# Skipping hor002411.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002411_blastp_results.txt already exists.
# Skipping hor006763.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006763_blastp_results.txt already exists.
# Skipping hor003609.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003609_blastp_results.txt already exists.
# Skipping hor005571.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005571_blastp_results.txt already exists.
# Skipping hor002292.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002292_blastp_results.txt already exists.
# Skipping hor006285.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006285_blastp_results.txt already exists.
# Skipping hor004075.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004075_blastp_results.txt already exists.
# Skipping hor001738.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001738_blastp_results.txt already exists.
# Skipping hor002737.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002737_blastp_results.txt already exists.
# Skipping hor005284.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005284_blastp_results.txt already exists.
# Skipping hor004049.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004049_blastp_results.txt already exists.
# Skipping hor000428.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000428_blastp_results.txt already exists.
# Skipping hor004411.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004411_blastp_results.txt already exists.
# Skipping hor002042.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002042_blastp_results.txt already exists.
# Skipping hor004558.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004558_blastp_results.txt already exists.
# Skipping hor006036.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006036_blastp_results.txt already exists.
# Skipping hor000338.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000338_blastp_results.txt already exists.
# Skipping hor002962.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002962_blastp_results.txt already exists.
# Skipping hor002990.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002990_blastp_results.txt already exists.
# Skipping hor003324.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003324_blastp_results.txt already exists.
# Skipping hor003266.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003266_blastp_results.txt already exists.
# Skipping hor002276.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002276_blastp_results.txt already exists.
# Skipping hor005625.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005625_blastp_results.txt already exists.
# Skipping hor004778.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004778_blastp_results.txt already exists.
# Skipping hor006191.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006191_blastp_results.txt already exists.
# Skipping hor005946.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005946_blastp_results.txt already exists.
# Skipping hor002778.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002778_blastp_results.txt already exists.
# Skipping hor004220.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004220_blastp_results.txt already exists.
# Skipping hor005324.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005324_blastp_results.txt already exists.
# Skipping hor005330.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005330_blastp_results.txt already exists.
# Skipping hor005787.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005787_blastp_results.txt already exists.
# Skipping hor000836.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000836_blastp_results.txt already exists.
# Skipping hor003070.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003070_blastp_results.txt already exists.
# Skipping hor001359.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001359_blastp_results.txt already exists.
# Skipping hor001576.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001576_blastp_results.txt already exists.
# Skipping hor001471.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001471_blastp_results.txt already exists.
# Skipping hor002961.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002961_blastp_results.txt already exists.
# Skipping hor006261.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006261_blastp_results.txt already exists.
# Skipping hor004873.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004873_blastp_results.txt already exists.
# Skipping hor003769.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003769_blastp_results.txt already exists.
# Skipping hor000498.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000498_blastp_results.txt already exists.
# Skipping hor000226.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000226_blastp_results.txt already exists.
# Skipping hor004217.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004217_blastp_results.txt already exists.
# Skipping hor006645.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006645_blastp_results.txt already exists.
# Skipping hor006088.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006088_blastp_results.txt already exists.
# Skipping hor000571.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000571_blastp_results.txt already exists.
# Skipping hor002555.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002555_blastp_results.txt already exists.
# Skipping hor004609.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004609_blastp_results.txt already exists.
# Skipping hor006192.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006192_blastp_results.txt already exists.
# Skipping hor002686.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002686_blastp_results.txt already exists.
# Skipping hor006046.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006046_blastp_results.txt already exists.
# Skipping hor005640.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005640_blastp_results.txt already exists.
# Skipping hor003434.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003434_blastp_results.txt already exists.
# Skipping hor001953.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001953_blastp_results.txt already exists.
# Skipping hor003241.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003241_blastp_results.txt already exists.
# Skipping hor004540.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004540_blastp_results.txt already exists.
# Skipping hor006466.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006466_blastp_results.txt already exists.
# Skipping hor000528.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000528_blastp_results.txt already exists.
# Skipping hor004421.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004421_blastp_results.txt already exists.
# Skipping hor002009.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002009_blastp_results.txt already exists.
# Skipping hor004621.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004621_blastp_results.txt already exists.
# Skipping hor003845.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003845_blastp_results.txt already exists.
# Skipping hor005242.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005242_blastp_results.txt already exists.
# Skipping hor005176.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005176_blastp_results.txt already exists.
# Skipping hor005282.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005282_blastp_results.txt already exists.
# Skipping hor006253.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006253_blastp_results.txt already exists.
# Skipping hor003789.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003789_blastp_results.txt already exists.
# Skipping hor000019.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000019_blastp_results.txt already exists.
# Skipping hor002241.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002241_blastp_results.txt already exists.
# Skipping hor006094.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006094_blastp_results.txt already exists.
# Skipping hor005040.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005040_blastp_results.txt already exists.
# Skipping hor001446.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001446_blastp_results.txt already exists.
# Skipping hor002332.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002332_blastp_results.txt already exists.
# Skipping hor004551.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004551_blastp_results.txt already exists.
# Skipping hor004314.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004314_blastp_results.txt already exists.
# Skipping hor001993.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001993_blastp_results.txt already exists.
# Skipping hor002838.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002838_blastp_results.txt already exists.
# Skipping hor005747.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005747_blastp_results.txt already exists.
# Skipping hor000545.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000545_blastp_results.txt already exists.
# Skipping hor000123.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000123_blastp_results.txt already exists.
# Skipping hor001812.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001812_blastp_results.txt already exists.
# Skipping hor004167.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004167_blastp_results.txt already exists.
# Skipping hor001820.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001820_blastp_results.txt already exists.
# Skipping hor000471.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000471_blastp_results.txt already exists.
# Skipping hor000720.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000720_blastp_results.txt already exists.
# Skipping hor006294.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006294_blastp_results.txt already exists.
# Skipping hor003935.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003935_blastp_results.txt already exists.
# Skipping hor003783.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003783_blastp_results.txt already exists.
# Skipping hor000491.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000491_blastp_results.txt already exists.
# Skipping hor003375.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003375_blastp_results.txt already exists.
# Skipping hor005445.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005445_blastp_results.txt already exists.
# Skipping hor006406.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006406_blastp_results.txt already exists.
# Skipping hor003301.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003301_blastp_results.txt already exists.
# Skipping hor003748.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003748_blastp_results.txt already exists.
# Skipping hor005868.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005868_blastp_results.txt already exists.
# Skipping hor003704.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003704_blastp_results.txt already exists.
# Skipping hor002286.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002286_blastp_results.txt already exists.
# Skipping hor003945.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003945_blastp_results.txt already exists.
# Skipping hor003246.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003246_blastp_results.txt already exists.
# Skipping hor000639.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000639_blastp_results.txt already exists.
# Skipping hor005016.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005016_blastp_results.txt already exists.
# Skipping hor001117.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001117_blastp_results.txt already exists.
# Skipping hor005191.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005191_blastp_results.txt already exists.
# Skipping hor004094.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004094_blastp_results.txt already exists.
# Skipping hor001821.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001821_blastp_results.txt already exists.
# Skipping hor000675.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000675_blastp_results.txt already exists.
# Skipping hor002333.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002333_blastp_results.txt already exists.
# Skipping hor004044.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004044_blastp_results.txt already exists.
# Skipping hor001134.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001134_blastp_results.txt already exists.
# Skipping hor000212.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000212_blastp_results.txt already exists.
# Skipping hor000763.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000763_blastp_results.txt already exists.
# Skipping hor001013.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001013_blastp_results.txt already exists.
# Skipping hor003626.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003626_blastp_results.txt already exists.
# Skipping hor002177.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002177_blastp_results.txt already exists.
# Skipping hor000735.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000735_blastp_results.txt already exists.
# Skipping hor001898.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001898_blastp_results.txt already exists.
# Skipping hor002896.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002896_blastp_results.txt already exists.
# Skipping hor005485.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005485_blastp_results.txt already exists.
# Skipping hor000633.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000633_blastp_results.txt already exists.
# Skipping hor002664.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002664_blastp_results.txt already exists.
# Skipping hor003371.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003371_blastp_results.txt already exists.
# Skipping hor001523.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001523_blastp_results.txt already exists.
# Skipping hor004532.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004532_blastp_results.txt already exists.
# Skipping hor003325.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003325_blastp_results.txt already exists.
# Skipping hor004811.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004811_blastp_results.txt already exists.
# Skipping hor003567.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003567_blastp_results.txt already exists.
# Skipping hor004371.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004371_blastp_results.txt already exists.
# Skipping hor001706.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001706_blastp_results.txt already exists.
# Skipping hor003564.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003564_blastp_results.txt already exists.
# Skipping hor001159.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001159_blastp_results.txt already exists.
# Skipping hor001651.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001651_blastp_results.txt already exists.
# Skipping hor005171.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005171_blastp_results.txt already exists.
# Skipping hor001397.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001397_blastp_results.txt already exists.
# Skipping hor001565.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001565_blastp_results.txt already exists.
# Skipping hor006245.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006245_blastp_results.txt already exists.
# Skipping hor001421.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001421_blastp_results.txt already exists.
# Skipping hor000076.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000076_blastp_results.txt already exists.
# Skipping hor001867.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001867_blastp_results.txt already exists.
# Skipping hor002805.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002805_blastp_results.txt already exists.
# Skipping hor005383.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005383_blastp_results.txt already exists.
# Skipping hor005930.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005930_blastp_results.txt already exists.
# Skipping hor003629.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003629_blastp_results.txt already exists.
# Skipping hor001485.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001485_blastp_results.txt already exists.
# Skipping hor002669.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002669_blastp_results.txt already exists.
# Skipping hor004942.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004942_blastp_results.txt already exists.
# Skipping hor000087.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000087_blastp_results.txt already exists.
# Skipping hor006586.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006586_blastp_results.txt already exists.
# Skipping hor003774.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003774_blastp_results.txt already exists.
# Skipping hor004384.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004384_blastp_results.txt already exists.
# Skipping hor003433.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003433_blastp_results.txt already exists.
# Skipping hor003920.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003920_blastp_results.txt already exists.
# Skipping hor003923.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003923_blastp_results.txt already exists.
# Skipping hor003145.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003145_blastp_results.txt already exists.
# Skipping hor002412.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002412_blastp_results.txt already exists.
# Skipping hor000116.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000116_blastp_results.txt already exists.
# Skipping hor006405.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006405_blastp_results.txt already exists.
# Skipping hor002446.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002446_blastp_results.txt already exists.
# Skipping hor005818.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005818_blastp_results.txt already exists.
# Skipping hor005331.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005331_blastp_results.txt already exists.
# Skipping hor002124.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002124_blastp_results.txt already exists.
# Skipping hor001994.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001994_blastp_results.txt already exists.
# Skipping hor004321.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004321_blastp_results.txt already exists.
# Skipping hor001630.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001630_blastp_results.txt already exists.
# Skipping hor005298.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005298_blastp_results.txt already exists.
# Skipping hor003252.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003252_blastp_results.txt already exists.
# Skipping hor002195.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002195_blastp_results.txt already exists.
# Skipping hor005724.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005724_blastp_results.txt already exists.
# Skipping hor001264.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001264_blastp_results.txt already exists.
# Skipping hor001530.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001530_blastp_results.txt already exists.
# Skipping hor001302.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001302_blastp_results.txt already exists.
# Skipping hor004003.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004003_blastp_results.txt already exists.
# Skipping hor002343.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002343_blastp_results.txt already exists.
# Skipping hor004400.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004400_blastp_results.txt already exists.
# Skipping hor004315.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004315_blastp_results.txt already exists.
# Skipping hor002867.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002867_blastp_results.txt already exists.
# Skipping hor001209.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001209_blastp_results.txt already exists.
# Skipping hor001995.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001995_blastp_results.txt already exists.
# Skipping hor005222.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005222_blastp_results.txt already exists.
# Skipping hor002120.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002120_blastp_results.txt already exists.
# Skipping hor000258.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000258_blastp_results.txt already exists.
# Skipping hor006559.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006559_blastp_results.txt already exists.
# Skipping hor001599.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001599_blastp_results.txt already exists.
# Skipping hor003682.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003682_blastp_results.txt already exists.
# Skipping hor003159.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003159_blastp_results.txt already exists.
# Skipping hor004855.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004855_blastp_results.txt already exists.
# Skipping hor001460.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001460_blastp_results.txt already exists.
# Skipping hor002434.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002434_blastp_results.txt already exists.
# Skipping hor005070.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005070_blastp_results.txt already exists.
# ...
# Skipping hor001579.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001579_blastp_results.txt already exists.
# Skipping hor002639.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002639_blastp_results.txt already exists.
# Skipping hor004850.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004850_blastp_results.txt already exists.
# Skipping hor002478.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002478_blastp_results.txt already exists.
# Skipping hor002792.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002792_blastp_results.txt already exists.
# Skipping hor004007.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004007_blastp_results.txt already exists.
# Skipping hor005314.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005314_blastp_results.txt already exists.
# Skipping hor002672.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002672_blastp_results.txt already exists.
# Skipping hor003838.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003838_blastp_results.txt already exists.
# Skipping hor005780.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005780_blastp_results.txt already exists.
# Skipping hor004408.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004408_blastp_results.txt already exists.
# Skipping hor005517.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005517_blastp_results.txt already exists.
# Skipping hor004623.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004623_blastp_results.txt already exists.
# Skipping hor005412.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005412_blastp_results.txt already exists.
# Skipping hor000122.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000122_blastp_results.txt already exists.
# Skipping hor000918.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000918_blastp_results.txt already exists.
# Skipping hor004530.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004530_blastp_results.txt already exists.
# Skipping hor002094.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002094_blastp_results.txt already exists.
# Skipping hor005628.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005628_blastp_results.txt already exists.
# Skipping hor002325.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002325_blastp_results.txt already exists.
# Skipping hor004246.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004246_blastp_results.txt already exists.
# Skipping hor002780.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002780_blastp_results.txt already exists.
# Skipping hor005975.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005975_blastp_results.txt already exists.
# Skipping hor005944.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005944_blastp_results.txt already exists.
# Skipping hor000510.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000510_blastp_results.txt already exists.
# Skipping hor006682.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006682_blastp_results.txt already exists.
# Skipping hor001915.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001915_blastp_results.txt already exists.
# Skipping hor004459.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004459_blastp_results.txt already exists.
# Skipping hor005491.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005491_blastp_results.txt already exists.
# Skipping hor005354.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005354_blastp_results.txt already exists.
# Skipping hor001455.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001455_blastp_results.txt already exists.
# Skipping hor002136.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002136_blastp_results.txt already exists.
# Skipping hor001445.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001445_blastp_results.txt already exists.
# Skipping hor001939.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001939_blastp_results.txt already exists.
# Skipping hor003264.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003264_blastp_results.txt already exists.
# Skipping hor003496.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003496_blastp_results.txt already exists.
# Skipping hor005320.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005320_blastp_results.txt already exists.
# Skipping hor005150.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005150_blastp_results.txt already exists.
# Skipping hor005845.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005845_blastp_results.txt already exists.
# Skipping hor003910.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003910_blastp_results.txt already exists.
# Skipping hor001961.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001961_blastp_results.txt already exists.
# Skipping hor001079.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001079_blastp_results.txt already exists.
# Skipping hor005664.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005664_blastp_results.txt already exists.
# Skipping hor003804.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003804_blastp_results.txt already exists.
# Skipping hor004718.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004718_blastp_results.txt already exists.
# Skipping hor001508.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001508_blastp_results.txt already exists.
# Skipping hor003844.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003844_blastp_results.txt already exists.
# Skipping hor001991.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001991_blastp_results.txt already exists.
# Skipping hor002733.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002733_blastp_results.txt already exists.
# Skipping hor001936.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001936_blastp_results.txt already exists.
# Skipping hor001384.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001384_blastp_results.txt already exists.
# Skipping hor000128.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000128_blastp_results.txt already exists.
# Skipping hor001281.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001281_blastp_results.txt already exists.
# Skipping hor000057.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000057_blastp_results.txt already exists.
# Skipping hor006705.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006705_blastp_results.txt already exists.
# Skipping hor005371.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005371_blastp_results.txt already exists.
# Skipping hor005633.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005633_blastp_results.txt already exists.
# Skipping hor005226.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005226_blastp_results.txt already exists.
# Skipping hor005594.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005594_blastp_results.txt already exists.
# Skipping hor000168.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000168_blastp_results.txt already exists.
# Skipping hor006060.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006060_blastp_results.txt already exists.
# Skipping hor004256.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004256_blastp_results.txt already exists.
# Skipping hor003069.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003069_blastp_results.txt already exists.
# Skipping hor000025.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000025_blastp_results.txt already exists.
# Skipping hor001586.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001586_blastp_results.txt already exists.
# Skipping hor003309.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003309_blastp_results.txt already exists.
# Skipping hor001847.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001847_blastp_results.txt already exists.
# Skipping hor006045.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006045_blastp_results.txt already exists.
# Skipping hor005427.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005427_blastp_results.txt already exists.
# Skipping hor004956.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004956_blastp_results.txt already exists.
# Skipping hor001047.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001047_blastp_results.txt already exists.
# Skipping hor003239.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003239_blastp_results.txt already exists.
# Skipping hor006508.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006508_blastp_results.txt already exists.
# Skipping hor004253.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004253_blastp_results.txt already exists.
# Skipping hor000854.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000854_blastp_results.txt already exists.
# Skipping hor002963.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002963_blastp_results.txt already exists.
# Skipping hor000234.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000234_blastp_results.txt already exists.
# Skipping hor004578.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004578_blastp_results.txt already exists.
# Skipping hor004819.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004819_blastp_results.txt already exists.
# Skipping hor004069.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004069_blastp_results.txt already exists.
# Skipping hor001547.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001547_blastp_results.txt already exists.
# Skipping hor004974.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004974_blastp_results.txt already exists.
# Skipping hor000659.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000659_blastp_results.txt already exists.
# Skipping hor003052.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003052_blastp_results.txt already exists.
# Skipping hor001774.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001774_blastp_results.txt already exists.
# Skipping hor006217.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor006217_blastp_results.txt already exists.
# Skipping hor004415.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004415_blastp_results.txt already exists.
# Skipping hor005598.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor005598_blastp_results.txt already exists.
# Skipping hor003440.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor003440_blastp_results.txt already exists.
# Skipping hor002220.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002220_blastp_results.txt already exists.
# Skipping hor002155.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002155_blastp_results.txt already exists.
# Skipping hor004954.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004954_blastp_results.txt already exists.
# Skipping hor004006.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004006_blastp_results.txt already exists.
# Skipping hor002391.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002391_blastp_results.txt already exists.
# Skipping hor000978.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000978_blastp_results.txt already exists.
# Skipping hor001263.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor001263_blastp_results.txt already exists.
# Skipping hor004048.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor004048_blastp_results.txt already exists.
# Skipping hor000640.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor000640_blastp_results.txt already exists.
# Skipping hor002657.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002657_blastp_results.txt already exists.
# Skipping hor002731.fasta as output file /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hor002731_blastp_results.txt already exists.
# Blastp searches completed for all fasta files.

# %% [markdown]
# ## Run blast on processed sequences...

# %% [markdown]
# #

# %%
import os

# Directory containing blast result files
blast_output_directory = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results"

# Name of the master file
master_filename = "sf_master_blaster.txt"

# Path to the master file
master_filepath = os.path.join(blast_output_directory, master_filename)

# Open the master file in append mode
with open(master_filepath, "a") as master_file:
    # Iterate through each file in the blast output directory
    for filename in os.listdir(blast_output_directory):
        # Check if the file is a blast result file
        if filename.endswith("_blastp_results.txt"):
            # Get the full path of the blast result file
            blast_result_filepath = os.path.join(blast_output_directory, filename)
            # Open the blast result file and read its content
            with open(blast_result_filepath, "r") as blast_result_file:
                # Read the content of the blast result file and write it to the master file
                master_file.write(blast_result_file.read())
                # Write a newline character to separate the content of each blast result file
                master_file.write("\n")

print("All blast_results.txt files have been concatenated into the master file:", master_filepath)
# Out:
# All blast_results.txt files have been concatenated into the master file: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/sf_master_blaster.txt

# %%
from collections import defaultdict
import csv

# Path to the master file
master_filepath =  "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/sf_master_blaster.txt"

# Initialize a defaultdict to store query counts and hits
query_hits = defaultdict(list)

# Read the file and extract query IDs and hits
try:
    with open(master_filepath, "r") as master_file:
        current_query_id = None
        for line in master_file:
            if "|" in line:  # Check if the line contains an accession ID
                current_query_id = line.split("|")[1].strip()  # Extract the query ID between "|"
            elif ">" in line:  # Check if the line contains a hit
                if current_query_id:
                    query_hits[current_query_id].append(line.split(">")[1].strip())  
except FileNotFoundError:
    print(f"Error: File '{master_filepath}' not found.")
    exit(1)
except Exception as e:
    print(f"An error occurred: {e}")
    exit(1)

# Calculate total hits for each accession ID
total_hits = {query_id: len(hits) for query_id, hits in query_hits.items()}

# Write results to CSV file
output_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv"
try:
    with open(output_csv_path, mode='w', newline='') as csv_file:
        fieldnames = ['Accession ID', 'Total Hits', 'Hits']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        for query_id, hits in sorted(query_hits.items(), key=lambda x: len(x[1]), reverse=True):
            writer.writerow({'Accession ID': query_id, 'Total Hits': total_hits[query_id], 'Hits': ', '.join(hits)})
    print(f"Results saved to '{output_csv_path}'")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")

# Print ranked total hits to screen
print("Ranked total hits for each accession ID:")
for rank, (query_id, hits) in enumerate(sorted(total_hits.items(), key=lambda x: x[1], reverse=True), start=1):
    print(f"{rank}. Accession ID: {query_id}, Total Hits: {hits}")
# Out:
# Results saved to '/home/osheakes/Research_Project_MMM/Fasta/Bacterial_Blasts/bacterial_master_blaster_results.csv'
# Ranked total hits for each accession ID:

# %%
import os
import shutil

# Function to check if the given file contains the phrase "No hits found" (case-insensitive)
def contains_no_hits(file_path):
    with open(file_path, 'r') as f:
        content = f.read()
        return "no hits found" not in content.lower()  

# Source directory containing blast result files
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/"

# Destination directory for files with hits
dest_dir = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hits"

# Create destination directory if it doesn't exist
if not os.path.exists(dest_dir):
    os.makedirs(dest_dir)

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith(".txt"):  # Check if it's a text file
        file_path = os.path.join(source_dir, file_name)
        if contains_no_hits(file_path):
            # Move the file to the destination directory if it contains hits
            shutil.move(file_path, os.path.join(dest_dir, file_name))

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hits"

# Output CSV file path
output_csv = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hits/sf_hits.csv"
# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Function to parse data from blast result file
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        query_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0  # Initialize hit_number
        hit_id = None  # Initialize hit_id variable
        species_id = None  # Initialize species_id variable
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1  # Increment hit_number for each new hit
                # Extract Hit ID
                hit_id = line.split(">")[1].split(" ")[0]
                # Extract species ID if present
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
                # Manually add species ID for specific hit ID
                if hit_id == "MDO8640940.1":
                    species_id = "Nitrosarchaeum sp."

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
                hits_data.append([query_id, hit_id, hit_number, seq_length, species_id])
    return hits_data

# List to store parsed data
parsed_data = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"):  # Check if it's a blast result file
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow(['Query ID', 'Hit ID', 'Hit Number', 'Sequence Length', 'Species ID'])
    # Write parsed data
    writer.writerows(parsed_data)

print("CSV file created successfully")
# Out:
# CSV file created successfully

# %%
import os
import csv

# Source directory containing blast result files with hits
source_dir = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hits/"

# Output CSV file path
output_csv =  "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hits/comp_sf_hits.csv"

# Function to extract query ID from file name
def extract_query_id(file_name):
    return file_name.replace("_blastp_results.txt", "")

# Parse out required data from blast reaults
def parse_blast_results(file_path):
    hits_data = []
    with open(file_path, 'r') as f:
        query_id = extract_query_id(os.path.basename(file_path))
        hit_number = 0 
        hit_id = None 
        species_id = None 
        seq_length = None  
        evalue = None 
        score = None  
        identities = None  
        identities_percent = None
        positives = None 
        positives_percent = None  
        gaps = None  
        gaps_percent = None  
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hit_number += 1 
                hit_id = line.split(">")[1].split(" ")[0]
                species_split = line.split("[")
                if len(species_split) > 1:
                    species_id = species_split[1].split("]")[0]
                else:
                    species_id = None
               

            elif hit_id and "Length=" in line:
                seq_length = int(line.split("=")[-1].strip())
            elif hit_id and "Expect =" in line:
                evalue = line.split("Expect = ")[1].split(",")[0].strip()
                score = line.split("Score = ")[1].split(" bits")[0].strip()
            elif hit_id and "Identities =" in line:
                identities_str = line.split("Identities = ")[1].split(",")[0].strip()
                identities = identities_str.split(" ")[0]
                identities_fraction = identities.split("/")
                identities_percent = (int(identities_fraction[0]) / int(identities_fraction[1])) * 100
                positives_str = line.split("Positives = ")[1].split(",")[0].strip()
                positives = positives_str.split(" ")[0]
                positives_fraction = positives.split("/")
                positives_percent = (int(positives_fraction[0]) / int(positives_fraction[1])) * 100
                gaps_str = line.split("Gaps = ")[1].split(" ")[0].strip()
                gaps = gaps_str
                gaps_fraction = gaps.split("/")
                gaps_percent = (int(gaps_fraction[0]) / int(gaps_fraction[1])) * 100
                # Append all values to hits_data
                hits_data.append([
                    query_id, hit_id, hit_number, seq_length, species_id, evalue, score, 
                    identities, f"{identities_percent:.2f}%", positives, f"{positives_percent:.2f}%", gaps, f"{gaps_percent:.2f}%"
                ])
    return hits_data

# List to store parsed data
parsed_data = []

# Loop through all files in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith("_blastp_results.txt"): 
        file_path = os.path.join(source_dir, file_name)
        parsed_data.extend(parse_blast_results(file_path))

# Write parsed data to CSV file
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow([
        'Query ID', 'Hit ID', 'Hit Number', 'Sequence Length', 'Species ID', 'Evalue', 'Score', 
        'Identities', 'Identities (%)', 'Positives', 'Positives (%)', 'Gaps', 'Gaps (%)'
    ])
    # Write parsed data
    writer.writerows(parsed_data)

print("CSV file created successfully")
# Out:
# CSV file created successfully

# %% [markdown]
# ## Convert Identity, positives and gaps

# %%
import pandas as pd

# Path to the input CSV file
input_csv_path = "/home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hits/comp_sf_hits.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(input_csv_path)

# Function to convert fraction to percentage without the % symbol
def convert_fraction_to_percentage(fraction_str):
    try:
        numerator, denominator = map(int, fraction_str.split('/'))
        percentage = (numerator / denominator) * 100
        return f"{percentage:.2f}"
    except ZeroDivisionError:
        return "Error: Division by zero"
    except ValueError:
        return fraction_str 

# Convert fractions to percentages in the entire DataFrame
for col in df.columns:
    df[col] = df[col].apply(lambda x: convert_fraction_to_percentage(x) if isinstance(x, str) and '/' in x else x)

# Save the modified DataFrame back to the original file name
df.to_csv(input_csv_path, index=False)

print(f"\nConverted fractions to percentages and saved to: {input_csv_path}")
# Out:
# Converted fractions to percentages and saved to: /home/osheakes/Research_Project_MMM/Fasta/Viral_Blasts/safety_net/results/hits/comp_sf_hits.csv
